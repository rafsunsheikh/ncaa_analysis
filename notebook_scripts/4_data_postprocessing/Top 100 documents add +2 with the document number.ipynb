# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/all_documents_per_topic_for_40_topics.xlsx')

df.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0        41663               0              0.8463
# 1        60670               0              0.8263
# 2        18707               0              0.8070
# 3        72012               0              0.7925
# 4        37592               0              0.7920
#
#                                             Keywords  \
# 0  school, schools, college, players, athletes, u...
# 1  school, schools, college, players, athletes, u...
# 2  school, schools, college, players, athletes, u...
# 3  school, schools, college, players, athletes, u...
# 4  school, schools, college, players, athletes, u...
#
#                                                 Text
# 0  ['graduation', 'success', 'rate', 'gsr', 'deve...
# 1  ['ncaa', 'academic', 'reforms', 'refined', 'el...
# 2  ['colleges', 'rankings', 'determined', 'federa...
# 3  ['western', 'sports', 'post', 'graduation', 's...
# 4  ['athlete', 'graduation', 'rate', 'fell', 'stu...

# %%
df['Document_No'] = df['Document_No'] + 2
display(df.head())
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0        41665               0              0.8463
# 1        60672               0              0.8263
# 2        18709               0              0.8070
# 3        72014               0              0.7925
# 4        37594               0              0.7920
#
#                                             Keywords  \
# 0  school, schools, college, players, athletes, u...
# 1  school, schools, college, players, athletes, u...
# 2  school, schools, college, players, athletes, u...
# 3  school, schools, college, players, athletes, u...
# 4  school, schools, college, players, athletes, u...
#
#                                                 Text
# 0  ['graduation', 'success', 'rate', 'gsr', 'deve...
# 1  ['ncaa', 'academic', 'reforms', 'refined', 'el...
# 2  ['colleges', 'rankings', 'determined', 'federa...
# 3  ['western', 'sports', 'post', 'graduation', 's...
# 4  ['athlete', 'graduation', 'rate', 'fell', 'stu...

# %%
excel_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/all_documents_per_topic_for_40_topics.xlsx'

df.to_excel(excel_file_path, index=False)

# %% [markdown]
# ##### **© 2024–2025 MD Rafsun Sheikh**
# ##### **Licensed under the Apache License, Version 2.0.**
