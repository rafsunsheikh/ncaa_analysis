# %%
# %pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 47.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 53.9 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 12.2 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gensim.models.ldamodel import LdaModel

# Load the LDA model
loaded_lda_model = LdaModel.load('/content/drive/MyDrive/Colab Notebooks/alex/models/lda_35_topics/lda_model_35_topics.gensim')

# Now you can access information from the loaded model.
# For example, you can print the topics:
print("Topics:")
for topic_id, topic in loaded_lda_model.print_topics():
    print(f"Topic {topic_id}: {topic}")

# You can also access the dictionary (id2word)
print("\nDictionary:")
print(loaded_lda_model.id2word)

# And the number of topics
print("\nNumber of topics:")
print(loaded_lda_model.num_topics)
# Out:
# Topics:
# Topic 33: 0.098*"bruins" + 0.069*"pac" + 0.052*"trojans" + 0.036*"los" + 0.032*"sun_devils" + 0.022*"photo" + 0.017*"cal" + 0.015*"conference" + 0.014*"ducks" + 0.012*"gottlieb"
# Topic 28: 0.107*"gophers" + 0.087*"minnesota" + 0.032*"ten" + 0.030*"johnson" + 0.021*"staff" + 0.015*"season" + 0.013*"team" + 0.010*"dakota" + 0.010*"north_dakota" + 0.010*"vikings"
# Topic 20: 0.033*"football" + 0.031*"quarterback" + 0.021*"nfl" + 0.021*"defensive" + 0.020*"college_football" + 0.012*"receiver" + 0.012*"coordinator" + 0.011*"running" + 0.011*"offensive" + 0.009*"field"
# Topic 16: 0.062*"nba" + 0.028*"basketball" + 0.014*"celtics" + 0.014*"lakers" + 0.013*"star" + 0.012*"league" + 0.011*"bulls" + 0.011*"player" + 0.010*"draft" + 0.010*"pick"
# Topic 10: 0.030*"temple" + 0.029*"wright" + 0.018*"willard" + 0.015*"owls" + 0.015*"atlantic" + 0.015*"la" + 0.014*"drexel" + 0.014*"joe" + 0.013*"wildcats" + 0.013*"salle"
# Topic 3: 0.052*"yards" + 0.018*"yard" + 0.018*"touchdowns" + 0.017*"harbaugh" + 0.015*"touchdown" + 0.015*"quarterback" + 0.014*"sanders" + 0.012*"field" + 0.011*"season" + 0.011*"rushing"
# Topic 23: 0.028*"season" + 0.028*"conference" + 0.024*"sec" + 0.022*"teams" + 0.022*"games" + 0.020*"top" + 0.019*"ten" + 0.019*"win" + 0.017*"team" + 0.013*"week"
# Topic 2: 0.018*"sports" + 0.018*"ncaa" + 0.017*"athletes" + 0.016*"schools" + 0.013*"million" + 0.010*"money" + 0.009*"football" + 0.008*"college_sports" + 0.007*"revenue" + 0.007*"school"
# Topic 11: 0.033*"baseball" + 0.016*"softball" + 0.015*"tbd" + 0.013*"innings" + 0.012*"hit" + 0.012*"college_world_series" + 0.011*"inning" + 0.010*"run" + 0.010*"pitcher" + 0.009*"field"
# Topic 8: 0.030*"season" + 0.025*"injury" + 0.016*"injuries" + 0.013*"play" + 0.013*"week" + 0.012*"games" + 0.010*"return" + 0.010*"practice" + 0.010*"day" + 0.009*"knee"
# Topic 30: 0.028*"team" + 0.016*"school" + 0.014*"women" + 0.014*"award" + 0.013*"named" + 0.012*"player" + 0.012*"college" + 0.012*"girls" + 0.010*"division" + 0.010*"soccer"
# Topic 18: 0.012*"nil" + 0.008*"fans" + 0.007*"time" + 0.006*"people" + 0.006*"sports" + 0.006*"moment" + 0.005*"night" + 0.005*"day" + 0.004*"told" + 0.004*"story"
# Topic 17: 0.172*"p.m" + 0.057*"espn" + 0.052*"march" + 0.034*"saturday" + 0.033*"friday" + 0.027*"winner" + 0.021*"sunday" + 0.019*"schedule" + 0.017*"thursday" + 0.015*"a.m"
# Topic 32: 0.056*"golf" + 0.016*"round" + 0.016*"armour" + 0.015*"championship" + 0.013*"shot" + 0.012*"tour" + 0.012*"club" + 0.012*"par" + 0.012*"tournament" + 0.011*"pga_tour"
# Topic 4: 0.020*"family" + 0.016*"school" + 0.015*"life" + 0.011*"father" + 0.010*"basketball" + 0.009*"home" + 0.009*"son" + 0.009*"parents" + 0.008*"people" + 0.007*"told"
# Topic 26: 0.016*"volleyball" + 0.015*"wrestling" + 0.015*"match" + 0.013*"team" + 0.011*"set" + 0.009*"def" + 0.009*"women" + 0.008*"won" + 0.008*"taylor" + 0.008*"lee"
# Topic 31: 0.031*"goals" + 0.024*"hockey" + 0.021*"goal" + 0.012*"season" + 0.011*"cronin" + 0.010*"ice" + 0.010*"games" + 0.009*"boston" + 0.009*"play" + 0.009*"assists"
# Topic 5: 0.024*"ncaa" + 0.011*"university" + 0.011*"investigation" + 0.009*"trial" + 0.008*"settlement" + 0.008*"court" + 0.008*"statement" + 0.007*"told" + 0.006*"school" + 0.006*"report"
# Topic 9: 0.051*"coach" + 0.022*"program" + 0.018*"coaches" + 0.018*"season" + 0.018*"coaching" + 0.017*"head_coach" + 0.015*"seasons" + 0.013*"job" + 0.010*"assistant" + 0.009*"school"
# Topic 6: 0.177*"women" + 0.050*"south" + 0.041*"basketball" + 0.033*"wnba" + 0.016*"connecticut" + 0.011*"player" + 0.011*"auriemma" + 0.011*"time" + 0.011*"staley" + 0.010*"final"
#
# Dictionary:
# Dictionary<264174 unique tokens: ['absolutely', 'accepting', 'accommodations', 'accordance', 'account']...>
#
# Number of topics:
# 35

# %%
from gensim import corpora

# Load the corpus from the .mm file
corpus = corpora.MmCorpus('/content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/corpus.mm')

print("Corpus loaded successfully.")
# You can optionally print the corpus to inspect its structure
# print(list(corpus))
# Out:
# Corpus loaded successfully.

# %%
import json
import pandas as pd

# Assuming your JSON file contains a list of lists, where each inner list is a tokenized document
# Replace '/content/drive/MyDrive/path/to/your/texts.json' with the actual path to your JSON file
texts_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/texts.json'

with open(texts_file_path, 'r') as f:
    texts = json.load(f)

print(f"Loaded {len(texts)} documents from {texts_file_path}")
# Out:
# Loaded 149649 documents from /content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/texts.json

# %%
# import pandas as pd

# # Load the tokenized data from the Excel file
# try:
#     tokenized_data_df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/alex/updated_ tokenized_newspaper_data.xlsx')
#     print("Excel file loaded successfully.")
#     # Assuming the original text is in a column named 'text' or similar.
#     # Please adjust the column name if it's different in your Excel file.
#     if 'Main_text_tokenized' in tokenized_data_df.columns:
#         texts = tokenized_data_df['Main_text_tokenized'].tolist()
#         print(f"Extracted {len(texts)} documents.")
#     else:
#         texts = None
#         print("Could not find a 'text' column in the Excel file. Please make sure the column containing original texts is named 'text' or update the code.")

# except FileNotFoundError:
#     print("Error: The file was not found at the specified path.")
# except Exception as e:
#     print(f"An error occurred while reading the Excel file: {e}")
# Out:
# Excel file loaded successfully.
# Extracted 149703 documents.

# %%
#TFinding the dominant topic in each sentence

def format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts): # Updated to use loaded_lda_model and corpus, and texts=None
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = pd.concat([sent_topics_df, pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]).to_frame().T], ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

     # Add original text to the end of the output
    if texts is not None: # Added check if texts is not None
        contents = pd.Series(texts)
        sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


# Assuming texts is available as data_words or you provide another list/Series of texts
# df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts) # Updated to use loaded_lda_model and corpus, commented out as data_words is undefined
# To run this cell, define `data_words` with your text data before calling the function.
# For example:
# data_words = ["your document text 1", "your document text 2", ...]
# Then uncomment the line below:
df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts)

# Format
if 'df_topic_sents_keywords' in locals(): # Added check if df_topic_sents_keywords is defined
    df_dominant_topic = df_topic_sents_keywords.reset_index()
    df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
    # Show
    display(df_dominant_topic.head(20)) # Use display for better formatting
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              4             0.2807
# 1             1              4             0.1975
# 2             2             16             0.2509
# 3             3              7             0.1914
# 4             4              1             0.1688
# 5             5             11             0.3071
# 6             6              1             0.4016
# 7             7             31             0.2079
# 8             8             14             0.2681
# 9             9              4              0.256
# 10           10             14             0.1614
# 11           11             32             0.3526
# 12           12             21             0.2241
# 13           13              8             0.1458
# 14           14             21             0.2841
# 15           15              2             0.5249
# 16           16             11             0.2369
# 17           17              5             0.3316
# 18           18             16             0.3253
# 19           19             25             0.2257
#
#                                              Keywords  \
# 0   family, school, life, father, basketball, home...
# 1   family, school, life, father, basketball, home...
# 2   nba, basketball, celtics, lakers, star, league...
# 3   olympic, world, olympics, won, women, time, go...
# 4   league, draft, season, nfl, team, round, milli...
# 5   baseball, softball, tbd, innings, hit, college...
# 6   league, draft, season, nfl, team, round, milli...
# 7   goals, hockey, goal, season, cronin, ice, game...
# 8   season, guard, team, player, rebounds, forward...
# 9   family, school, life, father, basketball, home...
# 10  season, guard, team, player, rebounds, forward...
# 11  golf, round, armour, championship, shot, tour,...
# 12  team, players, time, play, lot, playing, coach...
# 13  season, injury, injuries, play, week, games, r...
# 14  team, players, time, play, lot, playing, coach...
# 15  sports, ncaa, athletes, schools, million, mone...
# 16  baseball, softball, tbd, innings, hit, college...
# 17  ncaa, university, investigation, trial, settle...
# 18  nba, basketball, celtics, lakers, star, league...
# 19  tournament, seed, ncaa_tournament, final, roun...
#
#                                                  Text
# 0   [coaching, living, bonnie, henrickson, phone, ...
# 1   [sidebar, ruston, la, dining, louisiana, cajun...
# 2   [garden, missed, lonely, nights, season, debut...
# 3   [ten, ago, chuck, daly, reclining, alongside, ...
# 4   [robinson, talk, rangers, stanley, cup, finals...
# 5   [conference, pacific, coach_mike, gillespie, s...
# 6   [rangers, signed, center, michael, nylander, m...
# 7   [gavitt, elected, hall, modest, player, dartmo...
# 8   [mythical, element, senior_guard, seimone, aug...
# 9   [ncaa_women, jim, izard, diana, vines, remembe...
# 10  [meet, george_mason, guard, lamar, butler, jai...
# 11  [kevin, iole, review, journal, local, golf, cl...
# 12  [seventh, time, coach, beilein, process, movin...
# 13  [demetrius, jones, talk, anymore, monday, iris...
# 14  [oakland, eating, gilbert, arenas, check, blog...
# 15  [bothered, myles, brand, term, dumb, jock, bra...
# 16  [lot, guessing, season, trade, twins, manager,...
# 17  [college, pa, n.c.a.a, penn, letter, announcin...
# 18  [person, called, call, cheryl, miller, stage, ...
# 19  [selection_sunday, month, ncaa, selection_comm...

# %%
# Display the first few rows of the dataframe to see the structure
display(df_dominant_topic.head())
# Out:
#    Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0            0              4             0.2807
# 1            1              4             0.1975
# 2            2             16             0.2509
# 3            3              7             0.1914
# 4            4              1             0.1688
#
#                                             Keywords  \
# 0  family, school, life, father, basketball, home...
# 1  family, school, life, father, basketball, home...
# 2  nba, basketball, celtics, lakers, star, league...
# 3  olympic, world, olympics, won, women, time, go...
# 4  league, draft, season, nfl, team, round, milli...
#
#                                                 Text
# 0  [coaching, living, bonnie, henrickson, phone, ...
# 1  [sidebar, ruston, la, dining, louisiana, cajun...
# 2  [garden, missed, lonely, nights, season, debut...
# 3  [ten, ago, chuck, daly, reclining, alongside, ...
# 4  [robinson, talk, rangers, stanley, cup, finals...

# %%
# Sort documents within each topic by percentage contribution in descending order
sorted_documents_by_topic = df_dominant_topic.sort_values(by=['Dominant_Topic', 'Topic_Perc_Contrib'], ascending=[True, False])

# Display the sorted document indexes for each topic
print("Document Indexes for Each Topic (Sorted by Percentage Contribution):")
for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    print(f"\nTopic {topic_num}:")
    # Get documents for the current topic and select only the 'Document_No' column
    topic_documents = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num]['Document_No']
    # Display the document indexes (first 20 as an example)
    print(topic_documents.tolist()[:20])
# Out:
# Document Indexes for Each Topic (Sorted by Percentage Contribution):
#
# Topic 0:
# [48272, 60670, 41524, 3062, 37592, 47626, 74180, 1559, 36857, 30983, 41663, 72012, 21372, 3064, 65983, 48414, 50073, 43428, 7154, 75518]
#
# Topic 1:
# [121690, 106857, 120843, 12464, 35493, 29263, 36414, 66420, 34420, 140455, 94057, 13824, 113778, 119726, 1975, 107744, 135710, 147245, 30662, 41037]
#
# Topic 2:
# [98680, 120467, 80907, 125383, 89542, 18118, 65224, 124320, 10627, 72246, 55312, 138267, 78306, 93669, 130664, 137874, 92216, 138322, 70093, 90129]
#
# Topic 3:
# [20671, 57020, 42451, 16834, 68235, 112805, 13039, 21250, 13038, 35187, 592, 6657, 22780, 28768, 19663, 17638, 63783, 25979, 9886, 107342]
#
# Topic 4:
# [63005, 11603, 60321, 45848, 23151, 67091, 15527, 123383, 25149, 31041, 15526, 76456, 95419, 69341, 100772, 75224, 3633, 23330, 87936, 53231]
#
# Topic 5:
# [115822, 25870, 100438, 57162, 15802, 33888, 57083, 14542, 93570, 127167, 77012, 121819, 67515, 56172, 24077, 124713, 127332, 68207, 61206, 95346]
#
# Topic 6:
# [50357, 60218, 144504, 146625, 135480, 67613, 132542, 58137, 148168, 148169, 2836, 107412, 19536, 148959, 148936, 141237, 146659, 147128, 149288, 141563]
#
# Topic 7:
# [25689, 131394, 21228, 29548, 143612, 82981, 35586, 79655, 44096, 130960, 143731, 91683, 22982, 13924, 31487, 47956, 48333, 11698, 59312, 31478]
#
# Topic 8:
# [71026, 63459, 107231, 43637, 130942, 11458, 57420, 147027, 68853, 77734, 81265, 57919, 35419, 65922, 11459, 44547, 85450, 50030, 50033, 57120]
#
# Topic 26:
# [7186, 56086, 18752, 35307, 20589, 33748, 3333, 80523, 20584, 23209, 65399, 20956, 32030, 31001, 40637, 27373, 8372, 30075, 3257, 79690]
#
# Topic 27:
# [62817, 57976, 141957, 72814, 139652, 109570, 145262, 148020, 84747, 142422, 16543, 32193, 121631, 135667, 46618, 109870, 100012, 87064, 121425, 58903]
#
# Topic 28:
# [86231, 146939, 91994, 58795, 118934, 19537, 82199, 126061, 12728, 76867, 102043, 41419, 146014, 90365, 6474, 137456, 26828, 117410, 46069, 127946]
#
# Topic 29:
# [64676]
#
# Topic 30:
# [3154, 79720, 3146, 16759, 76819, 20373, 15491, 16761, 16762, 79647, 17527, 4102, 19021, 24180, 58185, 2910, 131793, 2525, 22390, 6354]
#
# Topic 31:
# [28674, 110361, 43945, 74411, 39426, 20404, 22613, 44921, 133259, 108583, 101066, 14576, 13282, 97889, 5024, 43947, 85417, 46567, 21652, 34351]
#
# Topic 32:
# [31667, 22333, 131005, 22335, 81958, 3512, 9885, 19345, 40863, 58390, 23306, 60212, 2999, 40013, 58687, 37539, 15915, 13752, 108475, 106809]
#
# Topic 33:
# [28671, 111292, 44326, 144214, 87252, 10882, 31006, 6830, 82784, 19659, 121903, 45769, 122009, 116689, 148327, 1815, 7887, 119554, 44325, 35703]
#
# Topic 34:
# [96115, 7937, 98758, 6504, 108686, 99109, 134742, 111972, 17339, 113603, 99779, 99776, 112271, 23970, 114443, 123561, 33058, 54587, 116987, 39280]

# %%
# Get the total number of documents for each dominant topic
topic_counts = df_dominant_topic['Dominant_Topic'].value_counts().sort_index()

print("Total number of documents for each topic:")
display(topic_counts)
# Out:
# Total number of documents for each topic:
# Dominant_Topic
# 0       509
# 1      3447
# 2      8475
# 3      4273
# 4      3010
# 5      6092
# 6      1068
# 7      8189
# 8      2326
# 9      6522
# 10     1090
# 11     4515
# 12       58
# 13     2462
# 14     8951
# 15      473
# 16     2787
# 17     1075
# 18     6786
# 19     1131
# 20     2846
# 21    16109
# 22     3973
# 23     6024
# 24    17616
# 25     8487
# 26     2502
# 27     2812
# 28     1437
# 29        1
# 30     3422
# 31     4963
# 32     2592
# 33      622
# 34     3004
# Name: count, dtype: int64

# %%
# Get the top 100 documents for each topic
top_100_documents_per_topic = pd.DataFrame()

for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    # Get the top 100 documents for the current topic
    top_100 = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num].head(100)
    # Append to the results DataFrame
    top_100_documents_per_topic = pd.concat([top_100_documents_per_topic, top_100], ignore_index=True)

# Display the top 100 documents for each topic
print("Top 100 Documents for Each Topic (Sorted by Percentage Contribution):")

# Iterate through topics and display the top documents for each
for topic_num in top_100_documents_per_topic['Dominant_Topic'].unique():
    print(f"\n--- Topic {topic_num} ---")
    display(top_100_documents_per_topic[top_100_documents_per_topic['Dominant_Topic'] == topic_num])
# Out:
# Top 100 Documents for Each Topic (Sorted by Percentage Contribution):
#
# --- Topic 0 ---
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0         48272              0             0.8489
# 1         60670              0             0.7608
# 2         41524              0             0.7004
# 3          3062              0             0.6994
# 4         37592              0             0.6936
# ..          ...            ...                ...
# 95       121843              0             0.4079
# 96        29320              0              0.407
# 97        13135              0             0.4035
# 98        73863              0             0.4014
# 99        82516              0              0.401
#
#                                              Keywords  \
# 0   students, university, black, school, student, ...
# 1   students, university, black, school, student, ...
# 2   students, university, black, school, student, ...
# 3   students, university, black, school, student, ...
# 4   students, university, black, school, student, ...
# ..                                                ...
# 95  students, university, black, school, student, ...
# 96  students, university, black, school, student, ...
# 97  students, university, black, school, student, ...
# 98  students, university, black, school, student, ...
# 99  students, university, black, school, student, ...
#
#                                                  Text
# 0   [university, federal, graduation_rates, athlet...
# 1   [ncaa, academic, reforms, refined, eligibility...
# 2   [university, graduated, percent, scholarship, ...
# 3   [graduation, rate, university, student_athlete...
# 4   [athlete, graduation, rate, fell, students, ti...
# ..                                                ...
# 95  [consistently, lauded, universities, country, ...
# 96  [boston_college_football_team, embarks, idaho,...
# 97  [profits, fun, ncaa_basketball_tournament, pla...
# 98  [lowest, graduation, rate, percent, teams_ncaa...
# 99  [ncaa, released, academic, progress, ratings, ...
#
# [100 rows x 5 columns]
# --- Topic 1 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 100       121690              1             0.6615
# 101       106857              1             0.6507
# 102       120843              1             0.6254
# 103        12464              1             0.6146
# 104        35493              1             0.6101
# ..           ...            ...                ...
# 195       130920              1             0.4374
# 196       131943              1             0.4374
# 197       106391              1             0.4365
# 198       127942              1             0.4365
# 199        45103              1             0.4362
#
#                                               Keywords  \
# 100  league, draft, season, nfl, team, round, milli...
# 101  league, draft, season, nfl, team, round, milli...
# 102  league, draft, season, nfl, team, round, milli...
# 103  league, draft, season, nfl, team, round, milli...
# 104  league, draft, season, nfl, team, round, milli...
# ..                                                 ...
# 195  league, draft, season, nfl, team, round, milli...
# 196  league, draft, season, nfl, team, round, milli...
# 197  league, draft, season, nfl, team, round, milli...
# 198  league, draft, season, nfl, team, round, milli...
# 199  league, draft, season, nfl, team, round, milli...
#
#                                                   Text
# 100  [flyers, found, center, monday, night, acquire...
# 101  [surprisingly, sporting, director, earnie, ste...
# 102  [jeff, gorton, enjoying, fabulous, summer, ran...
# 103  [cal, northridge, goalkeepr, joe, barton, draf...
# 104  [baseball, american, league, activated, dan, w...
# ..                                                 ...
# 195  [phillip, danault, signed, million, contract, ...
# 196  [major, league, soccer, expansion, club, charl...
# 197  [secrecy, fundamental, nfl, playbook, teams, r...
# 198  [thursday, d.c, united, found, top, mls, draft...
# 199  [mls, draft, buzzing, friday, trades, trades, ...
#
# [100 rows x 5 columns]
# --- Topic 2 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 200        98680              2             0.9323
# 201       120467              2             0.9295
# 202        80907              2             0.9164
# 203       125383              2                0.9
# 204        89542              2             0.8828
# ..           ...            ...                ...
# 295       124963              2             0.7693
# 296        38286              2             0.7681
# 297        11356              2             0.7675
# 298        94819              2             0.7674
# 299       124910              2             0.7674
#
#                                               Keywords  \
# 200  sports, ncaa, athletes, schools, million, mone...
# 201  sports, ncaa, athletes, schools, million, mone...
# 202  sports, ncaa, athletes, schools, million, mone...
# 203  sports, ncaa, athletes, schools, million, mone...
# 204  sports, ncaa, athletes, schools, million, mone...
# ..                                                 ...
# 295  sports, ncaa, athletes, schools, million, mone...
# 296  sports, ncaa, athletes, schools, million, mone...
# 297  sports, ncaa, athletes, schools, million, mone...
# 298  sports, ncaa, athletes, schools, million, mone...
# 299  sports, ncaa, athletes, schools, million, mone...
#
#                                                   Text
# 200  [recent, ncaa_rules, resulting, major_college_...
# 201  [athletics, programs, million, operating, reve...
# 202  [major_college_athletics, departments, increas...
# 203  [influential, leadership, proposed, sweeping, ...
# 204  [major_college_athletics, departments, increas...
# ..                                                 ...
# 295  [college_athletes, gain, significant, abilitie...
# 296  [myles, brand, president, national, collegiate...
# 297  [ncaa, spending, won, football, title, bottom,...
# 298  [universities, country, prominent, athletics, ...
# 299  [ncaa, reduce, direct, distribution, division,...
#
# [100 rows x 5 columns]
# --- Topic 3 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 300        20671              3             0.9035
# 301        57020              3              0.896
# 302        42451              3             0.8656
# 303        16834              3             0.8508
# 304        68235              3             0.8466
# ..           ...            ...                ...
# 395        38576              3             0.7019
# 396        39437              3              0.701
# 397        36928              3             0.7006
# 398        51297              3              0.697
# 399        21638              3             0.6963
#
#                                               Keywords  \
# 300  yards, yard, touchdowns, harbaugh, touchdown, ...
# 301  yards, yard, touchdowns, harbaugh, touchdown, ...
# 302  yards, yard, touchdowns, harbaugh, touchdown, ...
# 303  yards, yard, touchdowns, harbaugh, touchdown, ...
# 304  yards, yard, touchdowns, harbaugh, touchdown, ...
# ..                                                 ...
# 395  yards, yard, touchdowns, harbaugh, touchdown, ...
# 396  yards, yard, touchdowns, harbaugh, touchdown, ...
# 397  yards, yard, touchdowns, harbaugh, touchdown, ...
# 398  yards, yard, touchdowns, harbaugh, touchdown, ...
# 399  yards, yard, touchdowns, harbaugh, touchdown, ...
#
#                                                   Text
# 300  [lawrence, kan, running, cedric, benson, yard,...
# 301  [categorynavyopppassing, yards, rushing, yards...
# 302  [week, wolfe, rushed, yards, carries, touchdow...
# 303  [college_football, tech, lubbock, b.j, symons,...
# 304  [damaris, johnson, broke, loose, career, purpo...
# ..                                                 ...
# 395  [redshirt, junior, passed, yards, touchdowns, ...
# 396  [east, stroudsburg, jimmy, terwilliger, threw,...
# 397  [deangelo, williams, set, ncaa_record, yard, r...
# 398  [jeremy, maclin, maclin, foot, pound, wide, re...
# 399  [adam, knoblauch, passed, yards, pair, touchdo...
#
# [100 rows x 5 columns]
# --- Topic 4 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 400        63005              4             0.6172
# 401        11603              4             0.5599
# 402        60321              4             0.5474
# 403        45848              4             0.5438
# 404        23151              4              0.538
# ..           ...            ...                ...
# 495        44260              4              0.398
# 496          378              4             0.3969
# 497         1356              4             0.3963
# 498        57239              4             0.3963
# 499        64480              4             0.3959
#
#                                               Keywords  \
# 400  family, school, life, father, basketball, home...
# 401  family, school, life, father, basketball, home...
# 402  family, school, life, father, basketball, home...
# 403  family, school, life, father, basketball, home...
# 404  family, school, life, father, basketball, home...
# ..                                                 ...
# 495  family, school, life, father, basketball, home...
# 496  family, school, life, father, basketball, home...
# 497  family, school, life, father, basketball, home...
# 498  family, school, life, father, basketball, home...
# 499  family, school, life, father, basketball, home...
#
#                                                   Text
# 400  [daniel, bugey, darby, postmaster, daniel, bug...
# 401  [dr, charles, labotka, children, house, calls,...
# 402  [pond, robert, jackson, memorial, service, fri...
# 403  [tschudy, dr, lynn, beloved, daughter, sister,...
# 404  [george, dernoeden, editorial, assistant, geor...
# ..                                                 ...
# 495  [schurz, school, terrence, mccann, ardent, suc...
# 496  [andrew, zamparelli, college, track, star, bus...
# 497  [midwest, traditional, feeder, retirement, mar...
# 498  [note, final, san_antonio, memphis, p.m, satur...
# 499  [patrick, traynor, perkasie, clinical, psychol...
#
# [100 rows x 5 columns]
# --- Topic 5 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 500       115822              5             0.8511
# 501        25870              5             0.8222
# 502       100438              5             0.8091
# 503        57162              5             0.8068
# 504        15802              5             0.8049
# ..           ...            ...                ...
# 595        15551              5             0.6454
# 596       119493              5             0.6451
# 597        75938              5              0.645
# 598       122888              5             0.6446
# 599        34110              5             0.6441
#
#                                               Keywords  \
# 500  ncaa, university, investigation, trial, settle...
# 501  ncaa, university, investigation, trial, settle...
# 502  ncaa, university, investigation, trial, settle...
# 503  ncaa, university, investigation, trial, settle...
# 504  ncaa, university, investigation, trial, settle...
# ..                                                 ...
# 595  ncaa, university, investigation, trial, settle...
# 596  ncaa, university, investigation, trial, settle...
# 597  ncaa, university, investigation, trial, settle...
# 598  ncaa, university, investigation, trial, settle...
# 599  ncaa, university, investigation, trial, settle...
#
#                                                   Text
# 500  [received, formal, notice, allegations, ncaa, ...
# 501  [colleges, basketball_coach, quin, snyder, acc...
# 502  [ncaa, committee, infractions, received, viole...
# 503  [indiana, coach, kelvin, sampson, staff, viola...
# 504  [lawyer, football_coach, rick, neuheisel, met,...
# ..                                                 ...
# 595  [colleges, tailback, maurice, clarett, admitte...
# 596  [york, coach, sean, miller, testify, upcoming,...
# 597  [freshmen, george, fant, t.j, price, miss, str...
# 598  [ncaa, notice, allegations, wildcats, basketba...
# 599  [basketball, court, claims, judge, joseph, cla...
#
# [100 rows x 5 columns]
# --- Topic 6 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 600        50357              6             0.7735
# 601        60218              6             0.6983
# 602       144504              6             0.6195
# 603       146625              6             0.5998
# 604       135480              6             0.5959
# ..           ...            ...                ...
# 695          233              6             0.3738
# 696       115880              6             0.3738
# 697       141251              6              0.372
# 698         1627              6             0.3718
# 699       148937              6             0.3717
#
#                                               Keywords  \
# 600  women, south, basketball, wnba, connecticut, p...
# 601  women, south, basketball, wnba, connecticut, p...
# 602  women, south, basketball, wnba, connecticut, p...
# 603  women, south, basketball, wnba, connecticut, p...
# 604  women, south, basketball, wnba, connecticut, p...
# ..                                                 ...
# 695  women, south, basketball, wnba, connecticut, p...
# 696  women, south, basketball, wnba, connecticut, p...
# 697  women, south, basketball, wnba, connecticut, p...
# 698  women, south, basketball, wnba, connecticut, p...
# 699  women, south, basketball, wnba, connecticut, p...
#
#                                                   Text
# 600  [newsy, defeated, rutgers, tuesday, night, win...
# 601  [goestenkors, ncaa_record, straight_win, seaso...
# 602  [south, women, basketball_team, completed, und...
# 603  [south, women, basketball_coach, dawn_staley, ...
# 604  [sue, bird, diana, taurasi, bring, expertise, ...
# ..                                                 ...
# 695  [rest, women, college_basketball, world, relie...
# 696  [piscataway, n.j, wins, vivian, stringer, join...
# 697  [caitlin_clark, era, officially, pick, indiana...
# 698  [ncaa_tournaments, san_antonio, supposed, hots...
# 699  [fla, national_title, securely, hand, connecti...
#
# [100 rows x 5 columns]
# --- Topic 7 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 700        25689              7             0.8724
# 701       131394              7             0.8393
# 702        21228              7             0.8375
# 703        29548              7              0.831
# 704       143612              7             0.8249
# ..           ...            ...                ...
# 795        46328              7             0.6948
# 796        54928              7             0.6946
# 797         3768              7             0.6943
# 798        30306              7              0.694
# 799        60498              7              0.694
#
#                                               Keywords  \
# 700  olympic, world, olympics, won, women, time, go...
# 701  olympic, world, olympics, won, women, time, go...
# 702  olympic, world, olympics, won, women, time, go...
# 703  olympic, world, olympics, won, women, time, go...
# 704  olympic, world, olympics, won, women, time, go...
# ..                                                 ...
# 795  olympic, world, olympics, won, women, time, go...
# 796  olympic, world, olympics, won, women, time, go...
# 797  olympic, world, olympics, won, women, time, go...
# 798  olympic, world, olympics, won, women, time, go...
# 799  olympic, world, olympics, won, women, time, go...
#
#                                                   Text
# 700  [christine, spence, seventh, meter, hurdles, n...
# 701  [tokyo, american, diving, duo, delaney, schnel...
# 702  [michael, phelps, quest, match, mark, spitz, g...
# 703  [colleges, simon, bairu, repeated, individual,...
# 704  [team_usa, stacked, roster, paris, olympics, c...
# ..                                                 ...
# 795  [venue, changed, results, wining, ncaa, indoor...
# 796  [eugene, ore, bryan, clay, shy, disgusted, per...
# 797  [minutes, saturday, night, janet, evans, invit...
# 798  [ran, fast, meter, hurdles, kerron, clement, s...
# 799  [half, marathoner, runners, died, yesterday, d...
#
# [100 rows x 5 columns]
# --- Topic 8 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 800        52293              8             0.6481
# 801        37272              8             0.6345
# 802        37020              8             0.6311
# 803         4644              8             0.6273
# 804       119253              8             0.6137
# ..           ...            ...                ...
# 895        32201              8             0.4361
# 896          457              8             0.4359
# 897        45201              8             0.4359
# 898       126266              8             0.4358
# 899        97665              8             0.4354
#
#                                               Keywords  \
# 800  season, injury, injuries, play, week, games, r...
# 801  season, injury, injuries, play, week, games, r...
# 802  season, injury, injuries, play, week, games, r...
# 803  season, injury, injuries, play, week, games, r...
# 804  season, injury, injuries, play, week, games, r...
# ..                                                 ...
# 895  season, injury, injuries, play, week, games, r...
# 896  season, injury, injuries, play, week, games, r...
# 897  season, injury, injuries, play, week, games, r...
# 898  season, injury, injuries, play, week, games, r...
# 899  season, injury, injuries, play, week, games, r...
#
#                                                   Text
# 800  [bye, week, regain, health, significant, playe...
# 801  [coach, jay, wright, players, progress, hopes,...
# 802  [summer, workouts, college_football_players, c...
# 803  [memphis, forward, chris, massie, declared, ac...
# 804  [injury, list, grown, absurd, proportions, sea...
# ..                                                 ...
# 895  [hours, hoped, pack, pavilion, hoops, mania, e...
# 896  [mississippi, center, mario, cleared, play, tu...
# 897  [curtis, sumpter, decided, return, play, seaso...
# 898  [people, aware, situation, rise, involved, spo...
# 899  [bulls, plan, introduce, fred, hoiberg, coach,...
#
# [100 rows x 5 columns]
# --- Topic 9 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 900        51773              9             0.8785
# 901        33318              9             0.8685
# 902        42557              9             0.8627
# 903        40702              9             0.8195
# 904        34824              9             0.8041
# ..           ...            ...                ...
# 995        87302              9             0.5949
# 996       141277              9             0.5945
# 997       111106              9              0.594
# 998         4568              9             0.5938
# 999        59541              9             0.5938
#
#                                               Keywords  \
# 900  coach, program, coaches, season, coaching, hea...
# 901  coach, program, coaches, season, coaching, hea...
# 902  coach, program, coaches, season, coaching, hea...
# 903  coach, program, coaches, season, coaching, hea...
# 904  coach, program, coaches, season, coaching, hea...
# ..                                                 ...
# 995  coach, program, coaches, season, coaching, hea...
# 996  coach, program, coaches, season, coaching, hea...
# 997  coach, program, coaches, season, coaching, hea...
# 998  coach, program, coaches, season, coaching, hea...
# 999  coach, program, coaches, season, coaching, hea...
#
#                                                   Text
# 900  [active, college_basketball_coaches, won, mult...
# 901  [short, seasons, coaching, serving, coach, ath...
# 902  [eddie, sutton, retired, basketball_coach, yes...
# 903  [yrswonlostpct, dean, smith, bob, knight, adol...
# 904  [football, shula, extension, coach_mike, shula...
# ..                                                 ...
# 995  [add, vacancy, sign, athletic, offices, michae...
# 996  [hired, calipari, basketball_coach, school, an...
# 997  [butler, coach, chris, holtmann, replace, thad...
# 998  [women, basketball_programs, ball, minnesota, ...
# 999  [mark, anderson, review, journal, kathy, olivi...
#
# [100 rows x 5 columns]
# --- Topic 10 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1000        93855             10              0.626
# 1001        61202             10             0.6153
# 1002        65063             10              0.615
# 1003        89069             10             0.5836
# 1004       141157             10             0.5683
# ...           ...            ...                ...
# 1095        74573             10             0.3822
# 1096        24801             10              0.382
# 1097        34658             10              0.382
# 1098        88960             10             0.3819
# 1099         3263             10             0.3817
#
#                                                Keywords  \
# 1000  temple, wright, willard, owls, atlantic, la, d...
# 1001  temple, wright, willard, owls, atlantic, la, d...
# 1002  temple, wright, willard, owls, atlantic, la, d...
# 1003  temple, wright, willard, owls, atlantic, la, d...
# 1004  temple, wright, willard, owls, atlantic, la, d...
# ...                                                 ...
# 1095  temple, wright, willard, owls, atlantic, la, d...
# 1096  temple, wright, willard, owls, atlantic, la, d...
# 1097  temple, wright, willard, owls, atlantic, la, d...
# 1098  temple, wright, willard, owls, atlantic, la, d...
# 1099  temple, wright, willard, owls, atlantic, la, d...
#
#                                                    Text
# 1000  [george, colonials, results, november, radford...
# 1001  [read, wku, beat, writer, nick, baumgardner, h...
# 1002  [read, wku, beat, writer, nick, baumgardner, h...
# 1003  [baseball, george, vcu, lacrosse, women, ncaa_...
# 1004               [st, joe, stays, home, ncaa_tourney]
# ...                                                 ...
# 1095  [women, div, ncaa_tournament, p.m, st_joseph, ...
# 1096  [temple, drexel, basketball_season, continues,...
# 1097  [rutgers, pressure, defense, led, michelle, ca...
# 1098  [la, salle, unofficially, earned, bye, round, ...
# 1099  [nit, victories, costly, injury, david, hawkin...
#
# [100 rows x 5 columns]
# --- Topic 11 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 
---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1258        83258             13             0.8051
# 1259        77336             13             0.7939
# 1260       149605             13             0.7762
# 1261        26468             13             0.7703
# 1262       108918             13             0.7675
# ...           ...            ...                ...
# 1353       149429             13               0.63
# 1354        64435             13             0.6294
# 1355        83773             13             0.6287
# 1356        10767             13             0.6286
# 1357        18949             13             0.6275
#
#                                                Keywords  \
# 1258  sports, espn, tv, network, watch, usa, cbs, li...
# 1259  sports, espn, tv, network, watch, usa, cbs, li...
# 1260  sports, espn, tv, network, watch, usa, cbs, li...
# 1261  sports, espn, tv, network, watch, usa, cbs, li...
# 1262  sports, espn, tv, network, watch, usa, cbs, li...
# ...                                                 ...
# 1353  sports, espn, tv, network, watch, usa, cbs, li...
# 1354  sports, espn, tv, network, watch, usa, cbs, li...
# 1355  sports, espn, tv, network, watch, usa, cbs, li...
# 1356  sports, espn, tv, network, watch, usa, cbs, li...
# 1357  sports, espn, tv, network, watch, usa, cbs, li...
#
#                                                    Text
# 1258  [ncaa_basketball_games, carried, turner, tnt, ...
# 1259  [ncaa_basketball_tournament, air, entirety, cb...
# 1260  [madness, underway, cinderellas, crowned, cont...
# 1261  [top, top, sports, video, games, check, august...
# 1262  [streaming, service, hulu, wednesday, notched,...
# ...                                                 ...
# 1353  [events, march_madness, masters, tournament, h...
# 1354  [cbs, watched, network, week, time, television...
# 1355  [media, companies, nbc, fox, al, jazeera, digg...
# 1356  [viacom, networks, tnn, tv, land, tnt, tbs, jo...
# 1357  [ncaa_tournament, coverage, moved, cbs, espn, ...
#
# [100 rows x 5 columns]
# --- Topic 14 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1358       103586             14             0.9514
# 1359       108107             14             0.9514
# 1360        17702             14             0.8628
# 1361        24349             14             0.7744
# 1362        17703             14             0.7621
# ...           ...            ...                ...
# 1453        65744             14             0.5905
# 1454          282             14             0.5898
# 1455       140409             14             0.5896
# 1456        24375             14             0.5889
# 1457       121671             14             0.5887
#
#                                                Keywords  \
# 1358  season, guard, team, player, rebounds, forward...
# 1359  season, guard, team, player, rebounds, forward...
# 1360  season, guard, team, player, rebounds, forward...
# 1361  season, guard, team, player, rebounds, forward...
# 1362  season, guard, team, player, rebounds, forward...
# ...                                                 ...
# 1453  season, guard, team, player, rebounds, forward...
# 1454  season, guard, team, player, rebounds, forward...
# 1455  season, guard, team, player, rebounds, forward...
# 1456  season, guard, team, player, rebounds, forward...
# 1457  season, guard, team, player, rebounds, forward...
#
#                                                    Text
# 1358  [season, stats, ncaa, rank, scoring, offense, ...
# 1359  [season, stats, ncaa, rank, scoring, offense, ...
# 1360  [jackson, lady_vols, jackson, playing, basketb...
# 1361  [site, alamodome, san_antonio, watch, connecti...
# 1362  [focus, senior, forward, gwen, jackson, playin...
# ...                                                 ...
# 1453  [nation, team, takes, tonight, battle, east, r...
# 1454  [finally, question, junior, forward, nick, col...
# 1455  [deep, ncaa_tournament, quick, exit, aren, fac...
# 1456  [birmingham, site, st_louis, time, p.m, pst, w...
# 1457  [ncaa_tournament, couple, weeks, heartbreak, u...
#
# [100 rows x 5 columns]
# --- Topic 15 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1458        83443             15             0.8755
# 1459        77117             15             0.7657
# 1460       136091             15             0.7571
# 1461        95048             15             0.7524
# 1462        50007             15             0.7261
# ...           ...            ...                ...
# 1553        45986             15             0.3646
# 1554        88912             15             0.3617
# 1555        70700             15             0.3615
# 1556        64868             15             0.3608
# 1557        77252             15              0.358
#
#                                                Keywords  \
# 1458  indiana, purdue, pitino, northwestern, photo, ...
# 1459  indiana, purdue, pitino, northwestern, photo, ...
# 1460  indiana, purdue, pitino, northwestern, photo, ...
# 1461  indiana, purdue, pitino, northwestern, photo, ...
# 1462  indiana, purdue, pitino, northwestern, photo, ...
# ...                                                 ...
# 1553  indiana, purdue, pitino, northwestern, photo, ...
# 1554  indiana, purdue, pitino, northwestern, photo, ...
# 1555  indiana, purdue, pitino, northwestern, photo, ...
# 1556  indiana, purdue, pitino, northwestern, photo, ...
# 1557  indiana, purdue, pitino, northwestern, photo, ...
#
#                                                    Text
# 1458  [caption, text, illustration, caption, graphic...
# 1459  [caption, text, illustration, caption, graphic...
# 1460  [neil, neil.best, newsday.com, credit, neil, n...
# 1461  [caption, text, illustration, caption, graphic...
# 1462  [caption, text, illustration, caption, graphic...
# ...                                                 ...
# 1553  [note, special, section, ncaa_football_preview...
# 1554  [caption, text, illustration, caption, photo, ...
# 1555  [offense, kyle, singler, jon, scheyer, nolan, ...
# 1556  [caption, text, illustration, caption, roger, ...
# 1557  [east_regional, north, liu, george_mason, san_...
#
# [100 rows x 5 columns]
# --- Topic 16 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1558        24210             16             0.6885
# 1559       120014             16             0.6808
# 1560       120015             16             0.6808
# 1561        46827             16             0.6497
# 1562        57025             16             0.6321
# ...           ...            ...                ...
# 1653        62789             16             0.4626
# 1654        26045             16             0.4614
# 1655        35678             16             0.4614
# 1656        64106             16             0.4599
# 1657        11247             16             0.4598
#
#                                                Keywords  \
# 1558  nba, basketball, celtics, lakers, star, league...
# 1559  nba, basketball, celtics, lakers, star, league...
# 1560  nba, basketball, celtics, lakers, star, league...
# 1561  nba, basketball, celtics, lakers, star, league...
# 1562  nba, basketball, celtics, lakers, star, league...
# ...                                                 ...
# 1653  nba, basketball, celtics, lakers, star, league...
# 1654  nba, basketball, celtics, lakers, star, league...
# 1655  nba, basketball, celtics, lakers, star, league...
# 1656  nba, basketball, celtics, lakers, star, league...
# 1657  nba, basketball, celtics, lakers, star, league...
#
#                                                    Text
# 1558  [nba, champions, finals, valuable, players, ch...
# 1559  [nba, team, lottery, pick, signal, hope, optim...
# 1560  [nba, team, lottery, pick, signal, hope, optim...
# 1561  [portland, beat, odds, tuesday, won, nba_draft...
# 1562  [nba, convened, magic, johnson, larry, bird, m...
# ...                                                 ...
# 1653  [matt, guokas, mind, los, lakers, forward, luk...
# 1654  [nba, star, sports, monday, kidd, gloves, jaso...
# 1655  [bucks, suffered, disappointing, season, playo...
# 1656  [los, orlando, magic, decided, gamble, playoff...
# 1657  [detroit, pistons, nba, squad, hall_famer, lar...
#
# [100 rows x 5 columns]
# --- Topic 17 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 
---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1858       143389             19              0.851
# 1859        89263             19             0.8067
# 1860        28959             19             0.7894
# ...
# 2656  volleyball, wrestling, match, team, set, def, ...
# 2657  volleyball, wrestling, match, team, set, def, ...
#
#                                                    Text
# 2558  [volleyball, katie, olsovsky, kills, top_seede...
# 2559  [hpu, teams, advance, ncaa, dii, tennis, elena...
# 2560  [volleyball, keao, burdine, kills, digs, leadi...
# 2561  [byu, women, break, record, advertiser, staff,...
# 2562  [seasiders, beat, lynn, consecutive, title, ad...
# ...                                                 ...
# 2653  [elizabeth, lumpkin, won, singles, doubles, cl...
# 2654  [final, set, ncaa_volleyball, championships, b...
# 2655  [waves, block, warriors, stephen, tsai, advert...
# 2656  [matchup, nation, top_ranked, college_volleyba...
# 2657  [advertiser, staff, university, women, volleyb...
#
# [100 rows x 5 columns]
# --- Topic 27 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2658        62817             27             0.7566
# 2659        57976             27             0.7229
# 2660       141957             27             0.7195
# 2661        72814             27             0.7085
# 2662       139652             27             0.6891
# ...           ...            ...                ...
# 2753        99260             27             0.5107
# 2754       107797             27             0.5106
# 2755       111149             27             0.5098
# 2756        63014             27             0.5093
# 2757        74443             27             0.5092
#
#                                                Keywords  \
# 2658  fans, stadium, city, arena, event, tickets, ho...
# 2659  fans, stadium, city, arena, event, tickets, ho...
# 2660  fans, stadium, city, arena, event, tickets, ho...
# 2661  fans, stadium, city, arena, event, tickets, ho...
# 2662  fans, stadium, city, arena, event, tickets, ho...
# ...                                                 ...
# 2753  fans, stadium, city, arena, event, tickets, ho...
# 2754  fans, stadium, city, arena, event, tickets, ho...
# 2755  fans, stadium, city, arena, event, tickets, ho...
# 2756  fans, stadium, city, arena, event, tickets, ho...
# 2757  fans, stadium, city, arena, event, tickets, ho...
#
#                                                    Text
# 2658  [http, www.bgdailynews.com, multimedia, wku, i...
# 2659  [glendale, hosting, college_basketball_ncaa_fi...
# 2660  [ncaa_final, glendale, starts, basketball, cha...
# 2661  [http, bgdailynews.com, basketball.pdf, click,...
# 2662  [farm, stadium, significant, driver, tourism, ...
# ...                                                 ...
# 2753  [super_bowl, valley, buzziest, party, featured...
# 2754  [bank, stadium, purple, seats, ready, waiting,...
# 2755  [suburban, station, undergoing, major, retail,...
# 2756  [largest, city, country, sports, town, home, f...
# 2757  [karaoke, fanatics, whistler, ave, burst, gene...
#
# [100 rows x 5 columns]
# --- Topic 28 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2758        86231             28             0.5953
# 2759       146939             28             0.5209
# 2760        91994             28             0.5127
# 2761        58795             28             0.5082
# 2762       118934             28              0.488
# ...           ...            ...                ...
# 2853         3025             28             0.3542
# 2854        53236             28              0.353
# 2855       142155             28             0.3527
# 2856        12709             28             0.3525
# 2857        22977             28             0.3525
#
#                                                Keywords  \
# 2758  gophers, minnesota, ten, johnson, staff, seaso...
# 2759  gophers, minnesota, ten, johnson, staff, seaso...
# 2760  gophers, minnesota, ten, johnson, staff, seaso...
# 2761  gophers, minnesota, ten, johnson, staff, seaso...
# 2762  gophers, minnesota, ten, johnson, staff, seaso...
# ...                                                 ...
# 2853  gophers, minnesota, ten, johnson, staff, seaso...
# 2854  gophers, minnesota, ten, johnson, staff, seaso...
# 2855  gophers, minnesota, ten, johnson, staff, seaso...
# 2856  gophers, minnesota, ten, johnson, staff, seaso...
# 2857  gophers, minnesota, ten, johnson, staff, seaso...
#
#                                                    Text
# 2758  [xcel, energy, center, play, host, west_region...
# 2759  [p.m, wednesday, williams_arena, streaming, ra...
# 2760  [highlights, mavericks, warriors, fall, nsic, ...
# 2761  [official, games, major_college_basketball_sea...
# 2762  [p.m, friday, fsn, saturday, fsn, arena, mariu...
# ...                                                 ...
# 2853  [rsec, time, season, coaches, precious, moment...
# 2854  [minnesota, crookston, hold, news, conference,...
# 2855  [home, series, p.m, friday, saturday, arena, m...
# 2856  [gophers, offense, gophers_basketball_team, sh...
# 2857  [gophers, freshman, forward, kris, humphries, ...
#
# [100 rows x 5 columns]
# --- Topic 29 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2858        64676             29             0.1704
#
#                                                Keywords  \
# 2858  penn, brown, watkins, ivy_league, richardson, ...
#
#                                                    Text
# 2858  [cornell, clinch, consecutive, ivy_league, tit...
# --- Topic 30 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2859         3154             30             0.9835
# 2860        79720             30             0.8921
# 2861         3146             30             0.8735
# 2862        16759             30             0.8412
# 2863        76819             30             0.8381
# ...           ...            ...                ...
# 2954        69907             30             0.5873
# 2955        39970             30             0.5865
# 2956        19023             30             0.5856
# 2957        36624             30             0.5852
# 2958        71056             30             0.5836
#
#                                                Keywords  \
# 2859  team, school, women, award, named, player, col...
# 2860  team, school, women, award, named, player, col...
# 2861  team, school, women, award, named, player, col...
# 2862  team, school, women, award, named, player, col...
# 2863  team, school, women, award, named, player, col...
# ...                                                 ...
# 2954  team, school, women, award, named, player, col...
# 2955  team, school, women, award, named, player, col...
# 2956  team, school, women, award, named, player, col...
# 2957  team, school, women, award, named, player, col...
# 2958  team, school, women, award, named, player, col...
#
#                                                    Text
# 2859  [globe, west, sports, sportswest, wheaton, col...
# 2860  [player, played, senior, school, list, subject...
# 2861  [globe, west, sports, medway, sport, athlete, ...
# 2862  [globe, south, sports, notebook, paul, harber,...
# 2863  [field_hockey, ncaa_division_iii, tournament, ...
# ...                                                 ...
# 2954  [led, top, vote, getters, kim, willoughby, kan...
# 2955  [globe, northwest, sports, notebook, boys, gir...
# 2956  [globe, south, sports, sports, notebook, wheat...
# 2957  [globe, west, sports, hard, dedication, paid, ...
# 2958  [colin, henry, started, played, soccer_team, b...
#
# [100 rows x 5 columns]
# --- Topic 31 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2959        28674             31             0.8612
# 2960       110361             31             0.8142
# 2961        43945             31             0.7937
# 2962        74411             31               0.79
# 2963        39426             31             0.7705
# ...           ...            ...                ...
# 3054       103261             31             0.6597
# 3055        72763             31             0.6596
# 3056         7422             31             0.6594
# 3057        58995             31             0.6593
# 3058        66043             31             0.6589
#
#                                                Keywords  \
# 2959  goals, hockey, goal, season, cronin, ice, game...
# 2960  goals, hockey, goal, season, cronin, ice, game...
# 2961  goals, hockey, goal, season, cronin, ice, game...
# 2962  goals, hockey, goal, season, cronin, ice, game...
# 2963  goals, hockey, goal, season, cronin, ice, game...
# ...                                                 ...
# 3054  goals, hockey, goal, season, cronin, ice, game...
# 3055  goals, hockey, goal, season, cronin, ice, game...
# 3056  goals, hockey, goal, season, cronin, ice, game...
# 3057  goals, hockey, goal, season, cronin, ice, game...
# 3058  goals, hockey, goal, season, cronin, ice, game...
#
#                                                    Text
# 2959  [ncaa_division, tournament, columbus, champion...
# 2960  [lowell, won, hockey_east_title, saturday, nig...
# 2961  [boston, university, broke, boston_college, ne...
# 2962  [junior, wing, cam, atkinson, scored, period, ...
# 2963  [frozen, skating, crowd, bradley, center, nort...
# ...                                                 ...
# 3054  [worcester, deep, fast, opportunistic, puck, b...
# 3055  [ncaa_hockey_tournament_games, rit, ford, fiel...
# 3056  [boston, university, continues, pressure, hamp...
# 3057  [ncaa_tournament, sidebar, pdf, chart, data, c...
# 3058  [beanpot, notebook, season, run, ncaa_champion...
#
# [100 rows x 5 columns]
# --- Topic 32 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3059        31667             32             0.8501
# 3060        22333             32             0.8494
# 3061       131005             32             0.8378
# 3062        22335             32             0.8346
# 3063        81958             32             0.8335
# ...           ...            ...                ...
# 3154       131782             32             0.6784
# 3155        25391             32             0.6783
# 3156        38959             32             0.6779
# 3157         5665             32             0.6774
# 3158        79817             32             0.6754
#
#                                                Keywords  \
# 3059  golf, round, armour, championship, shot, tour,...
# 3060  golf, round, armour, championship, shot, tour,...
# 3061  golf, round, armour, championship, shot, tour,...
# 3062  golf, round, armour, championship, shot, tour,...
# 3063  golf, round, armour, championship, shot, tour,...
# ...                                                 ...
# 3154  golf, round, armour, championship, shot, tour,...
# 3155  golf, round, armour, championship, shot, tour,...
# 3156  golf, round, armour, championship, shot, tour,...
# 3157  golf, round, armour, championship, shot, tour,...
# 3158  golf, round, armour, championship, shot, tour,...
#
#                                                    Text
# 3059  [trip, masters, rewarding, mesa, resident, mar...
# 3060  [ernie, els, ben, curtis, share, birdies, toug...
# 3061  [valspar, championship, returns, palm, harbor,...
# 3062  [annika, sorenstam, mad, finished, birdies, gr...
# 3063  [defending_champion, bryce, molder, earned, pg...
# ...                                                 ...
# 3154  [holes, robert, gearhart, carefree, verde, riv...
# 3155  [european, event, world, match, play, champion...
# 3156  [stewart, cink, swinging, thinking, round, col...
# 3157  [golf, greg, norman, winless, pga_tour, shot, ...
# 3158  [michelle, wie, voice, emotion, birdie, putts,...
#
# [100 rows x 5 columns]
# --- Topic 33 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3159        28671             33             0.6734
# 3160       111292             33             0.6332
# 3161        44326             33             0.6255
# 3162       144214             33              0.571
# 3163        87252             33             0.5658
# ...           ...            ...                ...
# 3254        87335             33             0.3328
# 3255        15259             33             0.3322
# 3256        69630             33             0.3321
# 3257        80510             33             0.3311
# 3258       107509             33             0.3301
#
#                                                Keywords  \
# 3159  bruins, pac, trojans, los, sun_devils, photo, ...
# 3160  bruins, pac, trojans, los, sun_devils, photo, ...
# 3161  bruins, pac, trojans, los, sun_devils, photo, ...
# 3162  bruins, pac, trojans, los, sun_devils, photo, ...
# 3163  bruins, pac, trojans, los, sun_devils, photo, ...
# ...                                                 ...
# 3254  bruins, pac, trojans, los, sun_devils, photo, ...
# 3255  bruins, pac, trojans, los, sun_devils, photo, ...
# 3256  bruins, pac, trojans, los, sun_devils, photo, ...
# 3257  bruins, pac, trojans, los, sun_devils, photo, ...
# 3258  bruins, pac, trojans, los, sun_devils, photo, ...
#
#                                                    Text
# 3159  [caption, march_madness, road, st_louis, ncaa_...
# 3160  [defeated, ncaa, college_football, los, memori...
# 3161  [caption, text, illustration, caption, photo, ...
# 3162  [versus, ncaa_tournament, time, printing, edit...
# 3163  [caption, text, illustration, caption, photo, ...
# ...                                                 ...
# 3254  [urgency, word, day, play, saturday, maples, p...
# 3255  [tempe, ariz, ned, wulk, led, ncaa_basketball_...
# 3256  [caption, text, illustration, caption, history...
# 3257  [guard, lazeric, jones, likes, environment, mc...
# 3258  [p.m, beasley, coliseum, pullman, wash, tv, pa...
#
# [100 rows x 5 columns]
# --- Topic 34 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3259        96115             34             0.7714
# 3260         7937             34             0.7554
# 3261        98758             34             0.7524
# 3262         6504             34             0.7449
# 3263       108686             34             0.7402
# ...           ...            ...                ...
# 3354       116609             34              0.594
# 3355        49554             34             0.5926
# 3356       108656             34             0.5921
# 3357       102057             34             0.5919
# 3358       115871             34             0.5909
#
#                                                Keywords  \
# 3259  trump, president, people, sports_betting, gamb...
# 3260  trump, president, people, sports_betting, gamb...
# 3261  trump, president, people, sports_betting, gamb...
# 3262  trump, president, people, sports_betting, gamb...
# 3263  trump, president, people, sports_betting, gamb...
# ...                                                 ...
# 3354  trump, president, people, sports_betting, gamb...
# 3355  trump, president, people, sports_betting, gamb...
# 3356  trump, president, people, sports_betting, gamb...
# 3357  trump, president, people, sports_betting, gamb...
# 3358  trump, president, people, sports_betting, gamb...
#
#                                                    Text
# 3259  [legislature, gov, christie, bill, thursday, r...
# 3260  [sacramento, senate, voted, thursday, ban, sal...
# 3261  [federal, appeals, court, revived, quest, lega...
# 3262  [tony, batt, stephens, bureau, resurrection, b...
# 3263  [day, legal, quest, evade, federal, law, barri...
# ...                                                 ...
# 3354  [supreme_court, ruled, monday, purge, voter, r...
# 3355  [tony, batt, stephens, bureau, sen, mccain, ap...
# 3356  [american, democracy, comic, opera, frequently...
# 3357  [ebola, vaccines, safe, trial, experimental, e...
# 3358  [supreme_court, monday, overturned, federal, b...
#
# [100 rows x 5 columns]

# %%
# Define the path to save the Excel file in your Google Drive
excel_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_35_topics.xlsx'

# Save the DataFrame to an Excel file
try:
    top_100_documents_per_topic.to_excel(excel_file_path, index=False)
    print(f"Successfully saved the top 100 documents per topic to: {excel_file_path}")
except Exception as e:
    print(f"An error occurred while saving the Excel file: {e}")
# Out:
# Successfully saved the top 100 documents per topic to: /content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_35_topics.xlsx

# %% [markdown]
# ##### **© 2024–2025 MD Rafsun Sheikh**
# ##### **Licensed under the Apache License, Version 2.0.**
