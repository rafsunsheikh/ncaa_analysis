# %%
# %pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.9 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 45.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 47.4 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 9.5 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gensim.models.ldamodel import LdaModel

# Load the LDA model
loaded_lda_model = LdaModel.load('/content/drive/MyDrive/Colab Notebooks/alex/models/lda_15_topics/lda_model_15_topics.gensim')

# Now you can access information from the loaded model.
# For example, you can print the topics:
print("Topics:")
for topic_id, topic in loaded_lda_model.print_topics():
    print(f"Topic {topic_id}: {topic}")

# You can also access the dictionary (id2word)
print("\nDictionary:")
print(loaded_lda_model.id2word)

# And the number of topics
print("\nNumber of topics:")
print(loaded_lda_model.num_topics)
# Out:
# Topics:
# Topic 0: 0.040*"state" + 0.018*"game" + 0.018*"michigan" + 0.017*"big" + 0.016*"texas" + 0.014*"college" + 0.014*"team" + 0.014*"season" + 0.013*"florida" + 0.013*"alabama"
# Topic 1: 0.023*"school" + 0.018*"year" + 0.017*"team" + 0.016*"coach" + 0.015*"high" + 0.014*"season" + 0.014*"college" + 0.013*"player" + 0.012*"woman" + 0.011*"basketball"
# Topic 2: 0.032*"gopher" + 0.024*"hockey" + 0.023*"goal" + 0.021*"minnesota" + 0.021*"game" + 0.013*"team" + 0.012*"season" + 0.009*"first" + 0.009*"boston" + 0.008*"four"
# Topic 3: 0.013*"sport" + 0.007*"game" + 0.007*"fan" + 0.006*"basketball" + 0.006*"new" + 0.005*"one" + 0.005*"nil" + 0.005*"people" + 0.004*"time" + 0.004*"day"
# Topic 4: 0.015*"said" + 0.014*"ncaa" + 0.014*"sport" + 0.014*"college" + 0.013*"school" + 0.012*"athlete" + 0.008*"state" + 0.008*"university" + 0.008*"football" + 0.007*"would"
# Topic 5: 0.023*"woman" + 0.016*"u" + 0.015*"championship" + 0.013*"world" + 0.011*"olympic" + 0.011*"first" + 0.011*"2023" + 0.008*"united" + 0.008*"title" + 0.007*"champion"
# Topic 6: 0.026*"game" + 0.026*"point" + 0.013*"second" + 0.012*"first" + 0.011*"shot" + 0.009*"guard" + 0.009*"half" + 0.008*"minute" + 0.008*"lead" + 0.008*"rebound"
# Topic 7: 0.029*"baseball" + 0.019*"game" + 0.018*"run" + 0.017*"ppg" + 0.016*"series" + 0.016*"inning" + 0.016*"softball" + 0.016*"2024" + 0.014*"g" + 0.013*"hit"
# Topic 8: 0.063*"ucla" + 0.052*"arizona" + 0.046*"usc" + 0.031*"pac12" + 0.029*"bruin" + 0.022*"state" + 0.021*"asu" + 0.019*"oregon" + 0.017*"trojan" + 0.015*"california"
# Topic 9: 0.035*"football" + 0.026*"quarterback" + 0.023*"yard" + 0.021*"nfl" + 0.016*"game" + 0.015*"touchdown" + 0.012*"season" + 0.011*"back" + 0.010*"defensive" + 0.010*"offensive"
# Topic 10: 0.029*"said" + 0.012*"like" + 0.010*"year" + 0.010*"player" + 0.010*"coach" + 0.010*"going" + 0.010*"would" + 0.010*"team" + 0.010*"get" + 0.010*"one"
# Topic 11: 0.056*"v" + 0.049*"pm" + 0.027*"game" + 0.026*"state" + 0.025*"1" + 0.024*"march" + 0.023*"2" + 0.020*"3" + 0.018*"4" + 0.017*"espn"
# Topic 12: 0.021*"season" + 0.017*"draft" + 0.016*"player" + 0.015*"nba" + 0.011*"pick" + 0.010*"coach" + 0.010*"basketball" + 0.010*"league" + 0.010*"team" + 0.009*"year"
# Topic 13: 0.031*"point" + 0.017*"state" + 0.012*"iowa" + 0.010*"scored" + 0.008*"12" + 0.007*"win" + 0.007*"first" + 0.007*"16" + 0.007*"10" + 0.007*"second"
# Topic 14: 0.041*"tournament" + 0.024*"team" + 0.019*"ncaa" + 0.017*"basketball" + 0.017*"four" + 0.016*"game" + 0.015*"seed" + 0.014*"carolina" + 0.014*"final" + 0.013*"championship"
#
# Dictionary:
# Dictionary<416121 unique tokens: ['11', '14', '18', '20', '2001']...>
#
# Number of topics:
# 15

# %%
from gensim import corpora

# Load the corpus from the .mm file
corpus = corpora.MmCorpus('/content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/corpus.mm')

print("Corpus loaded successfully.")
# You can optionally print the corpus to inspect its structure
# print(list(corpus))
# Out:
# Corpus loaded successfully.

# %%
import pandas as pd

# Load the tokenized data from the Excel file
try:
    tokenized_data_df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/alex/updated_ tokenized_newspaper_data.xlsx')
    print("Excel file loaded successfully.")
    # Assuming the original text is in a column named 'text' or similar.
    # Please adjust the column name if it's different in your Excel file.
    if 'Main_text_tokenized' in tokenized_data_df.columns:
        texts = tokenized_data_df['Main_text_tokenized'].tolist()
        print(f"Extracted {len(texts)} documents.")
    else:
        texts = None
        print("Could not find a 'text' column in the Excel file. Please make sure the column containing original texts is named 'text' or update the code.")

except FileNotFoundError:
    print("Error: The file was not found at the specified path.")
except Exception as e:
    print(f"An error occurred while reading the Excel file: {e}")
# Out:
# Excel file loaded successfully.
# Extracted 149703 documents.

# %%
#TFinding the dominant topic in each sentence

def format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts): # Updated to use loaded_lda_model and corpus, and texts=None
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = pd.concat([sent_topics_df, pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]).to_frame().T], ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

     # Add original text to the end of the output
    if texts is not None: # Added check if texts is not None
        contents = pd.Series(texts)
        sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


# Assuming texts is available as data_words or you provide another list/Series of texts
# df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts) # Updated to use loaded_lda_model and corpus, commented out as data_words is undefined
# To run this cell, define `data_words` with your text data before calling the function.
# For example:
# data_words = ["your document text 1", "your document text 2", ...]
# Then uncomment the line below:
df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts)

# Format
if 'df_topic_sents_keywords' in locals(): # Added check if df_topic_sents_keywords is defined
    df_dominant_topic = df_topic_sents_keywords.reset_index()
    df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
    # Show
    display(df_dominant_topic.head(20)) # Use display for better formatting
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0             10             0.4354
# 1             1             10             0.2624
# 2             2             10             0.3697
# 3             3             10             0.3112
# 4             4             12             0.3408
# 5             5              7             0.3633
# 6             6             12             0.5554
# 7             7             12              0.487
# 8             8             10             0.3186
# 9             9             10             0.3069
# 10           10             10             0.2585
# 11           11              5             0.3045
# 12           12             10             0.3472
# 13           13             10             0.3931
# 14           14             10             0.4937
# 15           15              4              0.543
# 16           16              7             0.2254
# 17           17              4             0.7283
# 18           18             12             0.4729
# 19           19              0             0.3106
#
#                                              Keywords  \
# 0   said, like, year, player, coach, going, would,...
# 1   said, like, year, player, coach, going, would,...
# 2   said, like, year, player, coach, going, would,...
# 3   said, like, year, player, coach, going, would,...
# 4   season, draft, player, nba, pick, coach, baske...
# 5   baseball, game, run, ppg, series, inning, soft...
# 6   season, draft, player, nba, pick, coach, baske...
# 7   season, draft, player, nba, pick, coach, baske...
# 8   said, like, year, player, coach, going, would,...
# 9   said, like, year, player, coach, going, would,...
# 10  said, like, year, player, coach, going, would,...
# 11  woman, u, championship, world, olympic, first,...
# 12  said, like, year, player, coach, going, would,...
# 13  said, like, year, player, coach, going, would,...
# 14  said, like, year, player, coach, going, would,...
# 15  said, ncaa, sport, college, school, athlete, s...
# 16  baseball, game, run, ppg, series, inning, soft...
# 17  said, ncaa, sport, college, school, athlete, s...
# 18  season, draft, player, nba, pick, coach, baske...
# 19  state, game, michigan, big, texas, college, te...
#
#                                                  Text
# 0   ['14', 'year', 'coaching', '39', 'year', 'livi...
# 1   ['see', 'sidebar', '02c', 'ruston', 'la', 'din...
# 2   ['gave', 'garden', 'exactly', 'missed', 'lonel...
# 3   ['indianapolis', 'ten', 'year', 'ago', 'chuck'...
# 4   ['robinson', 'talk', 'ranger', 'stanley', 'cup...
# 5   ['usc', 'conference', 'pacific10', 'coach', 'm...
# 6   ['ranger', 'signed', 'center', 'michael', 'nyl...
# 7   ['gavitt', 'five', 'others', 'elected', 'hall'...
# 8   ['almost', 'mythical', 'element', 'lsu', 'seni...
# 9   ['ncaa', 'woman', 'jim', 'izard', 'diana', 'vi...
# 10  ['meet', 'george', 'mason', 'guard', 'lamar', ...
# 11  ['kevin', 'iole', 'reviewjournal', 'local', 'g...
# 12  ['seventh', 'time', 'coach', 'john', 'beilein'...
# 13  ['demetrius', 'jones', 'clear', 'want', 'talk'...
# 14  ['oakland', 'eating', 'gilbert', 'arena', 'go'...
# 15  ['nothing', 'bothered', 'myles', 'brand', 'ter...
# 16  ['yes', 'lot', 'secondguessing', 'season', 're...
# 17  ['state', 'college', 'pa', 'ncaa', 'sent', 'pe...
# 18  ['first', 'person', 'called', 'got', 'call', '...
# 19  ['selection', 'sunday', 'month', 'away', 'ncaa...

# %%
# Display the first few rows of the dataframe to see the structure
display(df_dominant_topic.head())
# Out:
#    Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0            0             10             0.4354
# 1            1             10             0.2624
# 2            2             10             0.3697
# 3            3             10             0.3112
# 4            4             12             0.3408
#
#                                             Keywords  \
# 0  said, like, year, player, coach, going, would,...
# 1  said, like, year, player, coach, going, would,...
# 2  said, like, year, player, coach, going, would,...
# 3  said, like, year, player, coach, going, would,...
# 4  season, draft, player, nba, pick, coach, baske...
#
#                                                 Text
# 0  ['14', 'year', 'coaching', '39', 'year', 'livi...
# 1  ['see', 'sidebar', '02c', 'ruston', 'la', 'din...
# 2  ['gave', 'garden', 'exactly', 'missed', 'lonel...
# 3  ['indianapolis', 'ten', 'year', 'ago', 'chuck'...
# 4  ['robinson', 'talk', 'ranger', 'stanley', 'cup...

# %%
# Sort documents within each topic by percentage contribution in descending order
sorted_documents_by_topic = df_dominant_topic.sort_values(by=['Dominant_Topic', 'Topic_Perc_Contrib'], ascending=[True, False])

# Display the sorted document indexes for each topic
print("Document Indexes for Each Topic (Sorted by Percentage Contribution):")
for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    print(f"\nTopic {topic_num}:")
    # Get documents for the current topic and select only the 'Document_No' column
    topic_documents = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num]['Document_No']
    # Display the document indexes (first 20 as an example)
    print(topic_documents.tolist()[:20])
# Out:
# Document Indexes for Each Topic (Sorted by Percentage Contribution):
#
# Topic 0:
# [144042, 14464, 138838, 144043, 143977, 123595, 123346, 124951, 5019, 141418, 115297, 132891, 123345, 115294, 138375, 140980, 123347, 140979, 125074, 127493]
#
# Topic 1:
# [3163, 66229, 64700, 3155, 70296, 71089, 17560, 83855, 34546, 105769, 6914, 68576, 76467, 2919, 23432, 51516, 57636, 136344, 45644, 49396]
#
# Topic 2:
# [5037, 137523, 22572, 21692, 2563, 14607, 12479, 4732, 5021, 95156, 83747, 24103, 137533, 142444, 99549, 121170, 137336, 138598, 137455, 129260]
#
# Topic 3:
# [38825, 144759, 60071, 24353, 24572, 49210, 122316, 147347, 127351, 65611, 139919, 72564, 80583, 72954, 129930, 64275, 19278, 137576, 110460, 45590]
#
# Topic 4:
# [69832, 70792, 14390, 32177, 124934, 146373, 127699, 132924, 70785, 112461, 1145, 138582, 148124, 148125, 105593, 143165, 143166, 92629, 24195, 43289]
#
# Topic 5:
# [60336, 21267, 60341, 24696, 31532, 24580, 13955, 27528, 105809, 54726, 144713, 37076, 103299, 19378, 53263, 122244, 12611, 74149, 96539, 30766]
#
# Topic 6:
# [128482, 47008, 5163, 15535, 128346, 15696, 15613, 99817, 7710, 40130, 9057, 4586, 52272, 4343, 33171, 13637, 4584, 17401, 25570, 43989]
#
# Topic 7:
# [113209, 10998, 71749, 38991, 118329, 49902, 89966, 36431, 70273, 44029, 71738, 18905, 10897, 83659, 77312, 70274, 68883, 24455, 78917, 88178]
#
# Topic 8:
# [9233, 38552, 9231, 36523, 107816, 117052, 102302, 87411, 112514, 28722, 44395, 116889, 111551, 175, 117060, 96608, 77146, 112602, 9232, 111217]
#
# Topic 9:
# [42381, 79168, 9913, 36378, 26917, 9390, 594, 21289, 33712, 103212, 97940, 112997, 25533, 130450, 15936, 42385, 17671, 63912, 26776, 45730]
#
# Topic 10:
# [54020, 108566, 35053, 72610, 118762, 72615, 25683, 48329, 116815, 122409, 63011, 101127, 125658, 131993, 86617, 66111, 108375, 144022, 91829, 144186]
#
# Topic 11:
# [1491, 47116, 143634, 98879, 98880, 98883, 102884, 71743, 71952, 37378, 73223, 146013, 110990, 105959, 148114, 135962, 143630, 115375, 28806, 145104]
#
# Topic 12:
# [90124, 126620, 90733, 5502, 97330, 4854, 53672, 38222, 93731, 1240, 29820, 60432, 58262, 71146, 54318, 9932, 120520, 25909, 14745, 29185]
#
# Topic 13:
# [83806, 19155, 94889, 45451, 44483, 149104, 19720, 39933, 134057, 70880, 83712, 149105, 36781, 77225, 86572, 122384, 122385, 64107, 114812, 133792]
#
# Topic 14:
# [58040, 59112, 10637, 71163, 9378, 77879, 52877, 43254, 80229, 83896, 57245, 75854, 35477, 50102, 50103, 50105, 50106, 50107, 50108, 57241]

# %%
# Get the total number of documents for each dominant topic
topic_counts = df_dominant_topic['Dominant_Topic'].value_counts().sort_index()

print("Total number of documents for each topic:")
display(topic_counts)
# Out:
# Total number of documents for each topic:
# Dominant_Topic
# 0      5590
# 1     10649
# 2      3966
# 3     12109
# 4     15375
# 5      9731
# 6     18873
# 7      2370
# 8      1121
# 9      3337
# 10    38967
# 11     1910
# 12     8732
# 13     6202
# 14    11287
# Name: count, dtype: int64

# %%
# Get the top 100 documents for each topic
top_100_documents_per_topic = pd.DataFrame()

for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    # Get the top 100 documents for the current topic
    top_100 = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num].head(100)
    # Append to the results DataFrame
    top_100_documents_per_topic = pd.concat([top_100_documents_per_topic, top_100], ignore_index=True)

# Display the top 100 documents for each topic
print("Top 100 Documents for Each Topic (Sorted by Percentage Contribution):")

# Iterate through topics and display the top documents for each
for topic_num in top_100_documents_per_topic['Dominant_Topic'].unique():
    print(f"\n--- Topic {topic_num} ---")
    display(top_100_documents_per_topic[top_100_documents_per_topic['Dominant_Topic'] == topic_num])
# Out:
# Top 100 Documents for Each Topic (Sorted by Percentage Contribution):
#
# --- Topic 0 ---
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0        144042              0             0.9402
# 1         14464              0             0.9378
# 2        138838              0             0.9326
# 3        144043              0             0.9272
# 4        143977              0             0.8961
# ..          ...            ...                ...
# 95       133818              0             0.7872
# 96       141752              0             0.7868
# 97       135037              0             0.7842
# 98       132670              0             0.7841
# 99       139112              0             0.7837
#
#                                              Keywords  \
# 0   state, game, michigan, big, texas, college, te...
# 1   state, game, michigan, big, texas, college, te...
# 2   state, game, michigan, big, texas, college, te...
# 3   state, game, michigan, big, texas, college, te...
# 4   state, game, michigan, big, texas, college, te...
# ..                                                ...
# 95  state, game, michigan, big, texas, college, te...
# 96  state, game, michigan, big, texas, college, te...
# 97  state, game, michigan, big, texas, college, te...
# 98  state, game, michigan, big, texas, college, te...
# 99  state, game, michigan, big, texas, college, te...
#
#                                                  Text
# 0   ['vaccination', 'reprinted', 'new', 'york', 't...
# 1   ['one', 'thing', 'sure', 'day', 'beach', 'wedn...
# 2   ['columbia', 'sc', 'south', 'carolina', 'quart...
# 3   ['chicago', 'red', 'star', 'bringing', 'new', ...
# 4   ['ncaa', 'baseball', 'tournament', 'remain', '...
# ..                                                ...
# 95  ['tableau', 'riot', 'police', 'screaming', 'cr...
# 96  ['head', 'coach', 'deion', 'sander', 'making',...
# 97  ['spring', 'day', 'lia', 'thomas', 'made', 'hi...
# 98  ['newark', 'inevitable', 'first', 'time', 'jim...
# 99  ['new', 'york', 'jet', 'agreed', 'deal', 'mond...
#
# [100 rows x 5 columns]
# --- Topic 1 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 100         3163              1             0.9872
# 101        66229              1             0.9767
# 102        64700              1             0.9622
# 103         3155              1              0.941
# 104        70296              1             0.9397
# ..           ...            ...                ...
# 195        20319              1             0.7503
# 196       117925              1             0.7503
# 197        76878              1             0.7489
# 198        98406              1             0.7485
# 199       113812              1             0.7475
#
#                                               Keywords  \
# 100  school, year, team, coach, high, season, colle...
# 101  school, year, team, coach, high, season, colle...
# 102  school, year, team, coach, high, season, colle...
# 103  school, year, team, coach, high, season, colle...
# 104  school, year, team, coach, high, season, colle...
# ..                                                 ...
# 195  school, year, team, coach, high, season, colle...
# 196  school, year, team, coach, high, season, colle...
# 197  school, year, team, coach, high, season, colle...
# 198  school, year, team, coach, high, season, colle...
# 199  school, year, team, coach, high, season, colle...
#
#                                                   Text
# 100  ['wrapped', 'regular', 'season', 'second', 'ma...
# 101  ['pasadena', 'ucla', 'deserves', 'play', 'bowl...
# 102  ['one', 'day', 'nick', 'pita', 'return', 'wind...
# 103  ['college', 'roundup', 'sophomore', 'jeff', 'h...
# 104  ['next', 'month', 'highcaliber', 'underclassma...
# ..                                                 ...
# 195  ['start', 'march', 'madness', 'always', 'bring...
# 196  ['spark', 'sawdust', 'norm', 'marketing', 'fir...
# 197  ['everybody', 'watching', 'louisville', 'put',...
# 198  ['one', 'moment', 'ucla', 'basketball', 'team'...
# 199  ['maryland', '68', 'wisconsin', '63', 'marylan...
#
# [100 rows x 5 columns]
# --- Topic 2 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 200         5037              2             0.8826
# 201       137523              2             0.8601
# 202        22572              2             0.8541
# 203        21692              2             0.8537
# 204         2563              2             0.8373
# ..           ...            ...                ...
# 295        79793              2             0.6711
# 296       147229              2             0.6705
# 297        74778              2             0.6703
# 298       134030              2             0.6683
# 299       136623              2             0.6683
#
#                                               Keywords  \
# 200  gopher, hockey, goal, minnesota, game, team, s...
# 201  gopher, hockey, goal, minnesota, game, team, s...
# 202  gopher, hockey, goal, minnesota, game, team, s...
# 203  gopher, hockey, goal, minnesota, game, team, s...
# 204  gopher, hockey, goal, minnesota, game, team, s...
# ..                                                 ...
# 295  gopher, hockey, goal, minnesota, game, team, s...
# 296  gopher, hockey, goal, minnesota, game, team, s...
# 297  gopher, hockey, goal, minnesota, game, team, s...
# 298  gopher, hockey, goal, minnesota, game, team, s...
# 299  gopher, hockey, goal, minnesota, game, team, s...
#
#                                                   Text
# 200  ['rsec', 'ron', 'mason', 'expect', 'emotion', ...
# 201  ['plenty', 'discussion', 'heading', 'men', 'co...
# 202  ['coach', 'mike', 'tice', 'seldom', 'brings', ...
# 203  ['college', 'opening', 'ceremony', 'wednesday'...
# 204  ['st', 'paul', '7', 'inch', 'snow', 'ground', ...
# ..                                                 ...
# 295  ['opposition', 'sport', 'gambling', 'ncaa', 'c...
# 296  ['iowa', 'dismissed', 'men', 'basketball', 'co...
# 297  ['frank', 'busch', 'completing', '22year', 'ca...
# 298  ['book', 'rick', 'pitino', 'sought', 'suppress...
# 299  ['bob', 'chesney', 'steady', 'climb', 'college...
#
# [100 rows x 5 columns]
# --- Topic 3 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 300        38825              3             0.9761
# 301       144759              3             0.9238
# 302        60071              3             0.8855
# 303        24353              3             0.8829
# 304        24572              3             0.8829
# ..           ...            ...                ...
# 395        54104              3             0.7803
# 396       118271              3             0.7796
# 397        52090              3             0.7794
# 398        32248              3             0.7788
# 399       139037              3             0.7784
#
#                                               Keywords  \
# 300  sport, game, fan, basketball, new, one, nil, p...
# 301  sport, game, fan, basketball, new, one, nil, p...
# 302  sport, game, fan, basketball, new, one, nil, p...
# 303  sport, game, fan, basketball, new, one, nil, p...
# 304  sport, game, fan, basketball, new, one, nil, p...
# ..                                                 ...
# 395  sport, game, fan, basketball, new, one, nil, p...
# 396  sport, game, fan, basketball, new, one, nil, p...
# 397  sport, game, fan, basketball, new, one, nil, p...
# 398  sport, game, fan, basketball, new, one, nil, p...
# 399  sport, game, fan, basketball, new, one, nil, p...
#
#                                                   Text
# 300  ['quote', 'grew', 'brooklyn', 'race', 'never',...
# 301  ['nil', 'revolution', 'occasional', 'series', ...
# 302  ['track', 'field', 'angela', 'williams', 'bega...
# 303  ['would', 'tempting', 'label', 'upstart', 'xav...
# 304  ['muttered', 'mantra', 'long', 'ride', 'minnes...
# ..                                                 ...
# 395  ['pat', 'summitt', 'care', 'crowd', 'mostly', ...
# 396  ['christian', 'coleman', 'united', 'state', 'w...
# 397  ['april', '29', '1901', 'eminence', 'ridden', ...
# 398  ['college', 'football', 'week', 'dream', 'vict...
# 399  ['top', 'college', 'basketball', 'world', 'def...
#
# [100 rows x 5 columns]
# --- Topic 4 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 400        69832              4             0.9929
# 401        70792              4             0.9923
# 402        14390              4             0.9885
# 403        32177              4             0.9772
# 404       124934              4             0.9665
# ..           ...            ...                ...
# 495       126437              4             0.9067
# 496       128067              4             0.9065
# 497       147354              4             0.9058
# 498        11046              4             0.9054
# 499       143024              4             0.9052
#
#                                               Keywords  \
# 400  said, ncaa, sport, college, school, athlete, s...
# 401  said, ncaa, sport, college, school, athlete, s...
# 402  said, ncaa, sport, college, school, athlete, s...
# 403  said, ncaa, sport, college, school, athlete, s...
# 404  said, ncaa, sport, college, school, athlete, s...
# ..                                                 ...
# 495  said, ncaa, sport, college, school, athlete, s...
# 496  said, ncaa, sport, college, school, athlete, s...
# 497  said, ncaa, sport, college, school, athlete, s...
# 498  said, ncaa, sport, college, school, athlete, s...
# 499  said, ncaa, sport, college, school, athlete, s...
#
#                                                   Text
# 400  ['note', 'sounding', 'contact', 'medium', 'col...
# 401  ['peace', 'new', 'prosperity', 'college', 'men...
# 402  ['notre', 'dame', 'ncaa', 'notified', 'notre',...
# 403  ['special', 'section', 'ncaa', 'tournament', '...
# 404  ['moment', 'ncaa', 'acknowledged', 'choice', '...
# ..                                                 ...
# 495  ['orlando', 'tiger', 'wood', 'decided', 'play'...
# 496  ['pro', 'basketball', 'buck', 'hire', 'byingto...
# 497  ['regular', 'season', 'started', 'dodger', 'be...
# 498  ['nik', 'canermedley', 'thought', 'understood'...
# 499  ['lynx', 'got', 'lot', 'talented', 'offense', ...
#
# [100 rows x 5 columns]
# --- Topic 5 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 500        60336              5             0.9481
# 501        21267              5             0.9334
# 502        60341              5              0.887
# 503        24696              5             0.8858
# 504        31532              5             0.8822
# ..           ...            ...                ...
# 595       105567              5             0.7594
# 596        23237              5             0.7586
# 597        58949              5             0.7582
# 598        15065              5              0.758
# 599        26841              5             0.7577
#
#                                               Keywords  \
# 500  woman, u, championship, world, olympic, first,...
# 501  woman, u, championship, world, olympic, first,...
# 502  woman, u, championship, world, olympic, first,...
# 503  woman, u, championship, world, olympic, first,...
# 504  woman, u, championship, world, olympic, first,...
# ..                                                 ...
# 595  woman, u, championship, world, olympic, first,...
# 596  woman, u, championship, world, olympic, first,...
# 597  woman, u, championship, world, olympic, first,...
# 598  woman, u, championship, world, olympic, first,...
# 599  woman, u, championship, world, olympic, first,...
#
#                                                   Text
# 500  ['unlv', 'football', 'team', 'lost', 'scholars...
# 501  ['football', 'weekend', 'week', 'usa', 'today'...
# 502  ['today', 'first', 'day', 'ncaa', 'winter', 's...
# 503  ['frozen', 'four', '2004', 'ncaa', 'men', 'hoc...
# 504  ['jones', 'say', 'head', 'coaching', 'job', 'c...
# ..                                                 ...
# 595  ['figuring', '10', 'seed', 'going', 'win', 'na...
# 596  ['john', 'lucas', 'iii', 'shopping', 'school',...
# 597  ['moment', 'team', 'fifth', 'victory', 'season...
# 598  ['bjarne', 'solbakken', 'norway', 'sunday', 'e...
# 599  ['globe', 'south', '1', 'sport', 'brockton', '...
#
# [100 rows x 5 columns]
# --- Topic 6 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 600       128482              6             0.8901
# 601        47008              6             0.8872
# 602         5163              6             0.8755
# 603        15535              6             0.8734
# 604       128346              6             0.8664
# ..           ...            ...                ...
# 695        51916              6             0.7733
# 696        13804              6             0.7729
# 697       118107              6             0.7729
# 698       113043              6             0.7725
# 699       104648              6             0.7722
#
#                                               Keywords  \
# 600  game, point, second, first, shot, guard, half,...
# 601  game, point, second, first, shot, guard, half,...
# 602  game, point, second, first, shot, guard, half,...
# 603  game, point, second, first, shot, guard, half,...
# 604  game, point, second, first, shot, guard, half,...
# ..                                                 ...
# 695  game, point, second, first, shot, guard, half,...
# 696  game, point, second, first, shot, guard, half,...
# 697  game, point, second, first, shot, guard, half,...
# 698  game, point, second, first, shot, guard, half,...
# 699  game, point, second, first, shot, guard, half,...
#
#                                                   Text
# 600  ['tanner', 'morgan', 'final', 'two', 'snap', '...
# 601  ['la', 'vega', 'former', 'ucla', 'quarterback'...
# 602  ['sacramento', 'north', 'carolina', 'wilmingto...
# 603  ['david', 'kimani', '25', 'sixtime', 'ncaa', '...
# 604  ['telling', 'part', 'midseason', 'upheaval', '...
# ..                                                 ...
# 695  ['texas', 'high', 'school', 'athlete', 'warned...
# 696  ['bob', 'knight', 'told', 'texas', 'tech', 'wo...
# 697  ['cal', 'state', 'northridge', 'forward', 'jar...
# 698  ['percy', 'speights', 'ready', 'battle', 'knee...
# 699  ['late', 'december', 'texas', 'tech', 'capped'...
#
# [100 rows x 5 columns]
# --- Topic 7 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 700       113209              7             0.6994
# 701        10998              7             0.6808
# 702        71749              7             0.6718
# 703        38991              7             0.6581
# 704       118329              7             0.6446
# ..           ...            ...                ...
# 795       135241              7             0.5138
# 796        16623              7             0.5136
# 797        29137              7              0.512
# 798        10135              7             0.5118
# 799       100131              7             0.5118
#
#                                               Keywords  \
# 700  baseball, game, run, ppg, series, inning, soft...
# 701  baseball, game, run, ppg, series, inning, soft...
# 702  baseball, game, run, ppg, series, inning, soft...
# 703  baseball, game, run, ppg, series, inning, soft...
# 704  baseball, game, run, ppg, series, inning, soft...
# ..                                                 ...
# 795  baseball, game, run, ppg, series, inning, soft...
# 796  baseball, game, run, ppg, series, inning, soft...
# 797  baseball, game, run, ppg, series, inning, soft...
# 798  baseball, game, run, ppg, series, inning, soft...
# 799  baseball, game, run, ppg, series, inning, soft...
#
#                                                   Text
# 700  ['sean', 'miller', 'came', 'fighting', 'thursd...
# 701  ['cal', 'state', 'northridge', 'left', 'big', ...
# 702  ['day', 'traded', 'away', 'nearly', 'every', '...
# 703  ['give', 'dan', 'monson', 'credit', 'realistic...
# 704  ['response', 'joining', 'taylor', 'redskin', '...
# ..                                                 ...
# 795  ['november', 'especially', 'kind', 'four', 'wo...
# 796  ['sport', 'monday', 'national', '2003', 'ncaa'...
# 797  ['bull', 'v', 'wizard', 'bull', 'lead', 'serie...
# 798  ['atlantic', 'coast', 'conference', 'official'...
# 799  ['stony', 'brook', 'men', 'lacrosse', 'team', ...
#
# [100 rows x 5 columns]
# --- Topic 8 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 800         9233              8             0.9059
# 801        38552              8             0.6948
# 802         9231              8             0.6228
# 803        36523              8             0.6194
# 804       107816              8             0.6173
# ..           ...            ...                ...
# 895       102319              8             0.4348
# 896       117656              8             0.4346
# 897        74432              8             0.4345
# 898       113216              8             0.4343
# 899        72812              8              0.434
#
#                                               Keywords  \
# 800  ucla, arizona, usc, pac12, bruin, state, asu, ...
# 801  ucla, arizona, usc, pac12, bruin, state, asu, ...
# 802  ucla, arizona, usc, pac12, bruin, state, asu, ...
# 803  ucla, arizona, usc, pac12, bruin, state, asu, ...
# 804  ucla, arizona, usc, pac12, bruin, state, asu, ...
# ..                                                 ...
# 895  ucla, arizona, usc, pac12, bruin, state, asu, ...
# 896  ucla, arizona, usc, pac12, bruin, state, asu, ...
# 897  ucla, arizona, usc, pac12, bruin, state, asu, ...
# 898  ucla, arizona, usc, pac12, bruin, state, asu, ...
# 899  ucla, arizona, usc, pac12, bruin, state, asu, ...
#
#                                                   Text
# 800  ['ncaa', 'tournament', '2', '1', '2', 'decade'...
# 801  ['chris', 'kenny', 'drove', 'length', 'court',...
# 802  ['fifty', 'year', 'ago', 'month', 'tiniest', '...
# 803  ['win', 'ranked', 'team', 'becoming', 'routine...
# 804  ['venable', 'palestra', 'one', 'memorable', 'n...
# ..                                                 ...
# 895  ['tumultuous', 'basketball', 'season', 'usc', ...
# 896  ['terrapin', 'closeknit', 'freshman', 'embody'...
# 897  ['two', 'season', 'usc', 'tailback', 'dillon',...
# 898  ['back', 'villanova', 'coach', 'harry', 'perre...
# 899  ['nick', 'baumgardner', 'daily', 'news', 'nbau...
#
# [100 rows x 5 columns]
# --- Topic 9 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 900        42381              9             0.7747
# 901        79168              9             0.6883
# 902         9913              9             0.6874
# 903        36378              9             0.6779
# 904        26917              9             0.6568
# ..           ...            ...                ...
# 995        52629              9             0.5102
# 996        95308              9             0.5102
# 997         2970              9             0.5101
# 998        46538              9             0.5101
# 999        51373              9             0.5096
#
#                                               Keywords  \
# 900  football, quarterback, yard, nfl, game, touchd...
# 901  football, quarterback, yard, nfl, game, touchd...
# 902  football, quarterback, yard, nfl, game, touchd...
# 903  football, quarterback, yard, nfl, game, touchd...
# 904  football, quarterback, yard, nfl, game, touchd...
# ..                                                 ...
# 995  football, quarterback, yard, nfl, game, touchd...
# 996  football, quarterback, yard, nfl, game, touchd...
# 997  football, quarterback, yard, nfl, game, touchd...
# 998  football, quarterback, yard, nfl, game, touchd...
# 999  football, quarterback, yard, nfl, game, touchd...
#
#                                                   Text
# 900  ['ncaa', 'title', 'game', '95yearold', 'coachi...
# 901  ['cbs', 'connecticutbutler', 'ncaa', 'men', 'b...
# 902  ['many', 'best', 'sport', 'television', 'idea'...
# 903  ['sport', 'usc', 'woman', 'soccer', 'team', '1...
# 904  ['day', 'early', 'february', 'depaul', 'beat',...
# ..                                                 ...
# 995  ['buckeye', 'back', 'louisiana', 'state', 'tig...
# 996  ['one', 'could', 'call', 'first', 'meeting', '...
# 997  ['conor', 'gill', 'hand', 'first', '10', 'virg...
# 998  ['kevin', 'buisman', 'know', 'feel', 'walk', '...
# 999  ['flip', 'saunders', 'assistant', 'gopher', 'm...
#
# [100 rows x 5 columns]
# --- Topic 10 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1000        54020             10             0.8361
# 1001       108566             10             0.8268
# 1002        35053             10             0.8148
# 1003        72610             10             0.8109
# 1004       118762             10             0.8079
# ...           ...            ...                ...
# 1095        14414             10             0.7191
# 1096       117975             10             0.7191
# 1097        83383             10             0.7187
# 1098        66127             10             0.7185
# 1099        69931             10             0.7185
#
#                                                Keywords  \
# 1000  said, like, year, player, coach, going, would,...
# 1001  said, like, year, player, coach, going, would,...
# 1002  said, like, year, player, coach, going, would,...
# 1003  said, like, year, player, coach, going, would,...
# 1004  said, like, year, player, coach, going, would,...
# ...                                                 ...
# 1095  said, like, year, player, coach, going, would,...
# 1096  said, like, year, player, coach, going, would,...
# 1097  said, like, year, player, coach, going, would,...
# 1098  said, like, year, player, coach, going, would,...
# 1099  said, like, year, player, coach, going, would,...
#
#                                                    Text
# 1000  ['waco', 'texas', 'proved', 'much', 'much', 'l...
# 1001  ['poetry', 'place', 'ended', 'oracle', 'arena'...
# 1002  ['2005', 'player', 'championship', 'bonus', 's...
# 1003  ['america', 'ready', 'forgive', 'tiger', 'wood...
# 1004  ['kent', 'state', 'decision', 'halt', 'woman',...
# ...                                                 ...
# 1095  ['marquette', '275', 'v', 'kansa', '297', 'gam...
# 1096  ['usc', 'coach', 'andy', 'enfield', 'might', '...
# 1097  ['fast', 'filming', 'next', 'weekend', 'teache...
# 1098  ['one', 'day', 'selection', 'sunday', '64team'...
# 1099  ['swag', 'alist', 'actor', 'academy', 'award',...
#
# [100 rows x 5 columns]
# --- Topic 11 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1100         1491             11             0.9562
# 1101        47116             11             0.9552
# 1102       143634             11             0.9498
# 1103        98879             11             0.9385
# 1104        98880             11             0.9385
# ...           ...            ...                ...
# 1195       147918             11             0.7001
# 1196        95024             11             0.6997
# 1197        28728             11             0.6982
# 1198       149842             11             0.6976
# 1199       147920             11             0.6974
#
#                                          Keywords  \
# 1100  v, pm, game, state, 1, march, 2, 3, 4, espn
# 1101  v, pm, game, state, 1, march, 2, 3, 4, espn
# 1102  v, pm, game, state, 1, march, 2, 3, 4, espn
# 1103  v, pm, game, state, 1, march, 2, 3, 4, espn
# 1104  v, pm, game, state, 1, march, 2, 3, 4, espn
# ...                                           ...
# 1195  v, pm, game, state, 1, march, 2, 3, 4, espn
# 1196  v, pm, game, state, 1, march, 2, 3, 4, espn
# 1197  v, pm, game, state, 1, march, 2, 3, 4, espn
# 1198  v, pm, game, state, 1, march, 2, 3, 4, espn
# 1199  v, pm, game, state, 1, march, 2, 3, 4, espn
#
#                                                    Text
# 1100  ['ucla', 'catcher', 'stacey', 'nuveman', 'set'...
# 1101  ['history', 'geography', 'offer', 'indication'...
# 1102  ['c', 'onnor', 'bedard', '19yearold', 'blackha...
# 1103  ['waning', 'moment', 'duke', '6652', 'victory'...
# 1104  ['providence', 'offering', 'stick', 'salute', ...
# ...                                                 ...
# 1195  ['roger', 'rubin', 'rogerrubin', 'newsdaycom',...
# 1196  ['asked', 'follower', 'step', 'college', 'foot...
# 1197  ['allscholatics', 'spring', '2005', 'player', ...
# 1198                                                NaN
# 1199  ['notebook', 'tampa', 'despite', '2000mile', '...
#
# [100 rows x 5 columns]
# --- Topic 12 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1200        90124             12             0.8763
# 1201       126620             12             0.8735
# 1202        90733             12             0.8599
# 1203         5502             12             0.8087
# 1204        97330             12             0.8049
# ...           ...            ...                ...
# 1295       106543             12             0.6825
# 1296         8407             12             0.6818
# 1297       120239             12             0.6818
# 1298       138405             12             0.6793
# 1299        92346             12             0.6763
#
#                                                Keywords  \
# 1200  season, draft, player, nba, pick, coach, baske...
# 1201  season, draft, player, nba, pick, coach, baske...
# 1202  season, draft, player, nba, pick, coach, baske...
# 1203  season, draft, player, nba, pick, coach, baske...
# 1204  season, draft, player, nba, pick, coach, baske...
# ...                                                 ...
# 1295  season, draft, player, nba, pick, coach, baske...
# 1296  season, draft, player, nba, pick, coach, baske...
# 1297  season, draft, player, nba, pick, coach, baske...
# 1298  season, draft, player, nba, pick, coach, baske...
# 1299  season, draft, player, nba, pick, coach, baske...
#
#                                                    Text
# 1200  ['illinois', 'hoped', 'ahmad', 'starks', 'woul...
# 1201  ['southern', 'california', 'quarterback', 'jt'...
# 1202  ['arlington', 'tex', 'arlington', 'tex', 'mich...
# 1203  ['rsec', 'state', 'tournament', 'time', 'seems...
# 1204  ['washington', 'wizard', 'relatively', 'muted'...
# ...                                                 ...
# 1295  ['oregon', 'wide', 'receiver', 'olympic', 'hur...
# 1296  ['long', 'beach', 'state', 'expected', 'select...
# 1297  ['editor', 'note', 'story', 'updated', 'latest...
# 1298  ['ucla', 'come', 'give', 'good', 'try', 'best'...
# 1299  ['michigan', 'basketball', 'team', 'came', 'nc...
#
# [100 rows x 5 columns]
# --- Topic 13 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1300        83806             13             0.9788
# 1301        19155             13             0.9358
# 1302        94889             13             0.9333
# 1303        45451             13             0.9285
# 1304        44483             13             0.9144
# ...           ...            ...                ...
# 1395        13798             13             0.8134
# 1396       147189             13              0.813
# 1397        32033             13             0.8129
# 1398        13797             13              0.812
# 1399        74844             13             0.8109
#
#                                                Keywords  \
# 1300  point, state, iowa, scored, 12, win, first, 16...
# 1301  point, state, iowa, scored, 12, win, first, 16...
# 1302  point, state, iowa, scored, 12, win, first, 16...
# 1303  point, state, iowa, scored, 12, win, first, 16...
# 1304  point, state, iowa, scored, 12, win, first, 16...
# ...                                                 ...
# 1395  point, state, iowa, scored, 12, win, first, 16...
# 1396  point, state, iowa, scored, 12, win, first, 16...
# 1397  point, state, iowa, scored, 12, win, first, 16...
# 1398  point, state, iowa, scored, 12, win, first, 16...
# 1399  point, state, iowa, scored, 12, win, first, 16...
#
#                                                    Text
# 1300  ['state', 'college', 'pa', 'penn', 'state', 'f...
# 1301  ['anaheim', 'took', 'turn', 'assessing', 'poss...
# 1302  ['sweet', '16', 'schedule', 'today', 'game', '...
# 1303  ['freshman', 'casey', 'nogueira', 'goal', 'ass...
# 1304  ['underrated', 'part', 'ncaa', 'tournament', '...
# ...                                                 ...
# 1395  ['sophomore', 'dave', 'kirschner', 'set', 'lyc...
# 1396  ['5', 'florida', 'state', 'softball', 'advance...
# 1397  ['three', 'year', 'ago', 'southern', 'californ...
# 1398  ['iona', 'led', 'richard', 'kiplagat', 'finish...
# 1399  ['caltech', 'men', 'basketball', 'team', 'new'...
#
# [100 rows x 5 columns]
# --- Topic 14 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1400        58040             14             0.9778
# 1401        59112             14             0.9761
# 1402        10637             14             0.9553
# 1403        71163             14             0.9513
# 1404         9378             14             0.9509
# ...           ...            ...                ...
# 1495        24477             14             0.7803
# 1496        99928             14               0.78
# 1497        81414             14             0.7792
# 1498        31986             14             0.7789
# 1499        56603             14             0.7745
#
#                                                Keywords  \
# 1400  tournament, team, ncaa, basketball, four, game...
# 1401  tournament, team, ncaa, basketball, four, game...
# 1402  tournament, team, ncaa, basketball, four, game...
# 1403  tournament, team, ncaa, basketball, four, game...
# 1404  tournament, team, ncaa, basketball, four, game...
# ...                                                 ...
# 1495  tournament, team, ncaa, basketball, four, game...
# 1496  tournament, team, ncaa, basketball, four, game...
# 1497  tournament, team, ncaa, basketball, four, game...
# 1498  tournament, team, ncaa, basketball, four, game...
# 1499  tournament, team, ncaa, basketball, four, game...
#
#                                                    Text
# 1400  ['scottie', 'reynolds', 'scored', '22', 'point...
# 1401  ['tyrus', 'thomas', 'glen', 'big', 'baby', 'da...
# 1402  ['jake', 'serfass', 'crossroad', 'sort', 'earl...
# 1403  ['bruin', 'notebook', 'wilmington', 'bruin', '...
# 1404  ['unheardof', 'nfl', 'draft', '20yearolds', 'b...
# ...                                                 ...
# 1495  ['hofstra', 'lost', 'topseeded', 'stanford', '...
# 1496  ['opening', 'loss', 'sacramento', 'state', 'ar...
# 1497  ['matt', 'youmans', 'la', 'vega', 'reviewjourn...
# 1498  ['special', 'section', 'ncaa', 'tournament', '...
# 1499  ['little', 'time', 'interior', 'decorating', '...
#
# [100 rows x 5 columns]

# %%
# Define the path to save the Excel file in your Google Drive
excel_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_15_topics.xlsx'

# Save the DataFrame to an Excel file
try:
    top_100_documents_per_topic.to_excel(excel_file_path, index=False)
    print(f"Successfully saved the top 100 documents per topic to: {excel_file_path}")
except Exception as e:
    print(f"An error occurred while saving the Excel file: {e}")
# Out:
# Successfully saved the top 100 documents per topic to: /content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_15_topics.xlsx

# %% [markdown]
# ##### **© 2024–2025 MD Rafsun Sheikh**
# ##### **Licensed under the Apache License, Version 2.0.**
