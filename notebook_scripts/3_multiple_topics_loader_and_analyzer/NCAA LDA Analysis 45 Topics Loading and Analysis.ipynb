# %%
# %pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.5 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 43.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 54.2 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 13.3 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gensim.models.ldamodel import LdaModel

# Load the LDA model
loaded_lda_model = LdaModel.load('/content/drive/MyDrive/Colab Notebooks/alex/models/lda_45_topics/lda_model_45_topics.gensim')

# Now you can access information from the loaded model.
# For example, you can print the topics:
print("Topics:")
for topic_id, topic in loaded_lda_model.print_topics():
    print(f"Topic {topic_id}: {topic}")

# You can also access the dictionary (id2word)
print("\nDictionary:")
print(loaded_lda_model.id2word)

# And the number of topics
print("\nNumber of topics:")
print(loaded_lda_model.num_topics)
# Out:
# Topics:
# Topic 24: 0.176*"women" + 0.058*"south" + 0.037*"basketball" + 0.035*"wnba" + 0.019*"connecticut" + 0.016*"gamecocks" + 0.012*"auriemma" + 0.012*"article" + 0.011*"player" + 0.010*"moore"
# Topic 19: 0.039*"season" + 0.029*"guard" + 0.018*"rebounds" + 0.015*"forward" + 0.014*"assists" + 0.014*"scoring" + 0.014*"freshman" + 0.013*"player" + 0.013*"team" + 0.012*"shooting"
# Topic 30: 0.025*"team" + 0.019*"girls" + 0.019*"school" + 0.014*"gcu" + 0.012*"college" + 0.012*"senior" + 0.012*"named" + 0.012*"division" + 0.011*"award" + 0.009*"player"
# Topic 28: 0.130*"gophers" + 0.102*"minnesota" + 0.032*"ten" + 0.023*"staff" + 0.019*"dakota" + 0.016*"season" + 0.014*"team" + 0.012*"johnson" + 0.011*"north_dakota" + 0.011*"startribune.com"
# Topic 1: 0.056*"nba" + 0.025*"draft" + 0.022*"basketball" + 0.019*"pick" + 0.018*"league" + 0.013*"player" + 0.013*"celtics" + 0.013*"lakers" + 0.012*"star" + 0.010*"professional"
# Topic 20: 0.034*"sec" + 0.023*"season" + 0.022*"top" + 0.021*"win" + 0.019*"bowl" + 0.018*"college_football" + 0.018*"conference" + 0.016*"week" + 0.015*"teams" + 0.014*"team"
# Topic 9: 0.034*"final" + 0.027*"coach" + 0.026*"won" + 0.025*"team" + 0.022*"basketball" + 0.021*"national_championship" + 0.019*"championship" + 0.019*"championships" + 0.018*"history" + 0.017*"time"
# Topic 16: 0.033*"team" + 0.022*"season" + 0.019*"players" + 0.017*"play" + 0.015*"lot" + 0.013*"time" + 0.011*"playing" + 0.010*"games" + 0.010*"coach" + 0.009*"guys"
# Topic 17: 0.114*"penn" + 0.052*"temple" + 0.049*"staley" + 0.027*"owls" + 0.026*"joe" + 0.025*"la" + 0.023*"drexel" + 0.023*"salle" + 0.021*"ivy_league" + 0.018*"hawks"
# Topic 12: 0.099*"photo" + 0.054*"watkins" + 0.050*"caption" + 0.038*"ap" + 0.032*"tribune" + 0.027*"loyola" + 0.025*"collins" + 0.021*"getty" + 0.017*"clayton" + 0.016*"images"
# Topic 0: 0.043*"athletes" + 0.031*"university" + 0.028*"school" + 0.024*"sports" + 0.023*"schools" + 0.021*"students" + 0.020*"women" + 0.018*"college" + 0.016*"athletic" + 0.014*"student_athletes"
# Topic 38: 0.044*"hockey" + 0.019*"boston" + 0.018*"nhl" + 0.018*"ice" + 0.014*"bc" + 0.012*"frozen" + 0.012*"games" + 0.012*"flyers" + 0.011*"goals" + 0.011*"puck"
# Topic 14: 0.118*"st" + 0.071*"pitino" + 0.070*"east" + 0.059*"hall" + 0.033*"thompson" + 0.030*"willard" + 0.029*"providence" + 0.029*"red_storm" + 0.028*"garden" + 0.028*"seton"
# Topic 39: 0.058*"coach" + 0.025*"head_coach" + 0.023*"program" + 0.023*"coaches" + 0.021*"coaching" + 0.020*"job" + 0.019*"season" + 0.016*"seasons" + 0.013*"assistant" + 0.012*"hired"
# Topic 22: 0.043*"school" + 0.026*"players" + 0.017*"transfer" + 0.016*"recruiting" + 0.015*"college" + 0.012*"class" + 0.012*"season" + 0.011*"player" + 0.010*"play" + 0.010*"program"
# Topic 27: 0.072*"nfl" + 0.030*"football" + 0.021*"sanders" + 0.017*"super_bowl" + 0.015*"betts" + 0.014*"quarterback" + 0.013*"bears" + 0.013*"draft" + 0.011*"pro" + 0.011*"patriots"
# Topic 8: 0.032*"season" + 0.023*"injury" + 0.014*"week" + 0.014*"injuries" + 0.014*"games" + 0.013*"play" + 0.011*"practice" + 0.010*"day" + 0.010*"return" + 0.009*"team"
# Topic 34: 0.011*"city" + 0.011*"president" + 0.010*"sports_betting" + 0.010*"gambling" + 0.010*"streaming" + 0.007*"people" + 0.006*"bill" + 0.005*"law" + 0.005*"events" + 0.005*"united"
# Topic 31: 0.030*"league" + 0.014*"season" + 0.012*"baseball" + 0.011*"games" + 0.010*"professional" + 0.010*"team" + 0.010*"york" + 0.008*"manager" + 0.008*"united" + 0.008*"contract"
# Topic 15: 0.151*"ten" + 0.109*"indiana" + 0.098*"purdue" + 0.044*"wolverines" + 0.030*"spartans" + 0.025*"buckeyes" + 0.025*"irish" + 0.024*"boilermakers" + 0.024*"illini" + 0.023*"izzo"
#
# Dictionary:
# Dictionary<264174 unique tokens: ['absolutely', 'accepting', 'accommodations', 'accordance', 'account']...>
#
# Number of topics:
# 45

# %%
from gensim import corpora

# Load the corpus from the .mm file
corpus = corpora.MmCorpus('/content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/corpus.mm')

print("Corpus loaded successfully.")
# You can optionally print the corpus to inspect its structure
# print(list(corpus))
# Out:
# Corpus loaded successfully.

# %%
import json
import pandas as pd

# Assuming your JSON file contains a list of lists, where each inner list is a tokenized document
# Replace '/content/drive/MyDrive/path/to/your/texts.json' with the actual path to your JSON file
texts_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/texts.json'

with open(texts_file_path, 'r') as f:
    texts = json.load(f)

print(f"Loaded {len(texts)} documents from {texts_file_path}")
# Out:
# Loaded 149649 documents from /content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/texts.json

# %%
# import pandas as pd

# # Load the tokenized data from the Excel file
# try:
#     tokenized_data_df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/alex/updated_ tokenized_newspaper_data.xlsx')
#     print("Excel file loaded successfully.")
#     # Assuming the original text is in a column named 'text' or similar.
#     # Please adjust the column name if it's different in your Excel file.
#     if 'Main_text_tokenized' in tokenized_data_df.columns:
#         texts = tokenized_data_df['Main_text_tokenized'].tolist()
#         print(f"Extracted {len(texts)} documents.")
#     else:
#         texts = None
#         print("Could not find a 'text' column in the Excel file. Please make sure the column containing original texts is named 'text' or update the code.")

# except FileNotFoundError:
#     print("Error: The file was not found at the specified path.")
# except Exception as e:
#     print(f"An error occurred while reading the Excel file: {e}")
# Out:
# Excel file loaded successfully.
# Extracted 149703 documents.

# %%
#TFinding the dominant topic in each sentence

def format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts): # Updated to use loaded_lda_model and corpus, and texts=None
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = pd.concat([sent_topics_df, pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]).to_frame().T], ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

     # Add original text to the end of the output
    if texts is not None: # Added check if texts is not None
        contents = pd.Series(texts)
        sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


# Assuming texts is available as data_words or you provide another list/Series of texts
# df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts) # Updated to use loaded_lda_model and corpus, commented out as data_words is undefined
# To run this cell, define `data_words` with your text data before calling the function.
# For example:
# data_words = ["your document text 1", "your document text 2", ...]
# Then uncomment the line below:
df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts)

# Format
if 'df_topic_sents_keywords' in locals(): # Added check if df_topic_sents_keywords is defined
    df_dominant_topic = df_topic_sents_keywords.reset_index()
    df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
    # Show
    display(df_dominant_topic.head(20)) # Use display for better formatting
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              4             0.4325
# 1             1              4             0.2554
# 2             2             43             0.3364
# 3             3             16             0.2316
# 4             4             31             0.2168
# 5             5             19             0.2858
# 6             6             31             0.3528
# 7             7             31             0.2631
# 8             8             44             0.2184
# 9             9              4             0.3633
# 10           10             16             0.1418
# 11           11             32              0.384
# 12           12             16             0.2669
# 13           13              8             0.1769
# 14           14             43             0.3495
# 15           15              2             0.3374
# 16           16             31             0.2159
# 17           17              5             0.3042
# 18           18              9             0.2535
# 19           19             25             0.3381
#
#                                              Keywords  \
# 0   family, school, life, time, people, basketball...
# 1   family, school, life, time, people, basketball...
# 2   fans, time, people, sports, day, moment, artic...
# 3   team, season, players, play, lot, time, playin...
# 4   league, season, baseball, games, professional,...
# 5   season, guard, rebounds, forward, assists, sco...
# 6   league, season, baseball, games, professional,...
# 7   league, season, baseball, games, professional,...
# 8   half, lead, minutes, shot, left, rebounds, pla...
# 9   family, school, life, time, people, basketball...
# 10  team, season, players, play, lot, time, playin...
# 11  golf, round, championship, shot, tour, club, t...
# 12  team, season, players, play, lot, time, playin...
# 13  season, injury, week, injuries, games, play, p...
# 14  fans, time, people, sports, day, moment, artic...
# 15  ncaa, schools, conference, college_sports, spo...
# 16  league, season, baseball, games, professional,...
# 17  ncaa, investigation, university, court, settle...
# 18  final, coach, won, team, basketball, national_...
# 19  tournament, seed, teams, team, ncaa_tournament...
#
#                                                  Text
# 0   [coaching, living, bonnie, henrickson, phone, ...
# 1   [sidebar, ruston, la, dining, louisiana, cajun...
# 2   [garden, missed, lonely, nights, season, debut...
# 3   [ten, ago, chuck, daly, reclining, alongside, ...
# 4   [robinson, talk, rangers, stanley, cup, finals...
# 5   [conference, pacific, coach_mike, gillespie, s...
# 6   [rangers, signed, center, michael, nylander, m...
# 7   [gavitt, elected, hall, modest, player, dartmo...
# 8   [mythical, element, senior_guard, seimone, aug...
# 9   [ncaa_women, jim, izard, diana, vines, remembe...
# 10  [meet, george_mason, guard, lamar, butler, jai...
# 11  [kevin, iole, review, journal, local, golf, cl...
# 12  [seventh, time, coach, beilein, process, movin...
# 13  [demetrius, jones, talk, anymore, monday, iris...
# 14  [oakland, eating, gilbert, arenas, check, blog...
# 15  [bothered, myles, brand, term, dumb, jock, bra...
# 16  [lot, guessing, season, trade, twins, manager,...
# 17  [college, pa, n.c.a.a, penn, letter, announcin...
# 18  [person, called, call, cheryl, miller, stage, ...
# 19  [selection_sunday, month, ncaa, selection_comm...

# %%
# Display the first few rows of the dataframe to see the structure
display(df_dominant_topic.head())
# Out:
#    Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0            0              4             0.4325
# 1            1              4             0.2554
# 2            2             43             0.3364
# 3            3             16             0.2316
# 4            4             31             0.2168
#
#                                             Keywords  \
# 0  family, school, life, time, people, basketball...
# 1  family, school, life, time, people, basketball...
# 2  fans, time, people, sports, day, moment, artic...
# 3  team, season, players, play, lot, time, playin...
# 4  league, season, baseball, games, professional,...
#
#                                                 Text
# 0  [coaching, living, bonnie, henrickson, phone, ...
# 1  [sidebar, ruston, la, dining, louisiana, cajun...
# 2  [garden, missed, lonely, nights, season, debut...
# 3  [ten, ago, chuck, daly, reclining, alongside, ...
# 4  [robinson, talk, rangers, stanley, cup, finals...

# %%
# Sort documents within each topic by percentage contribution in descending order
sorted_documents_by_topic = df_dominant_topic.sort_values(by=['Dominant_Topic', 'Topic_Perc_Contrib'], ascending=[True, False])

# Display the sorted document indexes for each topic
print("Document Indexes for Each Topic (Sorted by Percentage Contribution):")
for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    print(f"\nTopic {topic_num}:")
    # Get documents for the current topic and select only the 'Document_No' column
    topic_documents = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num]['Document_No']
    # Display the document indexes (first 20 as an example)
    print(topic_documents.tolist()[:20])
# Out:
# Document Indexes for Each Topic (Sorted by Percentage Contribution):
#
# Topic 0:
# [3064, 48272, 47626, 60670, 96487, 50073, 79657, 37592, 65983, 72012, 3062, 41663, 39259, 48437, 75518, 74180, 21372, 36857, 17304, 82691]
#
# Topic 1:
# [60308, 35678, 46827, 123733, 85984, 50512, 8388, 24210, 101871, 46828, 50513, 50511, 103313, 39842, 80593, 148177, 27269, 13271, 92178, 134431]
#
# Topic 2:
# [34130, 52659, 77138, 67265, 93194, 129597, 5007, 93468, 129598, 55378, 129599, 129461, 93060, 15655, 19921, 124883, 95049, 94998, 28895, 131184]
#
# Topic 3:
# [131802, 77022, 43636, 44086, 11292, 70761, 8994, 120101, 19333, 53822, 8995, 94717, 62891, 131787, 43348, 30644, 17582, 70162, 5241, 50074]
#
# Topic 4:
# [87936, 63005, 123383, 140488, 131126, 85340, 19603, 75224, 42581, 133552, 1977, 126779, 58259, 141363, 136513, 11603, 79638, 137579, 76784, 3211]
#
# Topic 5:
# [25870, 33888, 24077, 14542, 115822, 100438, 28071, 67515, 77012, 16414, 57162, 14534, 57083, 121819, 78292, 49104, 91429, 43823, 14537, 43182]
#
# Topic 6:
# [5035, 121836, 39634, 1815, 7545, 898, 119118, 118074, 93076, 28673, 121827, 32034, 121833, 122289, 122258, 58304, 114941, 10496, 119534, 117016]
#
# Topic 7:
# [143612, 131394, 143731, 25689, 91683, 24654, 82981, 3767, 11698, 78614, 99377, 79655, 21228, 85612, 44096, 40633, 32715, 105383, 54620, 82271]
#
# Topic 8:
# [4644, 69509, 37272, 121787, 52293, 17342, 9360, 13306, 148960, 66216, 1749, 6143, 119253, 59349, 138868, 62370, 126673, 83453, 52335, 36912]
#
# Topic 9:
# [57120, 50031, 57122, 50029, 50032, 50034, 57121, 57123, 141156, 87263, 60456, 77165, 69981, 79720, 50036, 148970, 147122, 94309, 53150, 99067]
#
# Topic 10:
# [46235, 38710, 1498, 129440, 133922, 20956, 29272, 10187, 235, 53241, 81436, 48604, 41382, 129439, 81286, 72468, 65998, 72806, 66980, 77866]
#
# Topic 11:
# [28686, 93624, 10927, 71612, 75740, 28675, 67538, 70137, 98461, 118404, 58521, 36369, 88017, 69462, 42283, 130034, 68749, 36372, 65347, 29966]
#
# Topic 12:
# [102740, 97470, 68040, 95048, 42679, 49587, 77117, 50007, 24240, 72673, 93845, 77226, 38487, 82205, 146745, 48118, 77002, 86553, 85432, 37287]
#
# Topic 13:
# [31164, 72182, 85247, 71814, 98701, 98702, 98705, 102704, 85248, 10767, 97126, 41808, 105775, 37315, 63449, 2505, 1488, 120341, 138306, 90929]
#
# Topic 14:
# [86414, 5265, 5026, 73942, 141892, 43659, 73935, 97376, 43988, 101179, 138843, 147954, 86958, 61767, 29629, 25246, 80073, 88329, 67673, 144133]
#
# Topic 15:
# [35128, 35095, 928, 123607, 73622, 42972, 117679, 29136, 82560, 100153, 28311, 72108, 145195, 117645, 62827, 90719, 48334, 32086, 78470, 11167]
#
# Topic 16:
# [108188, 25641, 76756, 37585, 97427, 90303, 91712, 141109, 141992, 116485, 95536, 66477, 141772, 115847, 108193, 101130, 133388, 72929, 65980, 27544]
#
# Topic 17:
# [61202, 65994, 65063, 11794, 7259, 2985, 61828, 71926, 40860, 62049, 57681, 54085, 60147, 80726, 47714, 113915, 7231, 39338, 7261, 25603]
#
# Topic 18:
# [50647, 4570, 149611, 2590, 57307, 15641, 87072, 64690, 70784, 63597, 66821, 65070, 133829, 4572, 146556, 36762, 21443, 31885, 19369, 24144]
#
# Topic 19:
# [103586, 108107, 40536, 49570, 80064, 86587, 66774, 85008, 92106, 73864, 37734, 24414, 133933, 85831, 65141, 63693, 24412, 67060, 66953, 24413]
#
# Topic 20:
# [14433, 143509, 14384, 141480, 143765, 97648, 120035, 144818, 64593, 18700, 143655, 138127, 118191, 10245, 3700, 127261, 120055, 120057, 17921, 124848]
#
# Topic 21:
# [48210, 71606, 53374, 12974, 73082, 65496, 16284, 40327, 31776, 48208, 39904, 48213, 55862, 27656, 12973, 27699, 48212, 18858, 33914, 15535]
#
# Topic 22:
# [51440, 118640, 72963, 100026, 61097, 32444, 71607, 91620, 66098, 125210, 16008, 13146, 85634, 20059, 88157, 4279, 70083, 122025, 109432, 34010]
#
# Topic 23:
# [76928]
#
# Topic 24:
# [19536, 60201, 144504, 50357, 58137, 2836, 132542, 67613, 135480, 60218, 135838, 28172, 58312, 145578, 141237, 140470, 148168, 148169, 79682, 148499]
#
# Topic 25:
# [63459, 110855, 54227, 9351, 43637, 76923, 71026, 52799, 69091, 74728, 71370, 101786, 96670, 71979, 66008, 96546, 42534, 108765, 50030, 50033]
#
# Topic 26:
# [7186, 36142, 41937, 18752, 33630, 56086, 67724, 52663, 28239, 14871, 23089, 5249, 67722, 50465, 65399, 35307, 76730, 50037, 41942, 63301]
#
# Topic 27:
# [46820, 5419, 10711, 18140, 126217, 1066, 50218, 39421, 123134, 15097, 40597, 139693, 69229, 13369, 43955, 12096, 106391, 47910, 141107, 59167]
#
# Topic 28:
# [86231, 118934, 12728, 19898, 58795, 90365, 141171, 112236, 31385, 146939, 146014, 104726, 135319, 104648, 82199, 19635, 91408, 92114, 12469, 108711]
#
# Topic 29:
# [57420, 17373, 23156, 13884, 28043, 133674, 10544, 36579, 45438, 24182, 5037, 86284, 77560, 68273, 2967, 132698, 147910, 36053, 70788, 138506]
#
# Topic 30:
# [3154, 16759, 20373, 2525, 136091, 6743, 6898, 16761, 17527, 131793, 16762, 24180, 3146, 30990, 15491, 110912, 109671, 2910, 22390, 22634]
#
# Topic 31:
# [126468, 35493, 10113, 51765, 39670, 44103, 16594, 44099, 44101, 74400, 7571, 115331, 20298, 74689, 132932, 75230, 16416, 36414, 32926, 78801]
#
# Topic 32:
# [22335, 19345, 40013, 31667, 105625, 3512, 131005, 30483, 106809, 22333, 3510, 13752, 81958, 108475, 58390, 102628, 9885, 37539, 108479, 37017]
#
# Topic 33:
# [45769, 28671, 116689, 122009, 7483, 121903, 144214, 44067, 111292, 7887, 44726, 148327, 111360, 59162, 112278, 61291, 8276, 34043, 52575, 35047]
#
# Topic 34:
# [134742, 119100, 121558, 124060, 10969, 124676, 134329, 134073, 132914, 17339, 105681, 57976, 71202, 49553, 6504, 76942, 77934, 89017, 81231, 138700]
#
# Topic 35:
# [13253, 76767, 33128, 35459, 193, 84372, 11967, 11964, 35136, 11875, 38837, 57317, 5423, 48001, 47812, 19515, 62222, 6016, 24026, 45516]
#
# Topic 36:
# [57252, 79022, 13039, 16834, 42313, 12832, 12276, 51739, 20671, 28768, 67193, 13038, 88426, 82634, 63783, 592, 17638, 57020, 78236, 29537]
#
# Topic 37:
# [120467, 128222, 136013, 113022, 144827, 117903, 142200, 109226, 79536, 131422, 144828, 123368, 138562, 83896, 143696, 138564, 74559, 144814, 147962, 111694]
#
# Topic 38:
# [141162, 70780, 19651, 37313, 77785, 7177, 100402, 63879, 71361, 58995, 6474, 110361, 108583, 109590, 21043, 26744, 97944, 43947, 103259, 65683]
#
# Topic 39:
# [33318, 104394, 57836, 26421, 57838, 21146, 58977, 36558, 99150, 37781, 49741, 87303, 48807, 40772, 10436, 35332, 119910, 22138, 20018, 20162]
#
# Topic 40:
# [63319, 495, 61073, 44737]
#
# Topic 41:
# [73765, 101115, 55331, 58112, 43139, 85043]
#
# Topic 42:
# [69272, 96054, 14760, 11566, 147801, 147701, 7340, 120093, 5014, 3576, 7255, 24535, 9756, 20449, 81649, 2931, 118051, 129443, 115402, 46676]
#
# Topic 43:
# [33969, 53099, 76949, 62398, 14041, 9888, 39586, 35675, 60073, 73549, 30675, 39585, 62136, 104432, 67375, 45906, 22470, 85493, 109263, 7904]
#
# Topic 44:
# [105853, 46221, 24351, 59896, 5126, 11372, 21495, 73471, 3821, 49030, 5140, 13226, 15665, 10938, 81432, 13606, 4918, 24585, 46939, 68362]

# %%
# Get the total number of documents for each dominant topic
topic_counts = df_dominant_topic['Dominant_Topic'].value_counts().sort_index()

print("Total number of documents for each topic:")
display(topic_counts)
# Out:
# Total number of documents for each topic:
# Dominant_Topic
# 0      2596
# 1      2903
# 2      4675
# 3      2907
# 4      5675
# 5      6183
# 6       352
# 7      7077
# 8      2902
# 9      2376
# 10      422
# 11     3686
# 12      187
# 13     2679
# 14       70
# 15       22
# 16    13290
# 17      541
# 18       31
# 19     5325
# 20     3233
# 21      122
# 22     3462
# 23        1
# 24      850
# 25    10366
# 26     1632
# 27      661
# 28     1196
# 29     3465
# 30     3132
# 31     4198
# 32     2752
# 33      273
# 34     3297
# 35     1431
# 36     6890
# 37     1748
# 38     2440
# 39     4586
# 40        4
# 41        6
# 42       25
# 43    12543
# 44    17437
# Name: count, dtype: int64

# %%
# Get the top 100 documents for each topic
top_100_documents_per_topic = pd.DataFrame()

for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    # Get the top 100 documents for the current topic
    top_100 = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num].head(100)
    # Append to the results DataFrame
    top_100_documents_per_topic = pd.concat([top_100_documents_per_topic, top_100], ignore_index=True)

# Display the top 100 documents for each topic
print("Top 100 Documents for Each Topic (Sorted by Percentage Contribution):")

# Iterate through topics and display the top documents for each
for topic_num in top_100_documents_per_topic['Dominant_Topic'].unique():
    print(f"\n--- Topic {topic_num} ---")
    display(top_100_documents_per_topic[top_100_documents_per_topic['Dominant_Topic'] == topic_num])
# Out:
# Top 100 Documents for Each Topic (Sorted by Percentage Contribution):
#
# --- Topic 0 ---
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0          3064              0             0.9279
# 1         48272              0             0.9035
# 2         47626              0             0.8509
# 3         60670              0             0.8439
# 4         96487              0             0.8349
# ..          ...            ...                ...
# 95         6516              0             0.6017
# 96        22708              0             0.6007
# 97       133433              0             0.6004
# 98         4800              0             0.5993
# 99        18114              0              0.599
#
#                                              Keywords  \
# 0   athletes, university, school, sports, schools,...
# 1   athletes, university, school, sports, schools,...
# 2   athletes, university, school, sports, schools,...
# 3   athletes, university, school, sports, schools,...
# 4   athletes, university, school, sports, schools,...
# ..                                                ...
# 95  athletes, university, school, sports, schools,...
# 96  athletes, university, school, sports, schools,...
# 97  athletes, university, school, sports, schools,...
# 98  athletes, university, school, sports, schools,...
# 99  athletes, university, school, sports, schools,...
#
#                                                  Text
# 0   [colleges, graduation, rate, division, student...
# 1   [university, federal, graduation_rates, athlet...
# 2   [graduation_rates, division, basketball, baseb...
# 3   [ncaa, academic, reforms, refined, eligibility...
# 4   [football_program, improved, academic, progres...
# ..                                                ...
# 95  [rice, football, field, owls, wisest, graduati...
# 96  [school, math, college, degree, political, sci...
# 97  [fifty, title_ix, passed, colleges, universiti...
# 98  [n.c.a.a, division, board, directors, approved...
# 99  [colleges, universities, allowed, limit, schol...
#
# [100 rows x 5 columns]
# --- Topic 1 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 100        60308              1             0.7271
# 101        35678              1              0.667
# 102        46827              1             0.6477
# 103       123733              1             0.6271
# 104        85984              1             0.5974
# ..           ...            ...                ...
# 195        48351              1             0.4672
# 196        45809              1             0.4671
# 197        63329              1             0.4667
# 198         5340              1             0.4665
# 199        45660              1             0.4664
#
#                                               Keywords  \
# 100  nba, draft, basketball, pick, league, player, ...
# 101  nba, draft, basketball, pick, league, player, ...
# 102  nba, draft, basketball, pick, league, player, ...
# 103  nba, draft, basketball, pick, league, player, ...
# 104  nba, draft, basketball, pick, league, player, ...
# ..                                                 ...
# 195  nba, draft, basketball, pick, league, player, ...
# 196  nba, draft, basketball, pick, league, player, ...
# 197  nba, draft, basketball, pick, league, player, ...
# 198  nba, draft, basketball, pick, league, player, ...
# 199  nba, draft, basketball, pick, league, player, ...
#
#                                                   Text
# 100  [timberwolves, entered, thursday, night, draft...
# 101  [bucks, suffered, disappointing, season, playo...
# 102  [portland, beat, odds, tuesday, won, nba_draft...
# 103  [ers, lucky, miss, prospect, hoped, snag, pick...
# 104  [happy, coincidence, tom, benson, newly, minte...
# ..                                                 ...
# 195  [listed, mock_drafts, ers, pick, uncertainty, ...
# 196  [timberwolves, played, wednesday, play, night,...
# 197  [plan, forty, hours, blake, griffin, stroll, p...
# 198  [nba, finals, lakers, nba, finals, bob, keisse...
# 199  [wizards, signed, guard, roger, mason, center,...
#
# [100 rows x 5 columns]
# --- Topic 2 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 200        34130              2              0.848
# 201        52659              2             0.8044
# 202        77138              2             0.7789
# 203        67265              2             0.7647
# 204        93194              2             0.7616
# ..           ...            ...                ...
# 295       129611              2             0.5964
# 296        46553              2             0.5951
# 297        33368              2             0.5947
# 298       138402              2             0.5916
# 299        92895              2              0.591
#
#                                               Keywords  \
# 200  ncaa, schools, conference, college_sports, spo...
# 201  ncaa, schools, conference, college_sports, spo...
# 202  ncaa, schools, conference, college_sports, spo...
# 203  ncaa, schools, conference, college_sports, spo...
# 204  ncaa, schools, conference, college_sports, spo...
# ..                                                 ...
# 295  ncaa, schools, conference, college_sports, spo...
# 296  ncaa, schools, conference, college_sports, spo...
# 297  ncaa, schools, conference, college_sports, spo...
# 298  ncaa, schools, conference, college_sports, spo...
# 299  ncaa, schools, conference, college_sports, spo...
#
#                                                   Text
# 200  [pacific, conference, athletic_directors, meet...
# 201  [ncaa, selection_committee, discuss, experiences]
# 202  [mark_emmert, president, n.c.a.a, reached, top...
# 203  [division, schools, notably, presidents, warmi...
# 204  [southeastern, conference, commissioner, mike,...
# ..                                                 ...
# 295  [ncaa_division, council, voted, wednesday, ath...
# 296  [annual, bowl, championship, series, meetings,...
# 297  [written, past, week, ncaa, executive, committ...
# 298  [massachusetts, governor, charlie, baker, form...
# 299  [ncaa, board, directors, voted, thursday, gran...
#
# [100 rows x 5 columns]
# --- Topic 3 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 300       131802              3             0.9425
# 301        77022              3              0.907
# 302        43636              3             0.9042
# 303        44086              3             0.8892
# 304        11292              3             0.8786
# ..           ...            ...                ...
# 395        66293              3             0.6779
# 396       135656              3             0.6762
# 397        38079              3             0.6758
# 398       133541              3             0.6742
# 399        71037              3             0.6741
#
#                                               Keywords  \
# 300  scored, round, south, tech, seeded, win, beat,...
# 301  scored, round, south, tech, seeded, win, beat,...
# 302  scored, round, south, tech, seeded, win, beat,...
# 303  scored, round, south, tech, seeded, win, beat,...
# 304  scored, round, south, tech, seeded, win, beat,...
# ..                                                 ...
# 395  scored, round, south, tech, seeded, win, beat,...
# 396  scored, round, south, tech, seeded, win, beat,...
# 397  scored, round, south, tech, seeded, win, beat,...
# 398  scored, round, south, tech, seeded, win, beat,...
# 399  scored, round, south, tech, seeded, win, beat,...
#
#                                                   Text
# 300  [ncaa_division, south, jackson, st, prairie, v...
# 301  [ncaa, automatic, bids, belmont, atlantic, sun...
# 302  [memphis, gonzaga, wichita, unc, wilm, san_die...
# 303  [special, section, ncaa_tournament, america_ea...
# 304  [schools, earned, automatic, bids, ncaa_women,...
# ..                                                 ...
# 395  [tyler, hansbrough, scored, final_home, north,...
# 396  [belmont, valley, mercer, southern, atlantic, ...
# 397  [junior, center, dani, kubik, scored, career, ...
# 398  [tech, mount, st_mary, cayla, king, schoolreco...
# 399  [demarcus, cousins, rebounds, saturday, return...
#
# [100 rows x 5 columns]
# --- Topic 4 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 400        87936              4             0.5801
# 401        63005              4             0.5653
# 402       123383              4             0.5527
# 403       140488              4              0.535
# 404       131126              4              0.534
# ..           ...            ...                ...
# 495        40486              4             0.4429
# 496        34235              4             0.4426
# 497        23151              4             0.4423
# 498        30458              4             0.4419
# 499       123277              4             0.4416
#
#                                               Keywords  \
# 400  family, school, life, time, people, basketball...
# 401  family, school, life, time, people, basketball...
# 402  family, school, life, time, people, basketball...
# 403  family, school, life, time, people, basketball...
# 404  family, school, life, time, people, basketball...
# ..                                                 ...
# 495  family, school, life, time, people, basketball...
# 496  family, school, life, time, people, basketball...
# 497  family, school, life, time, people, basketball...
# 498  family, school, life, time, people, basketball...
# 499  family, school, life, time, people, basketball...
#
#                                                   Text
# 400  [judy, ochoa, mom, sat, doctor, broke, news, d...
# 401  [daniel, bugey, darby, postmaster, daniel, bug...
# 402  [sean, boynes, natural, comedian, loving, fath...
# 403  [miri, sorin, buium, moved, united, israel, ag...
# 404  [stood, newborn, intensive, care, unit, hands,...
# ..                                                 ...
# 495  [columnist, sue, shellenbarger, answers, reade...
# 496  [special, section, ncaa_tournament, elite, sen...
# 497  [george, dernoeden, editorial, assistant, geor...
# 498  [northern, swimming, league, celebrating, summ...
# 499  [carrie, tollefson, continues, live, life, run...
#
# [100 rows x 5 columns]
# --- Topic 5 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 500        25870              5             0.9223
# 501        33888              5             0.8014
# 502        24077              5              0.799
# 503        14542              5             0.7967
# 504       115822              5             0.7745
# ..           ...            ...                ...
# 595        85741              5             0.6241
# 596        14535              5             0.6223
# 597       118387              5             0.6223
# 598        14599              5             0.6222
# 599       111804              5             0.6213
#
#                                               Keywords  \
# 500  ncaa, investigation, university, court, settle...
# 501  ncaa, investigation, university, court, settle...
# 502  ncaa, investigation, university, court, settle...
# 503  ncaa, investigation, university, court, settle...
# 504  ncaa, investigation, university, court, settle...
# ..                                                 ...
# 595  ncaa, investigation, university, court, settle...
# 596  ncaa, investigation, university, court, settle...
# 597  ncaa, investigation, university, court, settle...
# 598  ncaa, investigation, university, court, settle...
# 599  ncaa, investigation, university, court, settle...
#
#                                                   Text
# 500  [colleges, basketball_coach, quin, snyder, acc...
# 501  [monday, ncaa, notified, school, alleged, rule...
# 502  [basketball_coach, quin, snyder, accused, ncaa...
# 503  [colleges, school, win, appeal, ncaa, wolverin...
# 504  [received, formal, notice, allegations, ncaa, ...
# ..                                                 ...
# 595  [plaintiffs, lawyers, prosecutors, build, civi...
# 596  [acted, intentions, hint, booster, ed, martin,...
# 597  [government, actively, engaged, plea, negotiat...
# 598  [president, elson, floyd, told, press, resign,...
# 599  [federal, grand, jury, issued, subpoenas, univ...
#
# [100 rows x 5 columns]
# --- Topic 6 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 600         5035              6             0.5295
# 601       121836              6               0.51
# 602        39634              6              0.487
# 603         1815              6             0.4544
# 604         7545              6             0.4479
# ..           ...            ...                ...
# 695        53883              6             0.2774
# 696       149227              6             0.2762
# 697        88237              6             0.2749
# 698         9206              6             0.2734
# 699       111999              6             0.2724
#
#                                               Keywords  \
# 600  march, west, grand_canyon, uc, cal, san, beach...
# 601  march, west, grand_canyon, uc, cal, san, beach...
# 602  march, west, grand_canyon, uc, cal, san, beach...
# 603  march, west, grand_canyon, uc, cal, san, beach...
# 604  march, west, grand_canyon, uc, cal, san, beach...
# ..                                                 ...
# 695  march, west, grand_canyon, uc, cal, san, beach...
# 696  march, west, grand_canyon, uc, cal, san, beach...
# 697  march, west, grand_canyon, uc, cal, san, beach...
# 698  march, west, grand_canyon, uc, cal, san, beach...
# 699  march, west, grand_canyon, uc, cal, san, beach...
#
#                                                   Text
# 600  [university, park, pa, semifinals, thursday, b...
# 601  [uc, riverside, malou, thiebaut, de, kergret, ...
# 602  [college_basketball, monday, special, section,...
# 603  [cal, northridge, matadors, playing, improve, ...
# 604  [pacific, rematch, tournament_final, won, aggi...
# ..                                                 ...
# 695  [time, cal, northridge, coach, bobby, braswell...
# 696  [women, ncaa_tournament, begins, wednesday, ma...
# 697  [grand_canyon, university, women, basketball_t...
# 698  [staff, writer, chris, cocoles, covers, colleg...
# 699  [jaymi, steward, rounds, base, score, carter, ...
#
# [100 rows x 5 columns]
# --- Topic 7 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 700       143612              7             0.8354
# 701       131394              7             0.8235
# 702       143731              7             0.8228
# 703        25689              7             0.8187
# 704        91683              7             0.8055
# ..           ...            ...                ...
# 795        30306              7              0.685
# 796        54928              7             0.6847
# 797       128637              7             0.6846
# 798       138030              7             0.6842
# 799        88639              7             0.6824
#
#                                               Keywords  \
# 700  olympic, world, olympics, women, gold, won, ti...
# 701  olympic, world, olympics, women, gold, won, ti...
# 702  olympic, world, olympics, women, gold, won, ti...
# 703  olympic, world, olympics, women, gold, won, ti...
# 704  olympic, world, olympics, women, gold, won, ti...
# ..                                                 ...
# 795  olympic, world, olympics, women, gold, won, ti...
# 796  olympic, world, olympics, women, gold, won, ti...
# 797  olympic, world, olympics, women, gold, won, ti...
# 798  olympic, world, olympics, women, gold, won, ti...
# 799  olympic, world, olympics, women, gold, won, ti...
#
#                                                   Text
# 700  [team_usa, stacked, roster, paris, olympics, c...
# 701  [tokyo, american, diving, duo, delaney, schnel...
# 702  [team_usa, stacked, roster, paris, olympics, c...
# 703  [christine, spence, seventh, meter, hurdles, n...
# 704  [western, meter, relay, team, triple, jumper, ...
# ..                                                 ...
# 795  [ran, fast, meter, hurdles, kerron, clement, s...
# 796  [eugene, ore, bryan, clay, shy, disgusted, per...
# 797  [correction, clarification, previous, version,...
# 798  [summer, olympics, world, athletes, set, conve...
# 799  [junior, brianna, rollins, broke, collegiate, ...
#
# [100 rows x 5 columns]
# --- Topic 8 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 800         4644              8             0.6232
# 801        69509              8             0.6167
# 802        37272              8             0.6154
# 803       121787              8             0.6115
# 804        52293              8             0.6114
# ..           ...            ...                ...
# 895        38977              8             0.4622
# 896        78857              8             0.4602
# 897       117088              8               0.46
# 898        50460              8             0.4591
# 899        40754              8             0.4585
#
#                                               Keywords  \
# 800  season, injury, week, injuries, games, play, p...
# 801  season, injury, week, injuries, games, play, p...
# 802  season, injury, week, injuries, games, play, p...
# 803  season, injury, week, injuries, games, play, p...
# 804  season, injury, week, injuries, games, play, p...
# ..                                                 ...
# 895  season, injury, week, injuries, games, play, p...
# 896  season, injury, week, injuries, games, play, p...
# 897  season, injury, week, injuries, games, play, p...
# 898  season, injury, week, injuries, games, play, p...
# 899  season, injury, week, injuries, games, play, p...
#
#                                                   Text
# 800  [memphis, forward, chris, massie, declared, ac...
# 801  [jon, hargis, seasoned, offensive_lineman, mis...
# 802  [coach, jay, wright, players, progress, hopes,...
# 803  [gophers, redshirt, junior, forward, eric, cur...
# 804  [bye, week, regain, health, significant, playe...
# ..                                                 ...
# 895  [star, jay, williams, severe, injuries, suffer...
# 896  [slowed, injuries, spring, practice, senior_gu...
# 897  [loss, top, playmaker, defense, p.j, fleck, tu...
# 898  [defensive, loren, howard, lengthy, battle, re...
# 899  [college_basketball_teams, top_ranked, earlier...
#
# [100 rows x 5 columns]
# --- Topic 9 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 900        57120              9              0.837
# 901        50031              9             0.8044
# 902        57122              9             0.8044
# 903        50029              9             0.7556
# 904        50032              9             0.7556
# ..           ...            ...                ...
# 995       137519              9             0.4509
# 996       147129              9             0.4509
# 997        40974              9             0.4503
# 998        40985              9             0.4502
# 999        65609              9             0.4489
#
#                                               Keywords  \
# 900  final, coach, won, team, basketball, national_...
# 901  final, coach, won, team, basketball, national_...
# 902  final, coach, won, team, basketball, national_...
# 903  final, coach, won, team, basketball, national_...
# 904  final, coach, won, team, basketball, national_...
# ..                                                 ...
# 995  final, coach, won, team, basketball, national_...
# 996  final, coach, won, team, basketball, national_...
# 997  final, coach, won, team, basketball, national_...
# 998  final, coach, won, team, basketball, national_...
# 999  final, coach, won, team, basketball, national_...
#
#                                                   Text
# 900  [ncaa_tournament, championship, subject, tourn...
# 901  [ncaa_tournament, subject, tournaments, champi...
# 902  [ncaa_tournament_final, subject, tournaments, ...
# 903  [ncaa_tournament_east_region, subject, tournam...
# 904  [ncaa_tournament_midwest_region, subject, tour...
# ..                                                 ...
# 995  [denny, crum, basketball, encompass, dream, cr...
# 996  [kelvin, sampson, built, basketball, annual, c...
# 997  [college_basketball, bob, knight, temper, guil...
# 998  [coach_mike_krzyzewski, accomplished, bob, kni...
# 999  [west_regional, champion, nickname, location, ...
#
# [100 rows x 5 columns]
# --- Topic 10 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1000        46235             10             0.8914
# 1001        38710             10              0.604
# 1002         1498             10             0.5745
# 1003       129440             10             0.5546
# 1004       133922             10             0.5334
# ...           ...            ...                ...
# 1095        30043             10             0.2755
# 1096        16071             10             0.2754
# 1097       127146             10             0.2751
# 1098       128919             10             0.2747
# 1099        45859             10             0.2744
#
#                                                Keywords  \
# 1000  wrestling, edwards, st, island, wagner, st_tho...
# 1001  wrestling, edwards, st, island, wagner, st_tho...
# 1002  wrestling, edwards, st, island, wagner, st_tho...
# 1003  wrestling, edwards, st, island, wagner, st_tho...
# 1004  wrestling, edwards, st, island, wagner, st_tho...
# ...                                                 ...
# 1095  wrestling, edwards, st, island, wagner, st_tho...
# 1096  wrestling, edwards, st, island, wagner, st_tho...
# 1097  wrestling, edwards, st, island, wagner, st_tho...
# 1098  wrestling, edwards, st, island, wagner, st_tho...
# 1099  wrestling, edwards, st, island, wagner, st_tho...
#
#                                                    Text
# 1000  [au, josh, glenn, won, pound, division, ncaa_w...
# 1001  [scoreboard, dec, sports, grand, valley, playi...
# 1002  [source:apzfile:zkeyword:bc, ncaawrestlingresu...
# 1003  [times, eastern, round, nov, linfield, saint, ...
# 1004  [times, eastern, round, saint, minn, northwest...
# ...                                                 ...
# 1095  [nassau, cc, wrestling, team, americans, divis...
# 1096  [week, brought, bad, connecticut, hofstra, tie...
# 1097  [week, augustana, minnesota_duluth, p.m, satur...
# 1098  [miac, named, conference, football, champion, ...
# 1099  [north, central, conference, formed, penultima...
#
# [100 rows x 5 columns]
# --- Topic 11 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1100        28686             11             0.8778
# 1101        93624             11             0.8587
# 1102        10927             11             0.8303
# 1103        71612             11             0.8154
# 1104        75740             11             0.8067
# ...           ...            ...                ...
# 1195       116468             11             0.6609
# 1196        81864             11             0.6604
# 1197        53600             11             0.6601
# 1198         8707             11               0.66
# 1199        10970             11             0.6598
#
#                                                Keywords  \
# 1100  baseball, softball, regional, harbaugh, inning...
# 1101  baseball, softball, regional, harbaugh, inning...
# 1102  baseball, softball, regional, harbaugh, inning...
# 1103  baseball, softball, regional, harbaugh, inning...
# 1104  baseball, softball, regional, harbaugh, inning...
# ...                                                 ...
# 1195  baseball, softball, regional, harbaugh, inning...
# 1196  baseball, softball, regional, harbaugh, inning...
# 1197  baseball, softball, regional, harbaugh, inning...
# 1198  baseball, softball, regional, harbaugh, inning...
# 1199  baseball, softball, regional, harbaugh, inning...
#
#                                                    Text
# 1100  [ncaa_division, college_world_series, city, el...
# 1101  [kirsti, merritt, hit, run, homer, defeated, c...
# 1102  [ncaa_division, world_series, glance, city, do...
# 1103  [pi, ikea, kitamura, forced, ahead, run, outs,...
# 1104  [tyler, pill, enjoyed, busy, night, home, crow...
# ...                                                 ...
# 1195  [row, cal, fullerton, won, regional, advance, ...
# 1196  [night, pitching, faltered, career, outing, st...
# 1197  [softball, team, set, bar, season, victory, st...
# 1198  [malibu, position, past, weeks, firmly, wall, ...
# 1199  [beau, vaughan, home_run, start, inning, loss,...
#
# [100 rows x 5 columns]
# --- Topic 12 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1200       102740             12             0.7518
# 1201        97470             12             0.6996
# 1202        68040             12             0.6609
# 1203        95048             12             0.6542
# 1204        42679             12             0.6327
# ...           ...            ...                ...
# 1295         6831             12             0.3131
# 1296        35698             12             0.3106
# 1297        50374             12             0.3105
# 1298        32117             12               0.31
# 1299       104139             12             0.3092
#
#                                                Keywords  \
# 1200  photo, watkins, caption, ap, tribune, loyola, ...
# 1201  photo, watkins, caption, ap, tribune, loyola, ...
# 1202  photo, watkins, caption, ap, tribune, loyola, ...
# 1203  photo, watkins, caption, ap, tribune, loyola, ...
# 1204  photo, watkins, caption, ap, tribune, loyola, ...
# ...                                                 ...
# 1295  photo, watkins, caption, ap, tribune, loyola, ...
# 1296  photo, watkins, caption, ap, tribune, loyola, ...
# 1297  photo, watkins, caption, ap, tribune, loyola, ...
# 1298  photo, watkins, caption, ap, tribune, loyola, ...
# 1299  photo, watkins, caption, ap, tribune, loyola, ...
#
#                                                    Text
# 1200  [ncaa, scoreboard, gonzaga, n.c, illustration,...
# 1201  [ncaa, mens, tournament, text, database, illus...
# 1202  [caption, text, illustration, caption, butler,...
# 1203  [caption, text, illustration, caption, graphic...
# 1204  [caption, caption, text, illustration, photo, ...
# ...                                                 ...
# 1295  [role, mind, target, bother, mike, dunleavy, f...
# 1296  [caption, text, illustration, caption, photo, ...
# 1297  [photograph, antonio, graves, pitt, smothered,...
# 1298  [special, section, ncaa_tournament, elite, nat...
# 1299  [caption, text, illustration, caption, photo, ...
#
# [100 rows x 5 columns]
# --- Topic 13 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1300        31164             13              0.911
# 1301        72182             13              0.837
# 1302        85247             13             0.8213
# 1303        71814             13             0.7746
# 1304        98701             13             0.7731
# ...           ...            ...                ...
# 1395        19459             13             0.5914
# 1396        80837             13             0.5912
# 1397       134912             13             0.5912
# 1398       146769             13             0.5905
# 1399        33996             13             0.5904
#
#                                                Keywords  \
# 1300  p.m, espn, tv, watch, network, sports, cbs, li...
# 1301  p.m, espn, tv, watch, network, sports, cbs, li...
# 1302  p.m, espn, tv, watch, network, sports, cbs, li...
# 1303  p.m, espn, tv, watch, network, sports, cbs, li...
# 1304  p.m, espn, tv, watch, network, sports, cbs, li...
# ...                                                 ...
# 1395  p.m, espn, tv, watch, network, sports, cbs, li...
# 1396  p.m, espn, tv, watch, network, sports, cbs, li...
# 1397  p.m, espn, tv, watch, network, sports, cbs, li...
# 1398  p.m, espn, tv, watch, network, sports, cbs, li...
# 1399  p.m, espn, tv, watch, network, sports, cbs, li...
#
#                                                    Text
# 1300  [college_basketball, christmas, fans, ncaa_bas...
# 1301          [ncaa_women, championship, p.m, tv, espn]
# 1302  [consecutive, week, wouldancing, stars, ncis, ...
# 1303  [ncaa_division, softball, world_series, asa, h...
# 1304  [asa, hall_fame, stadium, city, double, elimin...
# ...                                                 ...
# 1395  [tip, clicker, picker, march_madness, continue...
# 1396  [bracket, yak, cbs, ncaa, selection, draws, ov...
# 1397  [radio, kmvp, fm, ktar, fm, ktar, wednesday, m...
# 1398  [wednesday, southern, uc, san_diego, thursday,...
# 1399  [million, households, tuned, week, watch, base...
#
# [100 rows x 5 columns]
# --- Topic 14 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1400        86414             14             0.6031
# 1401         5265             14             0.4756
# 1402         5026             14             0.4699
# 1403        73942             14              0.427
# 1404       141892             14             0.3714
# ...           ...            ...                ...
# 1465        97734             14             0.1447
# 1466       148394             14              0.143
# 1467        51405             14             0.1384
# 1468        32982             14             0.1253
# 1469        17274             14             0.1227
#
#                                                Keywords  \
# 1400  st, pitino, east, hall, thompson, willard, pro...
# 1401  st, pitino, east, hall, thompson, willard, pro...
# 1402  st, pitino, east, hall, thompson, willard, pro...
# 1403  st, pitino, east, hall, thompson, willard, pro...
# 1404  st, pitino, east, hall, thompson, willard, pro...
# ...                                                 ...
# 1465  st, pitino, east, hall, thompson, willard, pro...
# 1466  st, pitino, east, hall, thompson, willard, pro...
# 1467  st, pitino, east, hall, thompson, willard, pro...
# 1468  st, pitino, east, hall, thompson, willard, pro...
# 1469  st, pitino, east, hall, thompson, willard, pro...
#
#                                                    Text
# 1400  [syracusekansas, st, st.gonzaga, marquettemurr...
# 1401                    [refer, microfilm, chart, data]
# 1402  [march_madness, basketball, refer, microfilm, ...
# 1403  [paradise, jam, east_tournament, ncaa_tournament]
# 1404  [caption, photo, connecticut, donovan, clingan...
# ...                                                 ...
# 1465  [seton, hall, basketball_coach, kevin, willard...
# 1466  [roger, rubin, roger.rubin, newsday.com, st, c...
# 1467  [ncaa_basketball, bc, notebook, winston, salem...
# 1468  [called, underground, railroad, manhattan, bor...
# 1469  [midst, unprecedented, campus, building, boom,...
#
# [70 rows x 5 columns]
# --- Topic 15 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1470        35128             15             0.3407
# 1471        35095             15             0.2912
# 1472          928             15             0.2847
# 1473       123607             15             0.2746
# 1474        73622             15             0.2543
# 1475        42972             15             0.2378
# 1476       117679             15             0.2269
# 1477        29136             15              0.215
# 1478        82560             15             0.2054
# 1479       100153             15             0.2015
# 1480        28311             15             0.1953
# 1481        72108             15             0.1927
# 1482       145195             15             0.1818
# 1483       117645             15             0.1786
# 1484        62827             15             0.1729
# 1485        90719             15             0.1726
# 1486        48334             15             0.1702
# 1487        32086             15             0.1654
# 1488        78470             15              0.165
# 1489        11167             15             0.1415
# 1490        66700             15             0.1384
# 1491        76053             15              0.137
#
#                                                Keywords  \
# 1470  ten, indiana, purdue, wolverines, spartans, bu...
# 1471  ten, indiana, purdue, wolverines, spartans, bu...
# 1472  ten, indiana, purdue, wolverines, spartans, bu...
# 1473  ten, indiana, purdue, wolverines, spartans, bu...
# 1474  ten, indiana, purdue, wolverines, spartans, bu...
# 1475  ten, indiana, purdue, wolverines, spartans, bu...
# 1476  ten, indiana, purdue, wolverines, spartans, bu...
# 1477  ten, indiana, purdue, wolverines, spartans, bu...
# 1478  ten, indiana, purdue, wolverines, spartans, bu...
# 1479  ten, indiana, purdue, wolverines, spartans, bu...
# 1480  ten, indiana, purdue, wolverines, spartans, bu...
# 1481  ten, indiana, purdue, wolverines, spartans, bu...
# 1482  ten, indiana, purdue, wolverines, spartans, bu...
# 1483  ten, indiana, purdue, wolverines, spartans, bu...
# 1484  ten, indiana, purdue, wolverines, spartans, bu...
# 1485  ten, indiana, purdue, wolverines, spartans, bu...
# 1486  ten, indiana, purdue, wolverines, spartans, bu...
# 1487  ten, indiana, purdue, wolverines, spartans, bu...
# 1488  ten, indiana, purdue, wolverines, spartans, bu...
# 1489  ten, indiana, purdue, wolverines, spartans, bu...
# 1490  ten, indiana, purdue, wolverines, spartans, bu...
# 1491  ten, indiana, purdue, wolverines, spartans, bu...
#
#                                                    Text
# 1470  [hoops, nab, college, illini, bits, worried, w...
# 1471  [college_basketball, illini, bits, worried, we...
# 1472  [caption, text, illustration, photo, graphic, ...
# 1473  [depaul, athletic_director, jean, lenti, ponse...
# 1474  [hoyas, horses, stunning, loss, seeded, round,...
# 1475  [growing, indiana, fan, muncie, ind, matt, pai...
# 1476  [rosemont, ill, tom, izzo, hall_fame, career, ...
# 1477  [college_basketball, mark, aguirre, finished, ...
# 1478  [calendar, running, days, extricate, massive, ...
# 1479  [p.m, breslin, center, east, lansing, mich, tv...
# 1480  [college_basketball, bits, assisted, purdue, c...
# 1481  [faced, top, guards, nation, connecticut, kemb...
# 1482  [connecticut, purdue, clash, ncaa_basketball_t...
# 1483  [humans, watched, ten, basketball, tv, analyst...
# 1484  [dolphins, quarterbacks, dan, marino, dramatic...
# 1485  [school, juniors, guards, d.j, richardson, bra...
# 1486  [digging, deeper, storehouse, tom, crean, tom,...
# 1487  [team, straight, week, clinched, consecutive, ...
# 1488  [season, saving, comeback, mental, physical, t...
# 1489  [depaul, loyola, christmastime, ago, found, lo...
# 1490  [digesting, performance, ncaa_tournament, easy...
# 1491  [kramer, newman, crack, mystery, surrounding, ...
# --- Topic 16 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1492       108188             16             0.6969
# 1493        25641             16             0.6601
# 1494        76756             16             0.6374
# 1495        37585             16             0.6348
# 1496        97427             16             0.6162
# ...           ...            ...                ...
# 1587        99842             16             0.4979
# 1588        88181             16             0.4977
# 1589       128925             16             0.4976
# 1590       122103             16             0.4965
# 1591        68894             16             0.4958
#
#                                                Keywords  \
# 1492  team, season, players, play, lot, time, playin...
# 1493  team, season, players, play, lot, time, playin...
# 1494  team, season, players, play, lot, time, playin...
# 1495  team, season, players, play, lot, time, playin...
# 1496  team, season, players, play, lot, time, playin...
# ...                                                 ...
# 1587  team, season, players, play, lot, time, playin...
# 1588  team, season, players, play, lot, time, playin...
# 1589  team, season, players, play, lot, time, playin...
# 1590  team, season, players, play, lot, time, playin...
# 1591  team, season, players, play, lot, time, playin...
#
#                                                    Text
# 1492  [junior, jordan, murphy, beast, season, gopher...
# 1493  [pam, borton, arrived, minnesota, inherited, w...
# 1494  [brendon, lavender, graduated, mesa, mountain,...
# 1495  [calming, players, nerves, expert, sasho, ciro...
# 1496  [daly, santana, senior, hitter, leader, gopher...
# ...                                                 ...
# 1587  [trip, boston, coach, tom, izzo, team, cued, f...
# 1588  [boston, hotbed, college_hockey, hockey_east, ...
# 1589  [foxborough, mac, jones, moves, wednesday, pla...
# 1590  [penn, likes, rotate, lot, players, defense, p...
# 1591  [boston_college_hockey, staff, planning, strat...
#
# [100 rows x 5 columns]
# --- Topic 17 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1592        61202             17             0.4808
# 1593        65994             17             0.4807
# 1594        65063             17             0.4806
# 1595        11794             17             0.4669
# 1596         7259             17             0.4372
# ...           ...            ...                ...
# 1687        26528             17             0.3128
# 1688        71246             17             0.3122
# 1689        48565             17             0.3116
# 1690        55369             17              0.311
# 1691        47988             17             0.3105
#
#                                                Keywords  \
# 1592  penn, temple, staley, owls, joe, la, drexel, s...
# 1593  penn, temple, staley, owls, joe, la, drexel, s...
# 1594  penn, temple, staley, owls, joe, la, drexel, s...
# 1595  penn, temple, staley, owls, joe, la, drexel, s...
# 1596  penn, temple, staley, owls, joe, la, drexel, s...
# ...                                                 ...
# 1687  penn, temple, staley, owls, joe, la, drexel, s...
# 1688  penn, temple, staley, owls, joe, la, drexel, s...
# 1689  penn, temple, staley, owls, joe, la, drexel, s...
# 1690  penn, temple, staley, owls, joe, la, drexel, s...
# 1691  penn, temple, staley, owls, joe, la, drexel, s...
#
#                                                    Text
# 1592  [read, wku, beat, writer, nick, baumgardner, h...
# 1593  [read, wku, beat, writer, nick, baumgardner, h...
# 1594  [read, wku, beat, writer, nick, baumgardner, h...
# 1595  [tonight, liacouras, center, round, national, ...
# 1596  [tonight, palestra, tv, radio, comcast, sports...
# ...                                                 ...
# 1687  [dawn_staley, straight, women, basketball_coac...
# 1688  [seniors, temple, basketball_team, recognized,...
# 1689  [time, st_joseph, hawks, prompt, followers, st...
# 1690  [athletes, local, schools, scheduled, compete,...
# 1691  [adam, franklin, reserve, guard, penn, basketb...
#
# [100 rows x 5 columns]
# --- Topic 18 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1692        50647             18             0.4773
# 1693         4570             18             0.4387
# 1694       149611             18             0.4136
# 1695         2590             18             0.4076
# 1696        57307             18             0.3991
# 1697        15641             18             0.3838
# 1698        87072             18             0.3457
# 1699        64690             18             0.3361
# 1700        70784             18             0.3148
# 1701        63597             18             0.3039
# 1702        66821             18             0.2783
# 1703        65070             18             0.2494
# 1704       133829             18             0.2135
# 1705         4572             18             0.2038
# 1706       146556             18             0.1988
# 1707        36762             18             0.1942
# 1708        21443             18             0.1801
# 1709        31885             18             0.1801
# 1710        19369             18              0.178
# 1711        24144             18             0.1774
# 1712         9042             18             0.1762
# 1713         9008             18             0.1686
# 1714         4110             18             0.1663
# 1715        36861             18             0.1623
# 1716        21004             18             0.1619
# 1717        81517             18             0.1591
# 1718        27410             18             0.1502
# 1719        52957             18             0.1486
# 1720        69920             18             0.1425
# 1721       117263             18              0.133
# 1722        39521             18             0.1322
#
#                                                Keywords  \
# 1692  north, acc, tech, williams, blue_devils, tar_h...
# 1693  north, acc, tech, williams, blue_devils, tar_h...
# 1694  north, acc, tech, williams, blue_devils, tar_h...
# 1695  north, acc, tech, williams, blue_devils, tar_h...
# 1696  north, acc, tech, williams, blue_devils, tar_h...
# 1697  north, acc, tech, williams, blue_devils, tar_h...
# 1698  north, acc, tech, williams, blue_devils, tar_h...
# 1699  north, acc, tech, williams, blue_devils, tar_h...
# 1700  north, acc, tech, williams, blue_devils, tar_h...
# 1701  north, acc, tech, williams, blue_devils, tar_h...
# 1702  north, acc, tech, williams, blue_devils, tar_h...
# 1703  north, acc, tech, williams, blue_devils, tar_h...
# 1704  north, acc, tech, williams, blue_devils, tar_h...
# 1705  north, acc, tech, williams, blue_devils, tar_h...
# 1706  north, acc, tech, williams, blue_devils, tar_h...
# 1707  north, acc, tech, williams, blue_devils, tar_h...
# 1708  north, acc, tech, williams, blue_devils, tar_h...
# 1709  north, acc, tech, williams, blue_devils, tar_h...
# 1710  north, acc, tech, williams, blue_devils, tar_h...
# 1711  north, acc, tech, williams, blue_devils, tar_h...
# 1712  north, acc, tech, williams, blue_devils, tar_h...
# 1713  north, acc, tech, williams, blue_devils, tar_h...
# 1714  north, acc, tech, williams, blue_devils, tar_h...
# 1715  north, acc, tech, williams, blue_devils, tar_h...
# 1716  north, acc, tech, williams, blue_devils, tar_h...
# 1717  north, acc, tech, williams, blue_devils, tar_h...
# 1718  north, acc, tech, williams, blue_devils, tar_h...
# 1719  north, acc, tech, williams, blue_devils, tar_h...
# 1720  north, acc, tech, williams, blue_devils, tar_h...
# 1721  north, acc, tech, williams, blue_devils, tar_h...
# 1722  north, acc, tech, williams, blue_devils, tar_h...
#
#                                                    Text
# 1692  [time, series, north, tied, past, meetings, no...
# 1693  [photograph, tahj, holden, juan, dixon, lonny,...
# 1694  [ncaa_women, tournament, roundsunday, north, b...
# 1695  [season, acc, tied, ncaa_champion, coach, gary...
# 1696  [yearsitesemifinals, attendancefinal, attendan...
# 1697  [conferences, accounted, sweet, teams_ncaa_tou...
# 1698  [george, lasalle, north, boston_college, tech,...
# 1699  [november, bucknellw, st.w, youngstown, st.w, ...
# 1700  [women, north, saturday, p.m, fetzer, field, c...
# 1701  [ncaa_soccer, quarterfinals, klockner, stadium...
# 1702  [women, led, acc, attendance, winning, ncaa_ti...
# 1703  [record, pop, flat, screen, week, seasons, nor...
# 1704  [michael, jordan, scott, williams, teammates, ...
# 1705  [colleges, ranked, stay, cole, field, house, g...
# 1706  [cooper, flagg, remains, hot, streak, foot, fr...
# 1707  [wake_forest, yesterday, suspended, guard, chr...
# 1708  [north, proof, status, acc, securely, fluke, t...
# 1709  [julius, hodge, plays, lady, row, pure, showma...
# 1710  [dean, smith, retirement, sorely, tested, fait...
# 1711  [colleges, chapel, hill, n.c, hype, warm, spri...
# 1712  [colleges, durham, n.c, tears, blue_devils, wa...
# 1713  [university, forward, chris, wilcox, weeks, sp...
# 1714  [march_madness, basketball, n.y, stories, appe...
# 1715  [northern, exposure, conference, controlled, n...
# 1716  [hand, collection, basketball, talent, atlanti...
# 1717  [correction, march, sports, article, marking, ...
# 1718  [roy_williams, comeuppance, start, atlantic, c...
# 1719  [quality, quantity, variety, guard, conference...
# 1720  [march, north, played, chapel, hill, sorts, na...
# 1721  [celebration, season, basketball, brings, terr...
# 1722  [bc, notebook, chapel, hill, n.c, boston_colle...
# --- Topic 19 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1723       103586             19             0.9511
# 1724       108107             19             0.9511
# 1725        40536             19                0.8
# 1726        49570             19             0.7612
# 1727        80064             19             0.7562
# ...           ...            ...                ...
# 1818        84178             19             0.5681
# 1819        34914             19             0.5675
# 1820       133423             19             0.5674
# 1821       145022             19             0.5667
# 1822       134684             19             0.5665
#
#                                                Keywords  \
# 1723  season, guard, rebounds, forward, assists, sco...
# 1724  season, guard, rebounds, forward, assists, sco...
# 1725  season, guard, rebounds, forward, assists, sco...
# 1726  season, guard, rebounds, forward, assists, sco...
# 1727  season, guard, rebounds, forward, assists, sco...
# ...                                                 ...
# 1818  season, guard, rebounds, forward, assists, sco...
# 1819  season, guard, rebounds, forward, assists, sco...
# 1820  season, guard, rebounds, forward, assists, sco...
# 1821  season, guard, rebounds, forward, assists, sco...
# 1822  season, guard, rebounds, forward, assists, sco...
#
#                                                    Text
# 1723  [season, stats, ncaa, rank, scoring, offense, ...
# 1724  [season, stats, ncaa, rank, scoring, offense, ...
# 1725  [season, pre, season_final, weeks, ranked, nr,...
# 1726  [rebels, feature, players, program, sat, head_...
# 1727  [island, northeast, champion, blackbirds, ncaa...
# ...                                                 ...
# 1818  [record, ten, ten_tournament, lost, indiana, r...
# 1819  [boy, north, connecticut, bracket, possibly, l...
# 1820  [indiana, basketball_team, ten_tournament, sec...
# 1821  [ranked, ap, top, preseason, poll, straight, t...
# 1822  [tv, p.m, cbs, bottom, line, jayhawks, record,...
#
# [100 rows x 5 columns]
# --- Topic 20 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1823        14433             20             0.8957
# 1824       143509             20             0.8499
# 1825        14384             20             0.8248
# 1826       141480             20             0.8137
# 1827       143765             20             0.8067
# ...           ...            ...                ...
# 1918       132667             20             0.6391
# 1919        78602             20             0.6388
# 1920       141484             20             0.6386
# 1921        80829             20             0.6375
# 1922       138576             20             0.6366
#
#                                                Keywords  \
# 1823  sec, season, top, win, bowl, college_football,...
# 1824  sec, season, top, win, bowl, college_football,...
# 1825  sec, season, top, win, bowl, college_football,...
# ...
# 3520  million, money, revenue, pay, contract, paid, ...
# 3521  million, money, revenue, pay, contract, paid, ...
# 3522  million, money, revenue, pay, contract, paid, ...
# 3523  million, money, revenue, pay, contract, paid, ...
#
#                                                    Text
# 3424  [athletics, programs, million, operating, reve...
# 3425  [athletics, reporting, million, deficit, covid...
# 3426  [financial, reports, university, university, c...
# 3427  [athletic, revenue, surpassed, million, time, ...
# 3428  [university, athletics, program, nation, finan...
# ...                                                 ...
# 3519  [determine, total, pay, packages, football, bo...
# 3520  [ncaa_women, basketball, head_coach, salaries,...
# 3521  [athletics, director, tom, jurich, attractive,...
# 3522  [financial, boost, major_college_athletics, pr...
# 3523  [head, football_coaches, major_college, progra...
#
# [100 rows x 5 columns]
# --- Topic 38 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3524       141162             38             0.8508
# 3525        70780             38             0.8022
# 3526        19651             38             0.6803
# 3527        37313             38             0.6655
# 3528        77785             38             0.6075
# ...           ...            ...                ...
# 3619        31025             38               0.46
# 3620        55225             38             0.4594
# 3621        63089             38             0.4587
# 3622        44921             38             0.4585
# 3623        68898             38             0.4585
#
#                                                Keywords  \
# 3524  hockey, boston, nhl, ice, bc, frozen, games, f...
# 3525  hockey, boston, nhl, ice, bc, frozen, games, f...
# 3526  hockey, boston, nhl, ice, bc, frozen, games, f...
# 3527  hockey, boston, nhl, ice, bc, frozen, games, f...
# 3528  hockey, boston, nhl, ice, bc, frozen, games, f...
# ...                                                 ...
# 3619  hockey, boston, nhl, ice, bc, frozen, games, f...
# 3620  hockey, boston, nhl, ice, bc, frozen, games, f...
# 3621  hockey, boston, nhl, ice, bc, frozen, games, f...
# 3622  hockey, boston, nhl, ice, bc, frozen, games, f...
# 3623  hockey, boston, nhl, ice, bc, frozen, games, f...
#
#                                                    Text
# 3524  [college_hockey, ncaa, frozen, xcel, energy, c...
# 3525  [east_regional, unh, cornell, rit, denver, wes...
# 3526  [source:apzfile:zkeyword:bc, hkc, ncaatourname...
# 3527  [ncaa_division, hockey, championship, frozen, ...
# 3528  [past, ncaa_champions, yearchampionrunner, ups...
# ...                                                 ...
# 3619  [storied, history, boston, university, hockey,...
# 3620  [march_madness, bc, unh, hockey_east, semifina...
# 3621  [buunh, manchester, n.h, boston, university, f...
# 3622  [bc, unh, boston_college, ahead, goal, hampshi...
# 3623  [bc, vermont, vermont, yesterday, matinee, bos...
#
# [100 rows x 5 columns]
# --- Topic 39 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3624        33318             39             0.8085
# 3625       104394             39             0.7275
# 3626        57836             39             0.7123
# 3627        26421             39             0.6829
# 3628        57838             39             0.6752
# ...           ...            ...                ...
# 3719        36756             39             0.5179
# 3720        24922             39             0.5177
# 3721         8448             39             0.5161
# 3722        68591             39             0.5154
# 3723        32657             39             0.5152
#
#                                                Keywords  \
# 3624  coach, head_coach, program, coaches, coaching,...
# 3625  coach, head_coach, program, coaches, coaching,...
# 3626  coach, head_coach, program, coaches, coaching,...
# 3627  coach, head_coach, program, coaches, coaching,...
# 3628  coach, head_coach, program, coaches, coaching,...
# ...                                                 ...
# 3719  coach, head_coach, program, coaches, coaching,...
# 3720  coach, head_coach, program, coaches, coaching,...
# 3721  coach, head_coach, program, coaches, coaching,...
# 3722  coach, head_coach, program, coaches, coaching,...
# 3723  coach, head_coach, program, coaches, coaching,...
#
#                                                    Text
# 3624  [short, seasons, coaching, serving, coach, ath...
# 3625  [athletic_director, feb, sports, section, arti...
# 3626  [finalizing, negotiations, waves, coach, tom, ...
# 3627  [college_basketball, introduce, coach, rick, m...
# 3628  [tom, asbury, guided, ncaa_tournament, appeara...
# ...                                                 ...
# 3719  [coach, ray, giacoletti, grew, peoria, bob, be...
# 3720  [dozen, college, head_coaching, jobs, october,...
# 3721  [mark, anderson, review, journal, regina, mill...
# 3722  [boston_college_basketball_coach, cornell, coa...
# 3723  [verge, night, hiring, african, american, coac...
#
# [100 rows x 5 columns]
# --- Topic 40 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3724        63319             40             0.2693
# 3725          495             40             0.2569
# 3726        61073             40             0.2208
# 3727        44737             40              0.217
#
#                                                Keywords  \
# 3724  johnson, thomas, bulls, jordan, cooper, curry,...
# 3725  johnson, thomas, bulls, jordan, cooper, curry,...
# 3726  johnson, thomas, bulls, jordan, cooper, curry,...
# 3727  johnson, thomas, bulls, jordan, cooper, curry,...
#
#                                                    Text
# 3724  [caption, text, illustration, caption, larry, ...
# 3725  [lakers, superstar, earvin, magic, johnson, in...
# 3726  [magic, johnson, relationship, larry, bird, jo...
# 3727  [kareem, abdul, jabbar, absolutely, dominated,...
# --- Topic 41 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3728        73765             41             0.2305
# 3729       101115             41                0.2
# 3730        55331             41             0.1764
# 3731        58112             41             0.1738
# 3732        43139             41             0.1394
# 3733        85043             41             0.1362
#
#                                                Keywords  \
# 3728  clark, wildcats, wright, calipari, cronin, bro...
# 3729  clark, wildcats, wright, calipari, cronin, bro...
# 3730  clark, wildcats, wright, calipari, cronin, bro...
# 3731  clark, wildcats, wright, calipari, cronin, bro...
# 3732  clark, wildcats, wright, calipari, cronin, bro...
# 3733  clark, wildcats, wright, calipari, cronin, bro...
#
#                                                    Text
# 3728  [gonzalez, ford, bob, fox, ashley, subject, du...
# 3729  [captain, ahab, white, whale, stony_brook, bas...
# 3730  [larry, brown, conflicted, coach, peach, baske...
# 3731  [scottie, reynolds, world, figured, phone, ran...
# 3732  [allan, ray, waited, week, watch, stomach, vid...
# 3733  [signs, stony_brook, basketball, success, seaw...
# --- Topic 42 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3734        69272             42             0.3156
# 3735        96054             42             0.2757
# 3736        14760             42             0.2636
# 3737        11566             42             0.2464
# 3738       147801             42              0.243
# 3739       147701             42             0.2287
# 3740         7340             42             0.2201
# 3741       120093             42             0.2189
# 3742         5014             42              0.208
# 3743         3576             42             0.2058
# 3744         7255             42             0.2043
# 3745        24535             42             0.2002
# 3746         9756             42             0.1999
# 3747        20449             42             0.1909
# 3748        81649             42             0.1909
# 3749         2931             42             0.1867
# 3750       118051             42             0.1856
# 3751       129443             42             0.1807
# 3752       115402             42             0.1765
# 3753        46676             42             0.1696
# 3754          506             42             0.1667
# 3755        21170             42             0.1589
# 3756       122092             42             0.1529
# 3757         8865             42             0.1468
# 3758        22406             42             0.1276
#
#                                                Keywords  \
# 3734  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3735  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3736  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3737  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3738  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3739  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3740  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3741  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3742  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3743  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3744  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3745  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3746  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3747  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3748  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3749  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3750  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3751  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3752  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3753  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3754  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3755  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3756  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3757  gonzaga, san_diego, gymnastics, bulldogs, usf,...
# 3758  gonzaga, san_diego, gymnastics, bulldogs, usf,...
#
#                                                    Text
# 3734  [top_ranked, women, gymnastics, team, won, aft...
# 3735  [women, gymnastics, coach, spini, coaching, ru...
# 3736  [freshman, kate, richardson, accomplished, goa...
# 3737  [balance, start, left, deal, women, gymnastics...
# 3738  [sooners, women, gymnastics, team, sooners, su...
# 3739  [gymnastics, historically, boasts, olympians, ...
# 3740  [clay, strother, minnesota, repeated, champion...
# 3741  [gymnastics, stakes, ncaa, semifinals, teams, ...
# 3742  [jamie, dantzscher, score, uneven, bars, final...
# 3743  [college_basketball, dan, dickau, transferred,...
# 3744  [tonight, clock, gonzaga, arena, spokane, wash...
# 3745  [pushed, quartet, flying, energy, performances...
# 3746  [pick, poison, angle, ncaa, gymnastics, champi...
# 3747  [women, gymnastics, team, marched, pauley, pav...
# 3748  [kat, ding, waited, career, prove, uneven, bar...
# 3749  [jamie, dantzscher, ran, energy, competing, ev...
# 3750  [won, pac, championship, saturday, joy, kyla, ...
# 3751  [history, hung, directly, heads, written, bann...
# 3752  [competing, university, minnesota, maturi, pav...
# 3753  [sounds, broken, record, fix, gymnastics, team...
# 3754  [pac, gymnastics, championships, break, season...
# 3755  [ncaa_title, golden, bears, dominated, qualify...
# 3756  [brielle, nguyen, performs, beam, ncaa, colleg...
# 3757  [appearing, national, television, players, cou...
# 3758  [returning, nationals, women, gymnastics, team...
# --- Topic 43 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3759        33969             43             0.6818
# 3760        53099             43             0.6406
# 3761        76949             43             0.6341
# 3762        62398             43             0.6335
# 3763        14041             43             0.6237
# ...           ...            ...                ...
# 3854        47855             43             0.4872
# 3855        53907             43             0.4857
# 3856       112951             43             0.4852
# 3857        12636             43             0.4846
# 3858        61783             43             0.4846
#
#                                                Keywords  \
# 3759  fans, time, people, sports, day, moment, artic...
# 3760  fans, time, people, sports, day, moment, artic...
# 3761  fans, time, people, sports, day, moment, artic...
# 3762  fans, time, people, sports, day, moment, artic...
# 3763  fans, time, people, sports, day, moment, artic...
# ...                                                 ...
# 3854  fans, time, people, sports, day, moment, artic...
# 3855  fans, time, people, sports, day, moment, artic...
# 3856  fans, time, people, sports, day, moment, artic...
# 3857  fans, time, people, sports, day, moment, artic...
# 3858  fans, time, people, sports, day, moment, artic...
#
#                                                    Text
# 3759  [ncaa_tournament, diary, mad, fan, day, road, ...
# 3760  [wondering, classes, empty, wearing, gold, blu...
# 3761  [week, reader, wrote, concerned, succumbed, di...
# 3762  [lot, spam, usual, republic, spam, filter, blo...
# 3763  [bombs, fall, baghdad, grisham, nightstand, mi...
# ...                                                 ...
# 3854  [guys, wearing, blue, sweatshirts, letter, fro...
# 3855  [feeling, left, office, follow, college_basket...
# 3856  [enter, couch, slouch, wishes, war, world, jim...
# 3857  [peek, window, beautiful, morning, watch, peop...
# 3858  [love, ncaa_tournament, painful, watch, teams,...
#
# [100 rows x 5 columns]
# --- Topic 44 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 3859       105853             44             0.8569
# 3860        46221             44             0.8142
# 3861        24351             44             0.8044
# 3862        59896             44             0.7981
# 3863         5126             44             0.7976
# ...           ...            ...                ...
# 3954        14254             44             0.7046
# 3955       128111             44             0.7041
# 3956        36903             44             0.7032
# 3957        82867             44             0.7031
# 3958        56636             44             0.7028
#
#                                                Keywords  \
# 3859  half, lead, minutes, shot, left, rebounds, pla...
# 3860  half, lead, minutes, shot, left, rebounds, pla...
# 3861  half, lead, minutes, shot, left, rebounds, pla...
# 3862  half, lead, minutes, shot, left, rebounds, pla...
# 3863  half, lead, minutes, shot, left, rebounds, pla...
# ...                                                 ...
# 3954  half, lead, minutes, shot, left, rebounds, pla...
# 3955  half, lead, minutes, shot, left, rebounds, pla...
# 3956  half, lead, minutes, shot, left, rebounds, pla...
# 3957  half, lead, minutes, shot, left, rebounds, pla...
# 3958  half, lead, minutes, shot, left, rebounds, pla...
#
#                                                    Text
# 3859  [grayson, allen, including, pointers, seed, fe...
# 3860  [ncaa_final, indiana, sacramento, arron, affla...
# 3861  [deron, williams, released, ball, fourth, poin...
# 3862  [complemented, stifling, defense, balanced, of...
# 3863  [madison, wis, personal, fouls, nick, collison...
# ...                                                 ...
# 3954  [cushion, leading, minutes, play, seeded, foun...
# 3955  [halftime, deficit, win, requires, improvement...
# 3956  [special, section, ncaa_tournament, elite, reg...
# 3957  [saturday, night, national, semifinal, superdo...
# 3958  [vulnerable, memphis, humiliated, friday, nigh...
#
# [100 rows x 5 columns]

# %%
# Define the path to save the Excel file in your Google Drive
excel_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_45_topics.xlsx'

# Save the DataFrame to an Excel file
try:
    top_100_documents_per_topic.to_excel(excel_file_path, index=False)
    print(f"Successfully saved the top 100 documents per topic to: {excel_file_path}")
except Exception as e:
    print(f"An error occurred while saving the Excel file: {e}")
# Out:
# Successfully saved the top 100 documents per topic to: /content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_45_topics.xlsx

# %% [markdown]
# ##### **© 2024–2025 MD Rafsun Sheikh**
# ##### **Licensed under the Apache License, Version 2.0.**
