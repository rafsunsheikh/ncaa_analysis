# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from gensim.models.ldamodel import LdaModel

# Load the LDA model
loaded_lda_model = LdaModel.load('/content/drive/MyDrive/Colab Notebooks/alex/models/lda_25_topics/lda_model_25_topics.gensim')

# Now you can access information from the loaded model.
# For example, you can print the topics:
print("Topics:")
for topic_id, topic in loaded_lda_model.print_topics():
    print(f"Topic {topic_id}: {topic}")

# You can also access the dictionary (id2word)
print("\nDictionary:")
print(loaded_lda_model.id2word)

# And the number of topics
print("\nNumber of topics:")
print(loaded_lda_model.num_topics)
# Out:
# Topics:
# Topic 21: 0.022*"team" + 0.017*"players" + 0.016*"time" + 0.014*"play" + 0.014*"lot" + 0.010*"playing" + 0.010*"coach" + 0.009*"season" + 0.008*"guys" + 0.007*"player"
# Topic 16: 0.039*"nba" + 0.019*"draft" + 0.019*"basketball" + 0.017*"league" + 0.014*"pick" + 0.013*"player" + 0.011*"star" + 0.009*"season" + 0.008*"celtics" + 0.008*"lakers"
# Topic 8: 0.025*"injury" + 0.019*"season" + 0.016*"injuries" + 0.015*"health" + 0.012*"week" + 0.011*"surgery" + 0.010*"practice" + 0.010*"return" + 0.010*"day" + 0.009*"knee"
# Topic 9: 0.048*"coach" + 0.020*"program" + 0.018*"coaches" + 0.017*"season" + 0.016*"coaching" + 0.016*"head_coach" + 0.014*"seasons" + 0.012*"job" + 0.010*"school" + 0.009*"basketball"
# Topic 3: 0.022*"st" + 0.020*"tech" + 0.019*"south" + 0.014*"scored" + 0.013*"north" + 0.011*"gamecocks" + 0.009*"win" + 0.009*"round" + 0.009*"mississippi" + 0.008*"acc"
# Topic 24: 0.022*"half" + 0.017*"lead" + 0.015*"minutes" + 0.013*"shot" + 0.013*"left" + 0.011*"scored" + 0.010*"play" + 0.010*"rebounds" + 0.010*"win" + 0.009*"quarter"
# Topic 5: 0.020*"ncaa" + 0.009*"investigation" + 0.008*"university" + 0.008*"court" + 0.007*"statement" + 0.006*"told" + 0.005*"players" + 0.005*"federal" + 0.005*"report" + 0.005*"lawsuit"
# Topic 14: 0.024*"seed" + 0.024*"tournament" + 0.023*"final" + 0.019*"ncaa_tournament" + 0.019*"team" + 0.017*"round" + 0.015*"teams" + 0.013*"win" + 0.011*"sweet" + 0.011*"march_madness"
# Topic 15: 0.054*"gophers" + 0.041*"minnesota" + 0.028*"hockey" + 0.016*"goals" + 0.016*"season" + 0.015*"nhl" + 0.014*"games" + 0.012*"goal" + 0.012*"play" + 0.010*"ten"
# Topic 10: 0.031*"conference" + 0.028*"teams" + 0.024*"games" + 0.021*"team" + 0.021*"season" + 0.019*"ten" + 0.017*"top" + 0.015*"win" + 0.013*"sec" + 0.012*"play"
# Topic 1: 0.050*"golf" + 0.016*"round" + 0.015*"championship" + 0.012*"shot" + 0.012*"club" + 0.011*"tour" + 0.011*"tournament" + 0.010*"par" + 0.010*"pga_tour" + 0.010*"woods"
# Topic 19: 0.025*"san_diego" + 0.019*"mexico" + 0.018*"cronin" + 0.016*"watkins" + 0.015*"march" + 0.014*"byu" + 0.014*"grand_canyon" + 0.014*"gcu" + 0.013*"loyola" + 0.013*"dakota"
# Topic 20: 0.022*"yards" + 0.020*"college_football" + 0.020*"quarterback" + 0.016*"season" + 0.016*"bowl" + 0.015*"football" + 0.010*"week" + 0.010*"field" + 0.008*"defensive" + 0.008*"touchdowns"
# Topic 23: 0.042*"boston" + 0.030*"globe" + 0.023*"eagles" + 0.022*"bc" + 0.018*"boston_college" + 0.017*"providence" + 0.017*"maine" + 0.016*"bu" + 0.016*"massachusetts" + 0.014*"university"
# Topic 18: 0.010*"nil" + 0.009*"fans" + 0.007*"people" + 0.007*"sports" + 0.007*"time" + 0.004*"day" + 0.004*"moment" + 0.004*"story" + 0.004*"told" + 0.003*"media"
# Topic 0: 0.061*"school" + 0.022*"college" + 0.020*"players" + 0.014*"recruiting" + 0.014*"basketball" + 0.013*"schools" + 0.013*"transfer" + 0.012*"class" + 0.011*"athletic" + 0.010*"program"
# Topic 17: 0.141*"women" + 0.085*"p.m" + 0.038*"espn" + 0.038*"south" + 0.028*"basketball" + 0.027*"wnba" + 0.016*"march" + 0.015*"winner" + 0.015*"sunday" + 0.013*"friday"
# Topic 2: 0.014*"sports" + 0.014*"athletes" + 0.013*"ncaa" + 0.012*"schools" + 0.010*"million" + 0.007*"university" + 0.007*"money" + 0.007*"football" + 0.006*"college_sports" + 0.006*"revenue"
# Topic 13: 0.019*"sports" + 0.016*"tv" + 0.014*"network" + 0.014*"games" + 0.013*"espn" + 0.011*"watch" + 0.010*"live" + 0.009*"cbs" + 0.007*"fans" + 0.007*"streaming"
# Topic 12: 0.026*"league" + 0.022*"nfl" + 0.014*"baseball" + 0.013*"season" + 0.011*"team" + 0.010*"million" + 0.008*"york" + 0.008*"games" + 0.008*"professional" + 0.008*"manager"
#
# Dictionary:
# Dictionary<264174 unique tokens: ['absolutely', 'accepting', 'accommodations', 'accordance', 'account']...>
#
# Number of topics:
# 25

# %%
from gensim import corpora

# Load the corpus from the .mm file
corpus = corpora.MmCorpus('/content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/corpus.mm')

print("Corpus loaded successfully.")
# You can optionally print the corpus to inspect its structure
# print(list(corpus))
# Out:
# Corpus loaded successfully.

# %%
import json
import pandas as pd

# Assuming your JSON file contains a list of lists, where each inner list is a tokenized document
# Replace '/content/drive/MyDrive/path/to/your/texts.json' with the actual path to your JSON file
texts_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/texts.json'

with open(texts_file_path, 'r') as f:
    texts = json.load(f)

print(f"Loaded {len(texts)} documents from {texts_file_path}")
# Out:
# Loaded 149649 documents from /content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/texts.json

# %%
# import pandas as pd

# # Load the tokenized data from the Excel file
# try:
#     tokenized_data_df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/alex/updated_ tokenized_newspaper_data.xlsx')
#     print("Excel file loaded successfully.")
#     # Assuming the original text is in a column named 'text' or similar.
#     # Please adjust the column name if it's different in your Excel file.
#     if 'Main_text_tokenized' in tokenized_data_df.columns:
#         texts = tokenized_data_df['Main_text_tokenized'].tolist()
#         print(f"Extracted {len(texts)} documents.")
#     else:
#         texts = None
#         print("Could not find a 'text' column in the Excel file. Please make sure the column containing original texts is named 'text' or update the code.")

# except FileNotFoundError:
#     print("Error: The file was not found at the specified path.")
# except Exception as e:
#     print(f"An error occurred while reading the Excel file: {e}")

# %%
#TFinding the dominant topic in each sentence
import pandas as pd


def format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts): # Updated to use loaded_lda_model and corpus, and texts=None
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = pd.concat([sent_topics_df, pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]).to_frame().T], ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

     # Add original text to the end of the output
    if texts is not None: # Added check if texts is not None
        contents = pd.Series(texts)
        sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


# Assuming texts is available as data_words or you provide another list/Series of texts
# df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts) # Updated to use loaded_lda_model and corpus, commented out as data_words is undefined
# To run this cell, define `data_words` with your text data before calling the function.
# For example:
# data_words = ["your document text 1", "your document text 2", ...]
# Then uncomment the line below:
df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts)

# Format
if 'df_topic_sents_keywords' in locals(): # Added check if df_topic_sents_keywords is defined
    df_dominant_topic = df_topic_sents_keywords.reset_index()
    df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
    # Show
    display(df_dominant_topic.head(20)) # Use display for better formatting
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0              4             0.3268
# 1             1              4             0.2134
# 2             2             16             0.3215
# 3             3              7              0.182
# 4             4              5             0.2354
# 5             5             11             0.3559
# 6             6             12             0.2198
# 7             7             12             0.1571
# 8             8             21             0.2327
# 9             9              4             0.3432
# 10           10             14             0.1631
# 11           11              1             0.3518
# 12           12             21             0.2524
# 13           13              0             0.2838
# 14           14             18             0.3314
# 15           15              2              0.597
# 16           16             12             0.3186
# 17           17              5             0.4243
# 18           18             16             0.3884
# 19           19             14             0.3891
#
#                                              Keywords  \
# 0   family, school, life, people, home, black, cit...
# 1   family, school, life, people, home, black, cit...
# 2   nba, draft, basketball, league, pick, player, ...
# 3   olympic, women, world, won, time, united, olym...
# 4   ncaa, investigation, university, court, statem...
# 5   softball, regional, baseball, tbd, harbaugh, i...
# 6   league, nfl, baseball, season, team, million, ...
# 7   league, nfl, baseball, season, team, million, ...
# 8   team, players, time, play, lot, playing, coach...
# 9   family, school, life, people, home, black, cit...
# 10  seed, tournament, final, ncaa_tournament, team...
# 11  golf, round, championship, shot, club, tour, t...
# 12  team, players, time, play, lot, playing, coach...
# 13  school, college, players, recruiting, basketba...
# 14  nil, fans, people, sports, time, day, moment, ...
# 15  sports, athletes, ncaa, schools, million, univ...
# 16  league, nfl, baseball, season, team, million, ...
# 17  ncaa, investigation, university, court, statem...
# 18  nba, draft, basketball, league, pick, player, ...
# 19  seed, tournament, final, ncaa_tournament, team...
#
#                                                  Text
# 0   [coaching, living, bonnie, henrickson, phone, ...
# 1   [sidebar, ruston, la, dining, louisiana, cajun...
# 2   [garden, missed, lonely, nights, season, debut...
# 3   [ten, ago, chuck, daly, reclining, alongside, ...
# 4   [robinson, talk, rangers, stanley, cup, finals...
# 5   [conference, pacific, coach_mike, gillespie, s...
# 6   [rangers, signed, center, michael, nylander, m...
# 7   [gavitt, elected, hall, modest, player, dartmo...
# 8   [mythical, element, senior_guard, seimone, aug...
# 9   [ncaa_women, jim, izard, diana, vines, remembe...
# 10  [meet, george_mason, guard, lamar, butler, jai...
# 11  [kevin, iole, review, journal, local, golf, cl...
# 12  [seventh, time, coach, beilein, process, movin...
# 13  [demetrius, jones, talk, anymore, monday, iris...
# 14  [oakland, eating, gilbert, arenas, check, blog...
# 15  [bothered, myles, brand, term, dumb, jock, bra...
# 16  [lot, guessing, season, trade, twins, manager,...
# 17  [college, pa, n.c.a.a, penn, letter, announcin...
# 18  [person, called, call, cheryl, miller, stage, ...
# 19  [selection_sunday, month, ncaa, selection_comm...

# %%
# Display the first few rows of the dataframe to see the structure
display(df_dominant_topic.head())
# Out:
#    Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0            0              4             0.3268
# 1            1              4             0.2134
# 2            2             16             0.3215
# 3            3              7              0.182
# 4            4              5             0.2354
#
#                                             Keywords  \
# 0  family, school, life, people, home, black, cit...
# 1  family, school, life, people, home, black, cit...
# 2  nba, draft, basketball, league, pick, player, ...
# 3  olympic, women, world, won, time, united, olym...
# 4  ncaa, investigation, university, court, statem...
#
#                                                 Text
# 0  [coaching, living, bonnie, henrickson, phone, ...
# 1  [sidebar, ruston, la, dining, louisiana, cajun...
# 2  [garden, missed, lonely, nights, season, debut...
# 3  [ten, ago, chuck, daly, reclining, alongside, ...
# 4  [robinson, talk, rangers, stanley, cup, finals...

# %%
# Sort documents within each topic by percentage contribution in descending order
sorted_documents_by_topic = df_dominant_topic.sort_values(by=['Dominant_Topic', 'Topic_Perc_Contrib'], ascending=[True, False])

# Display the sorted document indexes for each topic
print("Document Indexes for Each Topic (Sorted by Percentage Contribution):")
for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    print(f"\nTopic {topic_num}:")
    # Get documents for the current topic and select only the 'Document_No' column
    topic_documents = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num]['Document_No']
    # Display the document indexes (first 20 as an example)
    print(topic_documents.tolist()[:20])
# Out:
# Document Indexes for Each Topic (Sorted by Percentage Contribution):
#
# Topic 0:
# [51440, 39630, 3498, 118640, 94794, 85634, 16581, 22224, 66098, 110007, 4279, 2260, 71500, 39014, 16008, 40054, 29020, 61097, 100026, 36857]
#
# Topic 1:
# [9885, 31667, 22335, 3512, 243, 81958, 23306, 13752, 6144, 40863, 19345, 40013, 117858, 30483, 37017, 60212, 22333, 58390, 15915, 105625]
#
# Topic 2:
# [70093, 98680, 93669, 72246, 32693, 120467, 127833, 55312, 80907, 10627, 90129, 86931, 63770, 89542, 131066, 65807, 20809, 86921, 70656, 89525]
#
# Topic 3:
# [83656, 94717, 37244, 37334, 105828, 70761, 18918, 8994, 14751, 143432, 111590, 43636, 35554, 63909, 44086, 131802, 148813, 100981, 62250, 43348]
#
# Topic 4:
# [63005, 69341, 3633, 23151, 13387, 95419, 25149, 53231, 69979, 60321, 67091, 45848, 50851, 15526, 21668, 15527, 45315, 100772, 89887, 71202]
#
# Topic 5:
# [115822, 28071, 92453, 100438, 112277, 49012, 14542, 121819, 83434, 14925, 46933, 124713, 77012, 49104, 94364, 43182, 25870, 91429, 61206, 116620]
#
# Topic 6:
# [18303, 68273, 64747, 32451, 50034, 10882, 70139, 105692, 5280, 64696, 17373, 56426, 110228, 20268, 70699, 77560, 41769, 76819, 110229, 7314]
#
# Topic 7:
# [29548, 31478, 131394, 24654, 27087, 24538, 25689, 82981, 11698, 66261, 21228, 130956, 30, 99377, 59317, 145517, 89016, 3767, 141745, 79667]
#
# Topic 8:
# [37020, 52293, 28031, 9360, 66216, 69030, 119253, 43660, 1749, 52335, 148960, 13570, 69509, 27532, 140872, 125649, 36081, 62370, 136412, 87384]
#
# Topic 9:
# [33318, 77165, 51773, 26421, 37781, 57838, 57836, 104394, 4722, 42447, 40702, 34824, 42557, 119910, 109173, 73608, 7469, 4568, 23892, 22947]
#
# Topic 10:
# [9268, 121452, 85375, 74728, 76923, 34003, 108765, 52799, 86590, 46542, 81704, 95228, 46543, 52418, 101729, 72577, 6120, 106185, 89821, 73943]
#
# Topic 11:
# [69462, 44067, 36369, 130034, 69472, 36372, 71612, 28686, 67538, 49905, 38487, 10913, 69478, 93624, 116699, 113421, 113597, 61182, 10927, 69475]
#
# Topic 12:
# [126468, 28432, 108575, 10113, 47910, 62425, 47747, 75230, 31013, 137331, 142968, 102714, 101875, 46063, 39670, 111070, 19749, 124065, 142881, 20298]
#
# Topic 13:
# [120341, 38760, 10769, 108918, 149605, 110322, 110321, 110323, 112966, 113763, 19515, 12239, 29105, 31164, 20913, 38435, 53124, 83258, 80633, 77336]
#
# Topic 14:
# [98052, 71026, 63459, 65922, 11459, 98925, 58832, 75711, 43637, 130942, 97465, 147027, 26855, 48121, 35, 44112, 57420, 107231, 10610, 64632]
#
# Topic 15:
# [26828, 55563, 112236, 55572, 2556, 137276, 137265, 2885, 55564, 138338, 98022, 141162, 88350, 39980, 137275, 73418, 102043, 84684, 104726, 4713]
#
# Topic 16:
# [8388, 80593, 60308, 4837, 46827, 120014, 120015, 148177, 24210, 94545, 27269, 101871, 50512, 26174, 46828, 35678, 29134, 50511, 50513, 1242]
#
# Topic 17:
# [24515, 143357, 105775, 63449, 63962, 72182, 74777, 98702, 98701, 98705, 102704, 41808, 41837, 129430, 83507, 71814, 37315, 83670, 138306, 94853]
#
# Topic 18:
# [77117, 9381, 93644, 95048, 67758, 29147, 47819, 95281, 95772, 45138, 22039, 53099, 39585, 67375, 104432, 81914, 142520, 59948, 94020, 143015]
#
# Topic 19:
# [100403, 52480, 114735, 40536, 24413, 71606, 80911, 41395, 70762, 24415, 42463, 58010, 24412, 73082, 37651, 24414, 45242, 80814, 56721, 51027]
#
# Topic 20:
# [13039, 57020, 13038, 12832, 13040, 26733, 76222, 35344, 79022, 67193, 3302, 116696, 33656, 116669, 140851, 96842, 42313, 116998, 83508, 592]
#
# Topic 21:
# [37585, 86459, 59253, 65980, 137868, 59849, 53939, 90303, 108188, 131752, 76756, 66918, 91712, 34996, 119259, 122193, 53397, 108193, 55253, 7113]
#
# Topic 22:
# [18356, 27521, 11900, 72259, 13930, 37734, 39787, 134126, 24567, 76583, 52217, 3845, 145021, 67060, 73864, 63693, 58663, 35360, 117122, 12357]
#
# Topic 23:
# [67634, 136091, 58995, 77373, 90045, 93888, 103436, 41604, 131793, 14236, 28696, 28695, 106887, 37213, 82143, 119090, 112364, 5024, 100402, 109670]
#
# Topic 24:
# [33116, 43920, 5628, 43921, 13606, 3820, 16319, 15665, 4918, 105853, 68362, 79128, 15504, 99638, 74512, 60430, 51825, 49936, 127741, 11372]

# %%
# Get the total number of documents for each dominant topic
topic_counts = df_dominant_topic['Dominant_Topic'].value_counts().sort_index()

print("Total number of documents for each topic:")
display(topic_counts)
# Out:
# Total number of documents for each topic:
# Dominant_Topic
# 0      3518
# 1      2473
# 2     10361
# 3      3072
# 4      5576
# 5      6502
# 6      3322
# 7      9731
# 8      1274
# 9      6469
# 10     7599
# 11     5370
# 12     3728
# 13     4141
# 14     8774
# 15     3633
# 16     4279
# 17     1079
# 18     7637
# 19      504
# 20     9937
# 21    15014
# 22     7555
# 23      981
# 24    17120
# Name: count, dtype: int64

# %%
# Get the top 100 documents for each topic
top_100_documents_per_topic = pd.DataFrame()

for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    # Get the top 100 documents for the current topic
    top_100 = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num].head(100)
    # Append to the results DataFrame
    top_100_documents_per_topic = pd.concat([top_100_documents_per_topic, top_100], ignore_index=True)

# Display the top 100 documents for each topic
print("Top 100 Documents for Each Topic (Sorted by Percentage Contribution):")

# Iterate through topics and display the top documents for each
for topic_num in top_100_documents_per_topic['Dominant_Topic'].unique():
    print(f"\n--- Topic {topic_num} ---")
    display(top_100_documents_per_topic[top_100_documents_per_topic['Dominant_Topic'] == topic_num])
# Out:
# Top 100 Documents for Each Topic (Sorted by Percentage Contribution):
#
# --- Topic 0 ---
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0         51440              0             0.8153
# 1         39630              0             0.7653
# 2          3498              0             0.6688
# 3        118640              0             0.6625
# 4         94794              0             0.6573
# ..          ...            ...                ...
# 95        84483              0              0.498
# 96         3330              0             0.4978
# 97        29648              0             0.4974
# 98        32481              0             0.4974
# 99       110163              0             0.4974
#
#                                              Keywords  \
# 0   school, college, players, recruiting, basketba...
# 1   school, college, players, recruiting, basketba...
# 2   school, college, players, recruiting, basketba...
# 3   school, college, players, recruiting, basketba...
# 4   school, college, players, recruiting, basketba...
# ..                                                ...
# 95  school, college, players, recruiting, basketba...
# 96  school, college, players, recruiting, basketba...
# 97  school, college, players, recruiting, basketba...
# 98  school, college, players, recruiting, basketba...
# 99  school, college, players, recruiting, basketba...
#
#                                                  Text
# 0   [school, players, expected, sign, national, le...
# 1   [college_basketball, article, tuesday, sports,...
# 2   [ahmad, brooks, met, defensive, football_playe...
# 3   [richard, pitino, recruiting, picking, gophers...
# 4   [anthony, lee, decided, transfer, temple, reds...
# ..                                                ...
# 95  [ron, darby, awe, walked, campus, spring, poto...
# 96  [ncaa, investigate, camp, spokeswoman, ncaa, p...
# 97  [nba, minimum, draft, age, affect, prep, schoo...
# 98  [father, school, senior, grown, understand, tr...
# 99  [loaded, top, notch, talent, transfers, added,...
#
# [100 rows x 5 columns]
# --- Topic 1 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 100         9885              1             0.8911
# 101        31667              1             0.8689
# 102        22335              1             0.8632
# 103         3512              1             0.8401
# 104          243              1             0.8358
# ..           ...            ...                ...
# 195         2151              1             0.7085
# 196         2870              1             0.7081
# 197        46429              1             0.7077
# 198        45336              1             0.7053
# 199       100079              1             0.7049
#
#                                               Keywords  \
# 100  golf, round, championship, shot, club, tour, t...
# 101  golf, round, championship, shot, club, tour, t...
# 102  golf, round, championship, shot, club, tour, t...
# 103  golf, round, championship, shot, club, tour, t...
# 104  golf, round, championship, shot, club, tour, t...
# ..                                                 ...
# 195  golf, round, championship, shot, club, tour, t...
# 196  golf, round, championship, shot, club, tour, t...
# 197  golf, round, championship, shot, club, tour, t...
# 198  golf, round, championship, shot, club, tour, t...
# 199  golf, round, championship, shot, club, tour, t...
#
#                                                   Text
# 100  [golf, jim, ahern, shot, stroke, lead, round, ...
# 101  [trip, masters, rewarding, mesa, resident, mar...
# 102  [annika, sorenstam, mad, finished, birdies, gr...
# 103  [top, somethings, chasing, tiger, woods, david...
# 104  [golf, vijay, singh, blew, tiger, woods, rest,...
# ..                                                 ...
# 195  [laura, diaz, shot, par, yesterday, lead, lpga...
# 196  [billy, andrade, shot, consecutive, round, mai...
# 197  [stacy, lewis, finished, atop, leaderboard, re...
# 198  [dave, shelburne, golf, column, appears, wedne...
# 199  [davis, love, iii, victory, drought, tiger, wo...
#
# [100 rows x 5 columns]
# --- Topic 2 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 200        70093              2             0.9556
# 201        98680              2             0.9432
# 202        93669              2             0.9382
# 203        72246              2             0.9242
# 204        32693              2              0.923
# ..           ...            ...                ...
# 295       138231              2             0.8404
# 296        97223              2               0.84
# 297        18114              2             0.8398
# 298       125064              2             0.8387
# 299        98612              2             0.8385
#
#                                               Keywords  \
# 200  sports, athletes, ncaa, schools, million, univ...
# 201  sports, athletes, ncaa, schools, million, univ...
# 202  sports, athletes, ncaa, schools, million, univ...
# 203  sports, athletes, ncaa, schools, million, univ...
# 204  sports, athletes, ncaa, schools, million, univ...
# ..                                                 ...
# 295  sports, athletes, ncaa, schools, million, univ...
# 296  sports, athletes, ncaa, schools, million, univ...
# 297  sports, athletes, ncaa, schools, million, univ...
# 298  sports, athletes, ncaa, schools, million, univ...
# 299  sports, athletes, ncaa, schools, million, univ...
#
#                                                   Text
# 200  [calling, increasing, funding, college_sports,...
# 201  [recent, ncaa_rules, resulting, major_college_...
# 202  [morning, ncaa, board, directors, scheduled, v...
# 203  [nation, profile, college, athletic, programs,...
# 204  [university, president, peter, likins, chair, ...
# ..                                                 ...
# 295  [groundbreaking, move, transform, college_athl...
# 296  [national, collegiate, athletic, association, ...
# 297  [colleges, universities, allowed, limit, schol...
# 298  [ncaa, committees, studying, division, schools...
# 299  [difference, university, cover, athletic, scho...
#
# [100 rows x 5 columns]
# --- Topic 3 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 300        83656              3             0.9435
# 301        94717              3             0.9127
# 302        37244              3             0.8853
# 303        37334              3             0.8692
# 304       105828              3             0.8546
# ..           ...            ...                ...
# 395       103727              3             0.6653
# 396        72861              3             0.6652
# 397        94994              3             0.6649
# 398        43652              3             0.6609
# 399       146298              3             0.6608
#
#                                               Keywords  \
# 300  st, tech, south, scored, north, gamecocks, win...
# 301  st, tech, south, scored, north, gamecocks, win...
# 302  st, tech, south, scored, north, gamecocks, win...
# 303  st, tech, south, scored, north, gamecocks, win...
# 304  st, tech, south, scored, north, gamecocks, win...
# ..                                                 ...
# 395  st, tech, south, scored, north, gamecocks, win...
# 396  st, tech, south, scored, north, gamecocks, win...
# 397  st, tech, south, scored, north, gamecocks, win...
# 398  st, tech, south, scored, north, gamecocks, win...
# 399  st, tech, south, scored, north, gamecocks, win...
#
#                                                   Text
# 300  [east, st, south, xavier, lehigh, west, st, st...
# 301  [teamconference, americanpatriot, coastal, car...
# 302  [siena, xavier, gonzaga, st, appalachian, st, ...
# 303  [penn, dominion, fairfield, tcu, ball, st, san...
# 304  [peayohio, valley, chattanoogasouthern, gulf, ...
# ..                                                 ...
# 395  [yogi, ferrell, assists, final_home, troy_will...
# 396  [brett, benzio, scored, grabbed, rebounds, tul...
# 397  [team, conference, coastal, carolinabig, south...
# 398  [donald, copeland, scored, seton, hall, final,...
# 399  [norfolk, howard, kierra, wheeler, diamond, jo...
#
# [100 rows x 5 columns]
# --- Topic 4 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 400        63005              4             0.8345
# 401        69341              4             0.7999
# 402         3633              4             0.7756
# 403        23151              4             0.7646
# 404        13387              4             0.7393
# ..           ...            ...                ...
# 495        83966              4             0.5771
# 496       105959              4             0.5767
# 497        51373              4             0.5757
# 498        25972              4             0.5744
# 499        80125              4             0.5744
#
#                                               Keywords  \
# 400  family, school, life, people, home, black, cit...
# 401  family, school, life, people, home, black, cit...
# 402  family, school, life, people, home, black, cit...
# 403  family, school, life, people, home, black, cit...
# 404  family, school, life, people, home, black, cit...
# ..                                                 ...
# 495  family, school, life, people, home, black, cit...
# 496  family, school, life, people, home, black, cit...
# 497  family, school, life, people, home, black, cit...
# 498  family, school, life, people, home, black, cit...
# 499  family, school, life, people, home, black, cit...
#
#                                                   Text
# 400  [daniel, bugey, darby, postmaster, daniel, bug...
# 401  [glen, allen, al, omans, mount, airy, professo...
# 402  [rhoda, katz, netsky, retired, teacher, rhoda,...
# 403  [george, dernoeden, editorial, assistant, geor...
# 404  [ruth, blanck, hospital, volunteer, ruth, baum...
# ..                                                 ...
# 495  [civil, rights, public, service, author, belov...
# 496  [catching, travel, odds, weeks, vacation, york...
# 497  [amy, brecht, perkiomen, township, janice, wag...
# 498  [boston, uncommon, getaway, mexican, dining, h...
# 499  [trinity, united, church, christ, changed, pri...
#
# [100 rows x 5 columns]
# --- Topic 5 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 500       115822              5             0.8448
# 501        28071              5             0.8283
# 502        92453              5             0.8215
# 503       100438              5             0.8213
# 504       112277              5             0.8116
# ..           ...            ...                ...
# 595       114152              5             0.7033
# 596       111804              5             0.7031
# 597        90443              5             0.7029
# 598        43822              5             0.7027
# 599        16966              5             0.7016
#
#                                               Keywords  \
# 500  ncaa, investigation, university, court, statem...
# 501  ncaa, investigation, university, court, statem...
# 502  ncaa, investigation, university, court, statem...
# 503  ncaa, investigation, university, court, statem...
# 504  ncaa, investigation, university, court, statem...
# ..                                                 ...
# 595  ncaa, investigation, university, court, statem...
# 596  ncaa, investigation, university, court, statem...
# 597  ncaa, investigation, university, court, statem...
# 598  ncaa, investigation, university, court, statem...
# 599  ncaa, investigation, university, court, statem...
#
#                                                   Text
# 500  [received, formal, notice, allegations, ncaa, ...
# 501  [football_coach, phillip, fulmer, secretly, pr...
# 502  [judges, peppered, ncaa, attorney, questions, ...
# 503  [ncaa, committee, infractions, received, viole...
# 504  [attorney, wildcats, assistant_coach, emanuel,...
# ..                                                 ...
# 595  [attorneys, wildcats, assistant_coach, emanuel...
# 596  [federal, grand, jury, issued, subpoenas, univ...
# 597  [attorneys, jerry, sandusky, outlined, issues,...
# 598  [legal, affairs, running, booker, stanley, sen...
# 599  [law, prosecutors, dealt, setback, tuesday, ju...
#
# [100 rows x 5 columns]
# --- Topic 6 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 600        18303              6             0.8583
# 601        68273              6             0.8183
# 602        64747              6             0.7973
# 603        32451              6             0.7912
# 604        50034              6               0.76
# ..           ...            ...                ...
# 695        17664              6             0.5836
# 696        88566              6              0.583
# 697        33274              6             0.5824
# 698        57493              6             0.5821
# 699        16842              6              0.582
#
#                                               Keywords  \
# 600  goals, goal, wrestling, lacrosse, championship...
# 601  goals, goal, wrestling, lacrosse, championship...
# 602  goals, goal, wrestling, lacrosse, championship...
# 603  goals, goal, wrestling, lacrosse, championship...
# 604  goals, goal, wrestling, lacrosse, championship...
# ..                                                 ...
# 695  goals, goal, wrestling, lacrosse, championship...
# 696  goals, goal, wrestling, lacrosse, championship...
# 697  goals, goal, wrestling, lacrosse, championship...
# 698  goals, goal, wrestling, lacrosse, championship...
# 699  goals, goal, wrestling, lacrosse, championship...
#
#                                                   Text
# 600  [soccer, host, oneonta, n.y, tied, university,...
# 601  [junior, max, feely, scored, career, goal, ove...
# 602  [rachel, ray, goals, assisted, lead, adelphi, ...
# 603  [lynbrook, graduate, michael, doneger, freshma...
# 604  [ncaa_tournament_south_region, subject, tourna...
# ..                                                 ...
# 695  [soccer, heather, areilly, goals, assist, lead...
# 696  [towson, women, lacrosse_team, scored, goals, ...
# 697  [garden, city, product, peter, lesueur, goal, ...
# 698  [division, women, lacrosse, championship, nort...
# 699  [senior, mike, mollet, sachem, graduate, earne...
#
# [100 rows x 5 columns]
# --- Topic 7 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 700        29548              7             0.9726
# 701        31478              7             0.9586
# 702       131394              7             0.9125
# 703        24654              7             0.9119
# 704        27087              7             0.9116
# ..           ...            ...                ...
# 795        25953              7             0.7817
# 796       122447              7             0.7813
# 797        50670              7             0.7806
# 798        56466              7               0.78
# 799        86268              7               0.78
#
#                                               Keywords  \
# 700  olympic, women, world, won, time, united, olym...
# 701  olympic, women, world, won, time, united, olym...
# 702  olympic, women, world, won, time, united, olym...
# 703  olympic, women, world, won, time, united, olym...
# 704  olympic, women, world, won, time, united, olym...
# ..                                                 ...
# 795  olympic, women, world, won, time, united, olym...
# 796  olympic, women, world, won, time, united, olym...
# 797  olympic, women, world, won, time, united, olym...
# 798  olympic, women, world, won, time, united, olym...
# 799  olympic, women, world, won, time, united, olym...
#
#                                                   Text
# 700  [colleges, simon, bairu, repeated, individual,...
# 701  [double, sophomore, kerron, clement, broke, mi...
# 702  [tokyo, american, diving, duo, delaney, schnel...
# 703  [skiing, mexico, won, ncaa, skiing, championsh...
# 704  [junior, kaitlin, sandeno, won, meter, individ...
# ..                                                 ...
# 795  [special, section, athens, summer, games, caps...
# 796  [katie, ledecky, swimmer, stunned, pack, world...
# 797  [eugene, ore, starting, michelle, perry, meter...
# 798  [bernard, lagat, lap, olympic, meter, round, f...
# 799  [ryan, whiting, shot, winning, national_titles...
#
# [100 rows x 5 columns]
# --- Topic 8 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 800        37020              8             0.6924
# 801        52293              8             0.6317
# 802        28031              8             0.5426
# 803         9360              8             0.5332
# 804        66216              8             0.5305
# ..           ...            ...                ...
# 895        28641              8             0.4132
# 896        23192              8             0.4124
# 897        16570              8             0.4122
# 898        59344              8             0.4121
# 899        47520              8             0.4116
#
#                                               Keywords  \
# 800  injury, season, injuries, health, week, surger...
# 801  injury, season, injuries, health, week, surger...
# 802  injury, season, injuries, health, week, surger...
# 803  injury, season, injuries, health, week, surger...
# 804  injury, season, injuries, health, week, surger...
# ..                                                 ...
# 895  injury, season, injuries, health, week, surger...
# 896  injury, season, injuries, health, week, surger...
# 897  injury, season, injuries, health, week, surger...
# 898  injury, season, injuries, health, week, surger...
# 899  injury, season, injuries, health, week, surger...
#
#                                                   Text
# 800  [summer, workouts, college_football_players, c...
# 801  [bye, week, regain, health, significant, playe...
# 802  [st, star, receiver, blake, elliott, suffered,...
# 803  [freshmen, starting, wide, receiver, lonnie, h...
# 804  [satele, support, linebacker, surgery, left, s...
# ..                                                 ...
# 895  [basketball_player, jason, fraser, calls, moth...
# 896  [cornerback, ronald, nunn, returned, practice,...
# 897  [tailback, darryl, poston, returning, football...
# 898  [proclaiming, free, pain, saturday, junior, sw...
# 899  [injuries, student_athletes, researchers, repo...
#
# [100 rows x 5 columns]
# --- Topic 9 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 900        33318              9             0.9435
# 901        77165              9             0.8933
# 902        51773              9             0.8799
# 903        26421              9             0.8404
# 904        37781              9             0.8175
# ..           ...            ...                ...
# 995        18675              9             0.6339
# 996       129236              9             0.6338
# 997        49659              9             0.6334
# 998        49741              9             0.6333
# 999        56381              9             0.6328
#
#                                               Keywords  \
# 900  coach, program, coaches, season, coaching, hea...
# 901  coach, program, coaches, season, coaching, hea...
# 902  coach, program, coaches, season, coaching, hea...
# 903  coach, program, coaches, season, coaching, hea...
# 904  coach, program, coaches, season, coaching, hea...
# ..                                                 ...
# 995  coach, program, coaches, season, coaching, hea...
# 996  coach, program, coaches, season, coaching, hea...
# 997  coach, program, coaches, season, coaching, hea...
# 998  coach, program, coaches, season, coaching, hea...
# 999  coach, program, coaches, season, coaching, hea...
#
#                                                   Text
# 900  [short, seasons, coaching, serving, coach, ath...
# 901  [ncaa, gary, williams, career, coaching, recor...
# 902  [active, college_basketball_coaches, won, mult...
# 903  [college_basketball, introduce, coach, rick, m...
# 904  [mike, anderson, hired, basketball_coach, sund...
# ..                                                 ...
# 995  [mark, anderson, review, journal, jim, schloss...
# 996  [basketball, head_coach, mark, turgeon, amid, ...
# 997  [dan, monson, final, day, gophers_basketball_c...
# 998  [ricardo, patton, named, coach, northern, news...
# 999  [bob, knight, courtside, chair, throw, anymore...
#
# [100 rows x 5 columns]
# --- Topic 10 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1000         9268             10              0.974
# 1001       121452             10              0.915
# 1002        85375             10             0.9117
# 1003        74728             10             0.9115
# 1004        76923             10             0.9093
# ...           ...            ...                ...
# 1095        24801             10             0.7332
# 1096        25007             10             0.7322
# 1097        70176             10             0.7307
# 1098        64871             10             0.7293
# 1099       126646             10             0.7262
#
#                                                Keywords  \
# 1000  conference, teams, games, team, season, ten, t...
# 1001  conference, teams, games, team, season, ten, t...
# 1002  conference, teams, games, team, season, ten, t...
# 1003  conference, teams, games, team, season, ten, t...
# 1004  conference, teams, games, team, season, ten, t...
# ...                                                 ...
# 1095  conference, teams, games, team, season, ten, t...
# 1096  conference, teams, games, team, season, ten, t...
# 1097  conference, teams, games, team, season, ten, t...
# 1098  conference, teams, games, team, season, ten, t...
# 1099  conference, teams, games, team, season, ten, t...
#
#                                                    Text
# 1000  [east, conference, dropped, division, format, ...
# 1001  [temple, tumble, ncaa, evaluation, tool, ranki...
# 1002  [temple, loss, st_joseph, costly, costly, expe...
# 1003  [resumes, teams_ncaa_tournament, bubble, compa...
# 1004  [resumes, teams_ncaa_tournament, bubble, compa...
# ...                                                 ...
# 1095  [temple, drexel, basketball_season, continues,...
# 1096  [american, office, pool, spit, copiers, tonigh...
# 1097  [western, lady_toppers, women, ncaa_tournament...
# 1098  [month, playing, top_seed, ncaa_tournament, st...
# 1099  [consecutive, victories, home, inched, seed, n...
#
# [100 rows x 5 columns]
# --- Topic 11 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1100        69462             11             0.9658
# 1101        44067             11             0.9466
# 1102        36369             11             0.9443
# 1103       130034             11             0.9255
# 1104        69472             11             0.9245
# ...           ...            ...                ...
# 1195        38658             11             0.7515
# 1196        68089             11             0.7502
# 1197        11232             11             0.7498
# 1198        24232             11             0.7485
# 1199       118055             11              0.748
#
#                                                Keywords  \
# 1100  softball, regional, baseball, tbd, harbaugh, i...
# 1101  softball, regional, baseball, tbd, harbaugh, i...
# 1102  softball, regional, baseball, tbd, harbaugh, i...
# 1103  softball, regional, baseball, tbd, harbaugh, i...
# 1104  softball, regional, baseball, tbd, harbaugh, i...
# ...                                                 ...
# 1195  softball, regional, baseball, tbd, harbaugh, i...
# 1196  softball, regional, baseball, tbd, harbaugh, i...
# 1197  softball, regional, baseball, tbd, harbaugh, i...
# 1198  softball, regional, baseball, tbd, harbaugh, i...
# 1199  softball, regional, baseball, tbd, harbaugh, i...
#
#                                                    Text
# 1100  [blake, amaral, hit, leadoff, home_run, sixth,...
# 1101  [seasons, ncaa, postseason, appearance, rainbo...
# 1102  [beach, victory, advancing, ncaa_baseball, sup...
# 1103  [frankie, hammoude, hit, run, walk, homer, sev...
# 1104  [kane, ohe, pacific, softball, team, lost, chi...
# ...                                                 ...
# 1195  [emily, zaplatosch, hits, including, home_run,...
# 1196  [season, pitching, calling, card, ncaa_basebal...
# 1197  [wins, games, cal, fullerton, dating, san_dieg...
# 1198  [fullerton, baseball_team, looked, stunned, op...
# 1199  [catcher, cooper, uhl, hitter, loyola, marymou...
#
# [100 rows x 5 columns]
# --- Topic 12 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1200       126468             12             0.7737
# 1201        28432             12             0.5984
# 1202       108575             12             0.5806
# 1203        10113             12             0.5758
# 1204        47910             12              0.558
# ...           ...            ...                ...
# 1295        41069             12             0.4413
# 1296        60423             12             0.4405
# 1297       128691             12             0.4392
# 1298        37583             12             0.4382
# 1299         7571             12              0.438
#
#                                                Keywords  \
# 1200  league, nfl, baseball, season, team, million, ...
# 1201  league, nfl, baseball, season, team, million, ...
# 1202  league, nfl, baseball, season, team, million, ...
# 1203  league, nfl, baseball, season, team, million, ...
# 1204  league, nfl, baseball, season, team, million, ...
# ...                                                 ...
# 1295  league, nfl, baseball, season, team, million, ...
# 1296  league, nfl, baseball, season, team, million, ...
# 1297  league, nfl, baseball, season, team, million, ...
# 1298  league, nfl, baseball, season, team, million, ...
# 1299  league, nfl, baseball, season, team, million, ...
#
#                                                    Text
# 1200  [staff, reports, twins, signed, major, leaguer...
# 1201  [kellen, winslow, agent, rejected, contract, o...
# 1202  [yankees, braves, ballpark, suntrust, park, fr...
# 1203  [scoreboard, american, league, boston, red_sox...
# 1204  [trivia, answer, quarterback, rick, neuheisel,...
# ...                                                 ...
# 1295  [ian, kennedy, seventh, baseball, player, draf...
# 1296  [responses, sunday, report, alex, rodriguez, p...
# 1297  [texans, signed, free_agent, quarterback, jeff...
# 1298  [detroit, lions, charles, rogers, mind, receiv...
# 1299  [source:apzfile:zkeyword:bc, transactionsdated...
#
# [100 rows x 5 columns]
# --- Topic 13 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1300       120341             13             0.9403
# 1301        38760             13             0.9217
# 1302        10769             13             0.9037
# 1303       108918             13             0.9035
# 1304       149605             13             0.8909
# ...           ...            ...                ...
# 1395        10962             13             0.7399
# 1396       102458             13             0.7389
# 1397       137548             13             0.7388
# 1398        87636             13             0.7372
# 1399        92225             13             0.7364
#
#                                                Keywords  \
# 1300  sports, tv, network, games, espn, watch, live,...
# 1301  sports, tv, network, games, espn, watch, live,...
# 1302  sports, tv, network, games, espn, watch, live,...
# 1303  sports, tv, network, games, espn, watch, live,...
# 1304  sports, tv, network, games, espn, watch, live,...
# ...                                                 ...
# 1395  sports, tv, network, games, espn, watch, live,...
# 1396  sports, tv, network, games, espn, watch, live,...
# 1397  sports, tv, network, games, espn, watch, live,...
# 1398  sports, tv, network, games, espn, watch, live,...
# 1399  sports, tv, network, games, espn, watch, live,...
#
#                                                    Text
# 1300  [unlike, super_bowl, recent, ticket, sporting,...
# 1301  [cbs, corp, sells, episodes, hit, television, ...
# 1302  [college_basketball, cbs, discussions, espn, s...
# 1303  [streaming, service, hulu, wednesday, notched,...
# 1304  [madness, underway, cinderellas, crowned, cont...
# ...                                                 ...
# 1395  [march_madness, ncaa_tournament, contingency, ...
# 1396  [technology, companies, including, facebook, s...
# 1397  [ve, cut, cord, favor, streaming, ve, smart, f...
# 1398  [cbs, corp, quarter, profit, rose, digital, st...
# 1399  [springtime, tv, ad, sales, season, networks, ...
#
# [100 rows x 5 columns]
# --- Topic 14 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1400        98052             14              0.984
# 1401        71026             14             0.9718
# 1402        63459             14             0.9563
# 1403        65922             14             0.9553
# 1404        11459             14             0.9541
# ...           ...            ...                ...
# 1495       106753             14             0.7394
# 1496       145518             14             0.7391
# 1497       129493             14             0.7377
# 1498        33757             14             0.7371
# 1499        41620             14             0.7365
#
#                                                Keywords  \
# 1400  seed, tournament, final, ncaa_tournament, team...
# 1401  seed, tournament, final, ncaa_tournament, team...
# 1402  seed, tournament, final, ncaa_tournament, team...
# 1403  seed, tournament, final, ncaa_tournament, team...
# 1404  seed, tournament, final, ncaa_tournament, team...
# ...                                                 ...
# 1495  seed, tournament, final, ncaa_tournament, team...
# 1496  seed, tournament, final, ncaa_tournament, team...
# 1497  seed, tournament, final, ncaa_tournament, team...
# 1498  seed, tournament, final, ncaa_tournament, team...
# 1499  seed, tournament, final, ncaa_tournament, team...
#
#                                                    Text
# 1400  [warned, ten_tournament, champions, advanced, ...
# 1401  [ncaa_tournament, unpredictable, compelling, s...
# 1402  [dating, ncaa_tournaments, double, digit, seed...
# 1403  [cream, rising, ncaa_basketball_tournament, vi...
# 1404  [usa, supplying, tips, filling, bracket, ncaa_...
# ...                                                 ...
# 1495  [predictionmachine.com, ran, simulations, ncaa...
# 1496  [madness, winding, elite, games, schedule, nca...
# 1497  [college_basketball_season, begins, selection_...
# 1498  [won, cardinals, won, games, teams, average, d...
# 1499  [special, section, ncaa_tournament, ten, confe...
#
# [100 rows x 5 columns]
# --- Topic 15 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1500        26828             15             0.8389
# 1501        55563             15             0.8038
# 1502       112236             15             0.8015
# 1503        55572             15             0.7962
# 1504         2556             15             0.7958
# ...           ...            ...                ...
# 1595        60256             15             0.6233
# 1596        86083             15             0.6224
# 1597         3013             15             0.6223
# 1598        41018             15             0.6199
# 1599        18983             15             0.6197
#
#                                                Keywords  \
# 1500  gophers, minnesota, hockey, goals, season, nhl...
# 1501  gophers, minnesota, hockey, goals, season, nhl...
# 1502  gophers, minnesota, hockey, goals, season, nhl...
# 1503  gophers, minnesota, hockey, goals, season, nhl...
# 1504  gophers, minnesota, hockey, goals, season, nhl...
# ...                                                 ...
# 1595  gophers, minnesota, hockey, goals, season, nhl...
# 1596  gophers, minnesota, hockey, goals, season, nhl...
# 1597  gophers, minnesota, hockey, goals, season, nhl...
# 1598  gophers, minnesota, hockey, goals, season, nhl...
# 1599  gophers, minnesota, hockey, goals, season, nhl...
#
#                                                    Text
# 1500  [ncaa, midwest_regional_final, van, andel, are...
# 1501  [tonight, p.m, saturday, magness, arena, recor...
# 1502  [p.m, fri, sat, fsn, fmpreview, gophers, ten, ...
# 1503  [defensemen, gophers_women, hockey, coach, bra...
# 1504  [rsec, gophers, won, ncaa_championship, saturd...
# ...                                                 ...
# 1595  [gophers_women, hockey_team, starts, preseason...
# 1596  [minnesota, mankato, seed, minnesota_duluth, u...
# 1597  [rsec, gophers, denver, saturdays, gophers, ho...
# 1598  [special, star, tribune, gophers, weekend, swe...
# 1599  [championship, gophers, college, march, corny,...
#
# [100 rows x 5 columns]
# --- Topic 16 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1600         8388             16              0.767
# 1601        80593             16             0.7634
# 1602        60308             16             0.7577
# 1603         4837             16             0.7394
# 1604        46827             16             0.7323
# ...           ...            ...                ...
# 1695        94471             16             0.6002
# 1696        46924             16             0.6001
# 1697        93843             16             0.5996
# 1698         9974             16             0.5994
# 1699       112933             16             0.5993
#
#                                                Keywords  \
# 1600  nba, draft, basketball, league, pick, player, ...
# 1601  nba, draft, basketball, league, pick, player, ...
# 1602  nba, draft, basketball, league, pick, player, ...
# 1603  nba, draft, basketball, league, pick, player, ...
# 1604  nba, draft, basketball, league, pick, player, ...
# ...                                                 ...
# 1695  nba, draft, basketball, league, pick, player, ...
# 1696  nba, draft, basketball, league, pick, player, ...
# 1697  nba, draft, basketball, league, pick, player, ...
# 1698  nba, draft, basketball, league, pick, player, ...
# 1699  nba, draft, basketball, league, pick, player, ...
#
#                                                    Text
# 1600  [round, nba_draft, unpredictable, rarely, scen...
# 1601  [pick, june, nba_draft, charlotte, bobcats, se...
# 1602  [timberwolves, entered, thursday, night, draft...
# 1603  [barbara, barker, mock, lottery, guarantee, mi...
# 1604  [portland, beat, odds, tuesday, won, nba_draft...
# ...                                                 ...
# 1695  [nba_draft, closer, lakers, hang, seventh, pic...
# 1696  [deerfield, ill, kobe, bryant, kevin, garnett,...
# 1697  [lakers, officially, waved, goodbye, free_agen...
# 1698  [ncaa_tournament, analysis, time, picks, nba_d...
# 1699  [bulls, pick, nba_draft, thursday, introductio...
#
# [100 rows x 5 columns]
# --- Topic 17 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1700        24515             17             0.8933
# 1701       143357             17             0.8888
# 1702       105775             17             0.8744
# 1703        63449             17             0.8628
# 1704        63962             17             0.8628
# ...           ...            ...                ...
# 1795        14846             17             0.5195
# 1796        42496             17              0.519
# 1797        41899             17             0.5174
# 1798       115247             17             0.5167
# 1799       143433             17             0.5151
#
#                                                Keywords  \
# 1700  women, p.m, espn, south, basketball, wnba, mar...
# 1701  women, p.m, espn, south, basketball, wnba, mar...
# 1702  women, p.m, espn, south, basketball, wnba, mar...
# 1703  women, p.m, espn, south, basketball, wnba, mar...
# 1704  women, p.m, espn, south, basketball, wnba, mar...
# ...                                                 ...
# 1795  women, p.m, espn, south, basketball, wnba, mar...
# 1796  women, p.m, espn, south, basketball, wnba, mar...
# 1797  women, p.m, espn, south, basketball, wnba, mar...
# 1798  women, p.m, espn, south, basketball, wnba, mar...
# 1799  women, p.m, espn, south, basketball, wnba, mar...
#
#                                                    Text
# 1700  [women, espn, p.m, wusa, wjz, p.m, subject, to...
# 1701  [times, eastern, daylight, knoxville, regional...
# 1702  [a.m, a.m, p.m, p.m, friday, june, winner, win...
# 1703  [ncaa_women, championship, p.m, tv, espn, st_l...
# 1704  [p.m, tv, wusa, wjz, subject, tournaments, cha...
# ...                                                 ...
# 1795  [college_basketball, women, preview, saturday,...
# 1796  [exhibition, baseball, york, yankees, minnesot...
# 1797  [semifinals, tomorrow, unseeded, massachusetts...
# 1798  [schedule, saturday, lacrosse, fan, fest, a.m,...
# 1799  [play, games, albany, presbyterian, sacred, he...
#
# [100 rows x 5 columns]
# --- Topic 18 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1800        77117             18             0.9359
# 1801         9381             18             0.8932
# 1802        93644             18              0.747
# 1803        95048             18             0.7393
# 1804        67758             18             0.7128
# ...           ...            ...                ...
# 1895        49540             18             0.5036
# 1896        10443             18             0.5033
# 1897        43681             18              0.503
# 1898        34981             18             0.5015
# 1899        61828             18             0.5014
#
#                                                Keywords  \
# 1800  nil, fans, people, sports, time, day, moment, ...
# 1801  nil, fans, people, sports, time, day, moment, ...
# 1802  nil, fans, people, sports, time, day, moment, ...
# 1803  nil, fans, people, sports, time, day, moment, ...
# 1804  nil, fans, people, sports, time, day, moment, ...
# ...                                                 ...
# 1895  nil, fans, people, sports, time, day, moment, ...
# 1896  nil, fans, people, sports, time, day, moment, ...
# 1897  nil, fans, people, sports, time, day, moment, ...
# 1898  nil, fans, people, sports, time, day, moment, ...
# 1899  nil, fans, people, sports, time, day, moment, ...
#
#                                                    Text
# 1800  [caption, text, illustration, caption, graphic...
# 1801  [text, database, illustration, caption, chart,...
# 1802  [caption, text, illustration, caption, photo, ...
# 1803  [caption, text, illustration, caption, graphic...
# 1804  [wild, eyed, college, kids, run, broomsticks, ...
# ...                                                 ...
# 1895  [north, mascot, jason, ray, hospital, hit, car...
# 1896  [row, critic, corner, life, gamble, people, gu...
# 1897  [underdog, day, nation, inspiring, basketball_...
# 1898  [homes, glossary, guide, finding, cool, crib, ...
# 1899  [wku, ncaa_bid, straight, sbc, win, http, www....
#
# [100 rows x 5 columns]
# --- Topic 19 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1900       100403             19             0.7784
# 1901        52480             19             0.6325
# 1902       114735             19             0.6117
# 1903        40536             19             0.5874
# 1904        24413             19             0.5244
# ...           ...            ...                ...
# 1995       121836             19             0.3357
# 1996       133207             19             0.3355
# 1997       133108             19             0.3349
# 1998       120707             19             0.3329
# 1999        43165             19             0.3325
#
#                                                Keywords  \
# 1900  san_diego, mexico, cronin, watkins, march, byu...
# 1901  san_diego, mexico, cronin, watkins, march, byu...
# 1902  san_diego, mexico, cronin, watkins, march, byu...
# 1903  san_diego, mexico, cronin, watkins, march, byu...
# 1904  san_diego, mexico, cronin, watkins, march, byu...
# ...                                                 ...
# 1995  san_diego, mexico, cronin, watkins, march, byu...
# 1996  san_diego, mexico, cronin, watkins, march, byu...
# 1997  san_diego, mexico, cronin, watkins, march, byu...
# 1998  san_diego, mexico, cronin, watkins, march, byu...
# 1999  san_diego, mexico, cronin, watkins, march, byu...
#
#                                                    Text
# 1900  [san_diego, wichita, dayton, gonzaga, west, no...
# 1901  [coach, lon, kruger, player, pos, ht, wt, yr, ...
# 1902  [loyola, season, coach, porter, moser, regular...
# 1903  [season, pre, season_final, weeks, ranked, nr,...
# 1904  [columbus, round, games, friday, record, locat...
# ...                                                 ...
# 1995  [uc, riverside, malou, thiebaut, de, kergret, ...
# 1996  [grand_canyon, start, women, national, invitat...
# 1997  [grand_canyon, cay, goodbye, catching, mexico,...
# 1998  [uc_irvine, guard, evan, leonard, drives, past...
# 1999  [steve, carp, review, journal, salt, lake, cit...
#
# [100 rows x 5 columns]
# --- Topic 20 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2000        13039             20             0.9578
# 2001        57020             20             0.9517
# 2002        13038             20             0.9411
# 2003        12832             20             0.9363
# 2004        13040             20             0.9244
# ...           ...            ...                ...
# 2095          659             20             0.7486
# 2096        22838             20             0.7479
# 2097        37314             20             0.7479
# 2098        29537             20             0.7477
# 2099       108894             20             0.7471
#
#                                                Keywords  \
# 2000  yards, college_football, quarterback, season, ...
# 2001  yards, college_football, quarterback, season, ...
# 2002  yards, college_football, quarterback, season, ...
# 2003  yards, college_football, quarterback, season, ...
# 2004  yards, college_football, quarterback, season, ...
# ...                                                 ...
# 2095  yards, college_football, quarterback, season, ...
# 2096  yards, college_football, quarterback, season, ...
# 2097  yards, college_football, quarterback, season, ...
# 2098  yards, college_football, quarterback, season, ...
# 2099  yards, college_football, quarterback, season, ...
#
#                                                    Text
# 2000  [colleges, fire, larry, fitzgerald, wide, rece...
# 2001  [categorynavyopppassing, yards, rushing, yards...
# 2002  [colleges, fire, josh, white, quarterback, sat...
# 2003  [larry, fitzgerald, wr, pitt, led, temple, tou...
# 2004  [college_football, fire, larry, fitzgerald, wi...
# ...                                                 ...
# 2095  [ten, report, badgers, wildcats, couple, commo...
# 2096  [college_football, kyle, orton, senior, qb, pu...
# 2097  [college_football, lightning, caused, minute, ...
# 2098  [college_football, adrian, davis, replacing, i...
# 2099  [tech, kyle, kempt, threw, touchdown, passes, ...
#
# [100 rows x 5 columns]
# --- Topic 21 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2100        37585             21             0.7492
# 2101        86459             21             0.6794
# 2102        59253             21             0.6735
# 2103        65980             21             0.6648
# 2104       137868             21             0.6579
# ...           ...            ...                ...
# 2195        36211             21             0.5415
# 2196       139728             21             0.5407
# 2197        76632             21              0.539
# 2198       137126             21              0.539
# 2199        78853             21             0.5368
#
#                                                Keywords  \
# 2100  team, players, time, play, lot, playing, coach...
# 2101  team, players, time, play, lot, playing, coach...
# 2102  team, players, time, play, lot, playing, coach...
# 2103  team, players, time, play, lot, playing, coach...
# 2104  team, players, time, play, lot, playing, coach...
# ...                                                 ...
# 2195  team, players, time, play, lot, playing, coach...
# 2196  team, players, time, play, lot, playing, coach...
# 2197  team, players, time, play, lot, playing, coach...
# 2198  team, players, time, play, lot, playing, coach...
# 2199  team, players, time, play, lot, playing, coach...
#
#                                                    Text
# 2100  [calming, players, nerves, expert, sasho, ciro...
# 2101  [beanie, told, bob, mcmanaman, weird, feeling,...
# 2102  [hockey, career, kyle, turris, shown, ability,...
# 2103  [compare, current, western, basketball_team, s...
# 2104  [weeks, training, camp, lynx, coach, cheryl, r...
# ...                                                 ...
# 2195  [redshirt, freshmen, eager, contribute, volley...
# 2196  [bears, manager, ryan, poles, test, darnell, w...
# 2197  [goal, goal, college_basketball_team, means, w...
# 2198  [days, tyson, foerster, wear, choice, flyers, ...
# 2199  [coyotes, lot, faith, trust, guy, ice, sequest...
#
# [100 rows x 5 columns]
# --- Topic 22 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2200        18356             22             0.8728
# 2201        27521             22             0.8458
# 2202        11900             22              0.761
# 2203        72259             22             0.7438
# 2204        13930             22             0.7408
# ...           ...            ...                ...
# 2295       145022             22             0.5869
# 2296        75161             22             0.5865
# 2297       145013             22             0.5865
# 2298        37490             22             0.5856
# 2299         1876             22             0.5843
#
#                                                Keywords  \
# 2200  season, team, guard, player, clark, freshman, ...
# 2201  season, team, guard, player, clark, freshman, ...
# 2202  season, team, guard, player, clark, freshman, ...
# 2203  season, team, guard, player, clark, freshman, ...
# 2204  season, team, guard, player, clark, freshman, ...
# ...                                                 ...
# 2295  season, team, guard, player, clark, freshman, ...
# 2296  season, team, guard, player, clark, freshman, ...
# 2297  season, team, guard, player, clark, freshman, ...
# 2298  season, team, guard, player, clark, freshman, ...
# 2299  season, team, guard, player, clark, freshman, ...
#
#                                                    Text
# 2200  [season, sixth, pacific, postseason, advanced,...
# 2201  [glance, season, pacific, conference, finish, ...
# 2202  [polls, accurate, tough, read, sun_devils, pro...
# 2203  [measure, women, basketball, progress, win, se...
# 2204  [northern, basketball_coaches, worry, recent, ...
# ...                                                 ...
# 2295  [ranked, ap, top, preseason, poll, straight, t...
# 2296  [jared, sullinger, physically, leaner, sulling...
# 2297  [missing, ncaa_tournament, time, coach_mike, w...
# 2298  [march_madness, record, top, conference, ten, ...
# 2299  [player, seasons, ncaa, playing, experience, g...
#
# [100 rows x 5 columns]
# --- Topic 23 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2300        67634             23               0.88
# 2301       136091             23             0.7599
# 2302        58995             23             0.5834
# 2303        77373             23             0.5522
# 2304        90045             23             0.5237
# ...           ...            ...                ...
# 2395         6907             23             0.3278
# 2396        88055             23             0.3278
# 2397        84739             23             0.3276
# 2398         5464             23              0.327
# 2399        15491             23             0.3267
#
#                                                Keywords  \
# 2300  boston, globe, eagles, bc, boston_college, pro...
# 2301  boston, globe, eagles, bc, boston_college, pro...
# 2302  boston, globe, eagles, bc, boston_college, pro...
# 2303  boston, globe, eagles, bc, boston_college, pro...
# 2304  boston, globe, eagles, bc, boston_college, pro...
# ...                                                 ...
# 2395  boston, globe, eagles, bc, boston_college, pro...
# 2396  boston, globe, eagles, bc, boston_college, pro...
# 2397  boston, globe, eagles, bc, boston_college, pro...
# 2398  boston, globe, eagles, bc, boston_college, pro...
# 2399  boston, globe, eagles, bc, boston_college, pro...
#
#                                                    Text
# 2300  [head_coach, jerry, york, celebrated, boston_c...
# 2301  [neil, neil.best, newsday.com, credit, neil, n...
# 2302  [ncaa_tournament, sidebar, pdf, chart, data, c...
# 2303  [frozen, bc, bu, cornell, tomorrow, p.m, erie,...
# 2304  [captured, beanpot, title, competitors, won, b...
# ...                                                 ...
# 2395  [globe, west, sports, sportswest, marvin, pave...
# 2396  [fitting, circumstance, brought, championships...
# 2397  [caption, text, illustration, caption, strike,...
# 2398  [globe, north, sports, notebook, apair, north,...
# 2399  [globe, north, sports, notebook, christopher, ...
#
# [100 rows x 5 columns]
# --- Topic 24 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 2400        33116             24             0.8919
# 2401        43920             24             0.8645
# 2402         5628             24             0.8545
# 2403        43921             24             0.8544
# 2404        13606             24             0.8534
# ...           ...            ...                ...
# 2495       105191             24               0.76
# 2496       106072             24             0.7599
# 2497        82904             24             0.7598
# 2498       137668             24             0.7598
# 2499        55273             24             0.7592
#
#                                                Keywords  \
# 2400  half, lead, minutes, shot, left, scored, play,...
# 2401  half, lead, minutes, shot, left, scored, play,...
# 2402  half, lead, minutes, shot, left, scored, play,...
# 2403  half, lead, minutes, shot, left, scored, play,...
# 2404  half, lead, minutes, shot, left, scored, play,...
# ...                                                 ...
# 2495  half, lead, minutes, shot, left, scored, play,...
# 2496  half, lead, minutes, shot, left, scored, play,...
# 2497  half, lead, minutes, shot, left, scored, play,...
# 2498  half, lead, minutes, shot, left, scored, play,...
# 2499  half, lead, minutes, shot, left, scored, play,...
#
#                                                    Text
# 2400  [final, prayer, bounced, rim, times, falling, ...
# 2401  [gerry, mcnamara, looked, exhausted, headed, b...
# 2402  [conference, championships, east_tournament, c...
# 2403  [gerry, mcnamara, looked, exhausted, headed, b...
# 2404  [roy_williams, jayhawks, recovered, half, offe...
# ...                                                 ...
# 2495  [guard, demetrius, jackson, rough, evening, fo...
# 2496  [rex, pflueger, tipped, putback, missed, layup...
# 2497  [minutes, half, ncaa, east_region, semifinal, ...
# 2498  [city, closing, saturday, afternoon, basketbal...
# 2499  [note, version, ran, final, edition, ot, home,...
#
# [100 rows x 5 columns]

# %%
# Define the path to save the Excel file in your Google Drive
excel_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_25_topics.xlsx'

# Save the DataFrame to an Excel file
try:
    top_100_documents_per_topic.to_excel(excel_file_path, index=False)
    print(f"Successfully saved the top 100 documents per topic to: {excel_file_path}")
except Exception as e:
    print(f"An error occurred while saving the Excel file: {e}")
# Out:
# Successfully saved the top 100 documents per topic to: /content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_25_topics.xlsx

# %% [markdown]
# ##### **© 2024–2025 MD Rafsun Sheikh**
# ##### **Licensed under the Apache License, Version 2.0.**
