# %%
# %pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.8 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 22.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 29.8 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 15.3 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gensim.models.ldamodel import LdaModel

# Load the LDA model
loaded_lda_model = LdaModel.load('/content/drive/MyDrive/Colab Notebooks/alex/models/lda_20_topics/lda_model_20_topics.gensim')

# Now you can access information from the loaded model.
# For example, you can print the topics:
print("Topics:")
for topic_id, topic in loaded_lda_model.print_topics():
    print(f"Topic {topic_id}: {topic}")

# You can also access the dictionary (id2word)
print("\nDictionary:")
print(loaded_lda_model.id2word)

# And the number of topics
print("\nNumber of topics:")
print(loaded_lda_model.num_topics)
# Out:
# Topics:
# Topic 0: 0.058*"coach" + 0.029*"basketball" + 0.014*"year" + 0.013*"coaching" + 0.013*"head" + 0.010*"program" + 0.010*"assistant" + 0.010*"season" + 0.009*"championship" + 0.009*"college"
# Topic 1: 0.028*"school" + 0.022*"year" + 0.021*"player" + 0.020*"high" + 0.020*"season" + 0.018*"team" + 0.018*"college" + 0.013*"coach" + 0.012*"said" + 0.011*"transfer"
# Topic 2: 0.036*"gopher" + 0.026*"hockey" + 0.025*"minnesota" + 0.020*"game" + 0.016*"goal" + 0.014*"team" + 0.013*"season" + 0.009*"state" + 0.009*"first" + 0.008*"four"
# Topic 3: 0.007*"nil" + 0.007*"people" + 0.005*"day" + 0.005*"one" + 0.005*"say" + 0.005*"family" + 0.005*"trump" + 0.004*"life" + 0.004*"new" + 0.004*"social"
# Topic 4: 0.016*"ncaa" + 0.016*"said" + 0.015*"college" + 0.015*"school" + 0.014*"athlete" + 0.012*"sport" + 0.011*"state" + 0.009*"university" + 0.008*"football" + 0.008*"would"
# Topic 5: 0.024*"woman" + 0.018*"u" + 0.015*"championship" + 0.015*"olympic" + 0.015*"world" + 0.012*"team" + 0.010*"first" + 0.010*"united" + 0.009*"title" + 0.009*"olympics"
# Topic 6: 0.028*"game" + 0.018*"point" + 0.012*"shot" + 0.011*"first" + 0.011*"second" + 0.011*"said" + 0.008*"minute" + 0.008*"guard" + 0.008*"team" + 0.008*"play"
# Topic 7: 0.020*"per" + 0.017*"point" + 0.015*"2024" + 0.014*"season" + 0.012*"ppg" + 0.012*"guard" + 0.011*"g" + 0.009*"last" + 0.008*"player" + 0.008*"rpg"
# Topic 8: 0.032*"tournament" + 0.026*"team" + 0.023*"state" + 0.016*"big" + 0.014*"ncaa" + 0.014*"seed" + 0.013*"game" + 0.012*"win" + 0.012*"season" + 0.012*"four"
# Topic 9: 0.089*"woman" + 0.038*"uconn" + 0.033*"clark" + 0.032*"basketball" + 0.029*"south" + 0.024*"carolina" + 0.023*"wnba" + 0.022*"championship" + 0.019*"game" + 0.018*"dame"
# Topic 10: 0.029*"said" + 0.013*"like" + 0.011*"would" + 0.011*"going" + 0.011*"get" + 0.011*"year" + 0.010*"one" + 0.010*"team" + 0.009*"player" + 0.009*"time"
# Topic 11: 0.047*"v" + 0.041*"pm" + 0.035*"state" + 0.024*"1" + 0.022*"2" + 0.021*"game" + 0.021*"march" + 0.019*"3" + 0.017*"4" + 0.016*"7"
# Topic 12: 0.022*"draft" + 0.019*"season" + 0.017*"nba" + 0.014*"player" + 0.014*"pick" + 0.012*"league" + 0.009*"team" + 0.009*"new" + 0.006*"game" + 0.006*"injury"
# Topic 13: 0.033*"football" + 0.017*"game" + 0.017*"state" + 0.014*"season" + 0.014*"quarterback" + 0.012*"bowl" + 0.012*"yard" + 0.012*"alabama" + 0.009*"college" + 0.009*"nfl"
# Topic 14: 0.021*"tournament" + 0.021*"st" + 0.016*"game" + 0.014*"goal" + 0.014*"east" + 0.013*"john" + 0.011*"first" + 0.011*"ncaa" + 0.010*"championship" + 0.010*"win"
# Topic 15: 0.026*"arizona" + 0.024*"baseball" + 0.023*"game" + 0.017*"asu" + 0.015*"run" + 0.014*"series" + 0.013*"softball" + 0.013*"first" + 0.013*"inning" + 0.012*"sun"
# Topic 16: 0.039*"golf" + 0.022*"tour" + 0.019*"open" + 0.015*"championship" + 0.015*"2023" + 0.015*"round" + 0.014*"tournament" + 0.012*"pga" + 0.011*"shot" + 0.010*"first"
# Topic 17: 0.052*"point" + 0.018*"scored" + 0.017*"second" + 0.015*"lead" + 0.014*"first" + 0.013*"state" + 0.013*"rebound" + 0.010*"16" + 0.009*"win" + 0.008*"12"
# Topic 18: 0.030*"sport" + 0.022*"game" + 0.012*"basketball" + 0.011*"network" + 0.010*"college" + 0.010*"fan" + 0.009*"year" + 0.009*"million" + 0.008*"new" + 0.007*"betting"
# Topic 19: 0.095*"ucla" + 0.075*"usc" + 0.046*"bruin" + 0.028*"trojan" + 0.026*"oregon" + 0.024*"los" + 0.024*"angeles" + 0.024*"california" + 0.019*"arizona" + 0.018*"photo"
#
# Dictionary:
# Dictionary<416121 unique tokens: ['11', '14', '18', '20', '2001']...>
#
# Number of topics:
# 20

# %%
from gensim import corpora

# Load the corpus from the .mm file
corpus = corpora.MmCorpus('/content/drive/MyDrive/Colab Notebooks/alex/models/dictionary_and_corpus/corpus.mm')

print("Corpus loaded successfully.")
# You can optionally print the corpus to inspect its structure
# print(list(corpus))
# Out:
# Corpus loaded successfully.

# %%
import pandas as pd

# Load the tokenized data from the Excel file
try:
    tokenized_data_df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/alex/updated_ tokenized_newspaper_data.xlsx')
    print("Excel file loaded successfully.")
    # Assuming the original text is in a column named 'text' or similar.
    # Please adjust the column name if it's different in your Excel file.
    if 'Main_text_tokenized' in tokenized_data_df.columns:
        texts = tokenized_data_df['Main_text_tokenized'].tolist()
        print(f"Extracted {len(texts)} documents.")
    else:
        texts = None
        print("Could not find a 'text' column in the Excel file. Please make sure the column containing original texts is named 'text' or update the code.")

except FileNotFoundError:
    print("Error: The file was not found at the specified path.")
except Exception as e:
    print(f"An error occurred while reading the Excel file: {e}")
# Out:
# Excel file loaded successfully.
# Extracted 149703 documents.

# %%
#TFinding the dominant topic in each sentence

def format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts): # Updated to use loaded_lda_model and corpus, and texts=None
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = pd.concat([sent_topics_df, pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]).to_frame().T], ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

     # Add original text to the end of the output
    if texts is not None: # Added check if texts is not None
        contents = pd.Series(texts)
        sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


# Assuming texts is available as data_words or you provide another list/Series of texts
# df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts) # Updated to use loaded_lda_model and corpus, commented out as data_words is undefined
# To run this cell, define `data_words` with your text data before calling the function.
# For example:
# data_words = ["your document text 1", "your document text 2", ...]
# Then uncomment the line below:
df_topic_sents_keywords = format_topics_sentences(ldamodel=loaded_lda_model, corpus=corpus, texts=texts)

# Format
if 'df_topic_sents_keywords' in locals(): # Added check if df_topic_sents_keywords is defined
    df_dominant_topic = df_topic_sents_keywords.reset_index()
    df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
    # Show
    display(df_dominant_topic.head(20)) # Use display for better formatting
# Out:
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0             0             10             0.3776
# 1             1              0             0.2295
# 2             2             10             0.3691
# 3             3             10             0.2876
# 4             4             12             0.3326
# 5             5              7             0.2607
# 6             6             12             0.4864
# 7             7             12               0.37
# 8             8             10             0.2839
# 9             9              3             0.2839
# 10           10             10              0.208
# 11           11             16              0.271
# 12           12             10             0.2834
# 13           13             10             0.3405
# 14           14             10             0.4785
# 15           15              4              0.504
# 16           16             15             0.1977
# 17           17              4             0.7415
# 18           18              0             0.4455
# 19           19              8             0.5551
#
#                                              Keywords  \
# 0   said, like, would, going, get, year, one, team...
# 1   coach, basketball, year, coaching, head, progr...
# 2   said, like, would, going, get, year, one, team...
# 3   said, like, would, going, get, year, one, team...
# 4   draft, season, nba, player, pick, league, team...
# 5   per, point, 2024, season, ppg, guard, g, last,...
# 6   draft, season, nba, player, pick, league, team...
# 7   draft, season, nba, player, pick, league, team...
# 8   said, like, would, going, get, year, one, team...
# 9   nil, people, day, one, say, family, trump, lif...
# 10  said, like, would, going, get, year, one, team...
# 11  golf, tour, open, championship, 2023, round, t...
# 12  said, like, would, going, get, year, one, team...
# 13  said, like, would, going, get, year, one, team...
# 14  said, like, would, going, get, year, one, team...
# 15  ncaa, said, college, school, athlete, sport, s...
# 16  arizona, baseball, game, asu, run, series, sof...
# 17  ncaa, said, college, school, athlete, sport, s...
# 18  coach, basketball, year, coaching, head, progr...
# 19  tournament, team, state, big, ncaa, seed, game...
#
#                                                  Text
# 0   ['14', 'year', 'coaching', '39', 'year', 'livi...
# 1   ['see', 'sidebar', '02c', 'ruston', 'la', 'din...
# 2   ['gave', 'garden', 'exactly', 'missed', 'lonel...
# 3   ['indianapolis', 'ten', 'year', 'ago', 'chuck'...
# 4   ['robinson', 'talk', 'ranger', 'stanley', 'cup...
# 5   ['usc', 'conference', 'pacific10', 'coach', 'm...
# 6   ['ranger', 'signed', 'center', 'michael', 'nyl...
# 7   ['gavitt', 'five', 'others', 'elected', 'hall'...
# 8   ['almost', 'mythical', 'element', 'lsu', 'seni...
# 9   ['ncaa', 'woman', 'jim', 'izard', 'diana', 'vi...
# 10  ['meet', 'george', 'mason', 'guard', 'lamar', ...
# 11  ['kevin', 'iole', 'reviewjournal', 'local', 'g...
# 12  ['seventh', 'time', 'coach', 'john', 'beilein'...
# 13  ['demetrius', 'jones', 'clear', 'want', 'talk'...
# 14  ['oakland', 'eating', 'gilbert', 'arena', 'go'...
# 15  ['nothing', 'bothered', 'myles', 'brand', 'ter...
# 16  ['yes', 'lot', 'secondguessing', 'season', 're...
# 17  ['state', 'college', 'pa', 'ncaa', 'sent', 'pe...
# 18  ['first', 'person', 'called', 'got', 'call', '...
# 19  ['selection', 'sunday', 'month', 'away', 'ncaa...

# %%
# Display the first few rows of the dataframe to see the structure
display(df_dominant_topic.head())
# Out:
#    Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0            0             10             0.3776
# 1            1              0             0.2295
# 2            2             10             0.3691
# 3            3             10             0.2876
# 4            4             12             0.3326
#
#                                             Keywords  \
# 0  said, like, would, going, get, year, one, team...
# 1  coach, basketball, year, coaching, head, progr...
# 2  said, like, would, going, get, year, one, team...
# 3  said, like, would, going, get, year, one, team...
# 4  draft, season, nba, player, pick, league, team...
#
#                                                 Text
# 0  ['14', 'year', 'coaching', '39', 'year', 'livi...
# 1  ['see', 'sidebar', '02c', 'ruston', 'la', 'din...
# 2  ['gave', 'garden', 'exactly', 'missed', 'lonel...
# 3  ['indianapolis', 'ten', 'year', 'ago', 'chuck'...
# 4  ['robinson', 'talk', 'ranger', 'stanley', 'cup...

# %%
# Sort documents within each topic by percentage contribution in descending order
sorted_documents_by_topic = df_dominant_topic.sort_values(by=['Dominant_Topic', 'Topic_Perc_Contrib'], ascending=[True, False])

# Display the sorted document indexes for each topic
print("Document Indexes for Each Topic (Sorted by Percentage Contribution):")
for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    print(f"\nTopic {topic_num}:")
    # Get documents for the current topic and select only the 'Document_No' column
    topic_documents = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num]['Document_No']
    # Display the document indexes (first 20 as an example)
    print(topic_documents.tolist()[:20])
# Out:
# Document Indexes for Each Topic (Sorted by Percentage Contribution):
#
# Topic 0:
# [77310, 40770, 136344, 70117, 127111, 133169, 59899, 21185, 147967, 18434, 43756, 129285, 43203, 39241, 23956, 61747, 42625, 131189, 56693, 27227]
#
# Topic 1:
# [55253, 23432, 66229, 3559, 79820, 70245, 15491, 26292, 51516, 3514, 4289, 63502, 13649, 63873, 72095, 83855, 72451, 29071, 34546, 62535]
#
# Topic 2:
# [2563, 83747, 86239, 71938, 137523, 55680, 137336, 5021, 142444, 139189, 99549, 137533, 109804, 82349, 7982, 21692, 55681, 45903, 112427, 121171]
#
# Topic 3:
# [30262, 72564, 29750, 106623, 89946, 80583, 60071, 18918, 95222, 26015, 6303, 119581, 43917, 38776, 55847, 6724, 55902, 104746, 40564, 147347]
#
# Topic 4:
# [70792, 32177, 70785, 127699, 138582, 112461, 33945, 43676, 89536, 143166, 143165, 105593, 43289, 24192, 101598, 133827, 47889, 129820, 131623, 132902]
#
# Topic 5:
# [21267, 24696, 31532, 27131, 1928, 24580, 3776, 3777, 103299, 35645, 48405, 143889, 13955, 122244, 27528, 54726, 144713, 59435, 131635, 83131]
#
# Topic 6:
# [9057, 3626, 131280, 128482, 47008, 39350, 17750, 43262, 89420, 44324, 11156, 7707, 44315, 48911, 80027, 131272, 87646, 35704, 4613, 5163]
#
# Topic 7:
# [60308, 24454, 24456, 24457, 24455, 37714, 41463, 45311, 42531, 29968, 28972, 29137, 34971, 103768, 1727, 39635, 3909, 4739, 67106, 115343]
#
# Topic 8:
# [256, 58953, 79094, 9378, 146602, 52877, 71087, 10637, 117089, 80229, 147779, 146598, 146608, 146599, 83098, 118679, 146610, 129447, 146986, 99173]
#
# Topic 9:
# [57241, 50109, 144783, 49889, 50431, 79081, 79535, 57243, 135733, 95494, 51771, 204, 92275, 98562, 146913, 98979, 149881, 57428, 39702, 58258]
#
# Topic 10:
# [54020, 86617, 35053, 125658, 72610, 118762, 122409, 66130, 139995, 73069, 131993, 144022, 35880, 108566, 108375, 88225, 63011, 101127, 141656, 25683]
#
# Topic 11:
# [28728, 28807, 143634, 47116, 28806, 106005, 132029, 110990, 94889, 71743, 19692, 105959, 37378, 9451, 41876, 73223, 98879, 98880, 98883, 102884]
#
# Topic 12:
# [28076, 4854, 117829, 97330, 4861, 47732, 14745, 39042, 87351, 25950, 32788, 35737, 20992, 28504, 90124, 28503, 28502, 120243, 80291, 32546]
#
# Topic 13:
# [51816, 25533, 79168, 50618, 13069, 148107, 20710, 130450, 21290, 16865, 35403, 50877, 63912, 82784, 17671, 13068, 141122, 67325, 131850, 11376]
#
# Topic 14:
# [95185, 10988, 142348, 44975, 41837, 120902, 57541, 51638, 88946, 70836, 21681, 56761, 17404, 68406, 15727, 48710, 50830, 6135, 35543, 13915]
#
# Topic 15:
# [10998, 130271, 36431, 71749, 98639, 69597, 17263, 88178, 118329, 56545, 70273, 10895, 72400, 68883, 71738, 112010, 10897, 36409, 114995, 113820]
#
# Topic 16:
# [74149, 30536, 40931, 82108, 37076, 22376, 104822, 9912, 3010, 19378, 3459, 105809, 6159, 13783, 5680, 31722, 19294, 45651, 31411, 7122]
#
# Topic 17:
# [63571, 63969, 28279, 83052, 72243, 56251, 14620, 72068, 75447, 77753, 88067, 98487, 70880, 39933, 122384, 122385, 71718, 110066, 61644, 19163]
#
# Topic 18:
# [29156, 79729, 31218, 5039, 33437, 115455, 54405, 87567, 5019, 24353, 24572, 109106, 120554, 53204, 75240, 100319, 77481, 39359, 149898, 72954]
#
# Topic 19:
# [38552, 46055, 9233, 28722, 31712, 117052, 111483, 87411, 9232, 44395, 147033, 45838, 122225, 111217, 175, 9231, 77146, 19698, 120922, 82934]

# %%
# Get the total number of documents for each dominant topic
topic_counts = df_dominant_topic['Dominant_Topic'].value_counts().sort_index()

print("Total number of documents for each topic:")
display(topic_counts)
# Out:
# Total number of documents for each topic:
# Dominant_Topic
# 0      4575
# 1      7568
# 2      3923
# 3      7320
# 4     14313
# 5      6935
# 6     16703
# 7      1870
# 8     12255
# 9       663
# 10    35809
# 11     2458
# 12     7247
# 13     8344
# 14     4120
# 15     3397
# 16     1901
# 17     5887
# 18     4320
# 19      611
# Name: count, dtype: int64

# %%
# Get the top 100 documents for each topic
top_100_documents_per_topic = pd.DataFrame()

for topic_num in sorted_documents_by_topic['Dominant_Topic'].unique():
    # Get the top 100 documents for the current topic
    top_100 = sorted_documents_by_topic[sorted_documents_by_topic['Dominant_Topic'] == topic_num].head(100)
    # Append to the results DataFrame
    top_100_documents_per_topic = pd.concat([top_100_documents_per_topic, top_100], ignore_index=True)

# Display the top 100 documents for each topic
print("Top 100 Documents for Each Topic (Sorted by Percentage Contribution):")

# Iterate through topics and display the top documents for each
for topic_num in top_100_documents_per_topic['Dominant_Topic'].unique():
    print(f"\n--- Topic {topic_num} ---")
    display(top_100_documents_per_topic[top_100_documents_per_topic['Dominant_Topic'] == topic_num])
# Out:
# Top 100 Documents for Each Topic (Sorted by Percentage Contribution):
#
# --- Topic 0 ---
#     Document_No Dominant_Topic Topic_Perc_Contrib  \
# 0         77310              0             0.8944
# 1         40770              0             0.8565
# 2        136344              0             0.8416
# 3         70117              0             0.7034
# 4        127111              0             0.6946
# ..          ...            ...                ...
# 95        90200              0             0.5406
# 96       114647              0             0.5385
# 97       133395              0             0.5382
# 98        85950              0             0.5371
# 99       142592              0             0.5371
#
#                                              Keywords  \
# 0   coach, basketball, year, coaching, head, progr...
# 1   coach, basketball, year, coaching, head, progr...
# 2   coach, basketball, year, coaching, head, progr...
# 3   coach, basketball, year, coaching, head, progr...
# 4   coach, basketball, year, coaching, head, progr...
# ..                                                ...
# 95  coach, basketball, year, coaching, head, progr...
# 96  coach, basketball, year, coaching, head, progr...
# 97  coach, basketball, year, coaching, head, progr...
# 98  coach, basketball, year, coaching, head, progr...
# 99  coach, basketball, year, coaching, head, progr...
#
#                                                  Text
# 0   ['denver', 'watching', 'ncaa', 'tournament', '...
# 1   ['ninetime', 'winner', 'michelle', 'kwan', 'ye...
# 2   ['august', '2004', 'michael', 'oher', 'living'...
# 3   ['nhl', 'reportedly', 'signed', 'ilya', 'koval...
# 4   ['tournament', 'played', 'indiana', 'mostly', ...
# ..                                                ...
# 95  ['jerry', 'bus', 'enroll', 'usc', 'graduate', ...
# 96  ['back', 'snark', 'age', 'mlb', 'player', 'ass...
# 97  ['popular', 'refrain', 'talking', 'kyle', 'nep...
# 98  ['note', 'college', 'basketball', 'preview', '...
# 99  ['illinois', 'fighting', 'illini', 'nebraska',...
#
# [100 rows x 5 columns]
# --- Topic 1 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 100        55253              1             0.8532
# 101        23432              1             0.8312
# 102        66229              1             0.8183
# 103         3559              1             0.7841
# 104        79820              1             0.7787
# ..           ...            ...                ...
# 195        51017              1             0.5859
# 196         9428              1             0.5855
# 197        76467              1             0.5855
# 198        62090              1              0.585
# 199        41735              1             0.5844
#
#                                               Keywords  \
# 100  school, year, player, high, season, team, coll...
# 101  school, year, player, high, season, team, coll...
# 102  school, year, player, high, season, team, coll...
# 103  school, year, player, high, season, team, coll...
# 104  school, year, player, high, season, team, coll...
# ..                                                 ...
# 195  school, year, player, high, season, team, coll...
# 196  school, year, player, high, season, team, coll...
# 197  school, year, player, high, season, team, coll...
# 198  school, year, player, high, season, team, coll...
# 199  school, year, player, high, season, team, coll...
#
#                                                   Text
# 100  ['nearly', 'two', 'year', 'since', 'ncaa', 'op...
# 101  ['upset', 'stomach', 'headache', 'dealt', 'day...
# 102  ['pasadena', 'ucla', 'deserves', 'play', 'bowl...
# 103  ['sport', 'monday', 'round', 'one', 'usc', 'li...
# 104  ['sport', 'delicious', 'duality', 'definite', ...
# ..                                                 ...
# 195  ['matt', 'youmans', 'reviewjournal', 'plain', ...
# 196  ['jordan', 'call', 'career', 'certainly', 'las...
# 197  ['long', 'time', 'since', 'temple', 'experienc...
# 198  ['former', 'bull', 'assistant', 'coach', 'tex'...
# 199  ['durham', 'nc', 'like', 'ivory', 'latta', 'no...
#
# [100 rows x 5 columns]
# --- Topic 2 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 200         2563              2             0.8384
# 201        83747              2             0.7917
# 202        86239              2             0.7819
# 203        71938              2             0.7727
# 204       137523              2             0.7702
# ..           ...            ...                ...
# 295       132720              2             0.6501
# 296        26871              2             0.6494
# 297        71937              2             0.6491
# 298        66697              2             0.6485
# 299        74778              2             0.6485
#
#                                               Keywords  \
# 200  gopher, hockey, minnesota, game, goal, team, s...
# 201  gopher, hockey, minnesota, game, goal, team, s...
# 202  gopher, hockey, minnesota, game, goal, team, s...
# 203  gopher, hockey, minnesota, game, goal, team, s...
# 204  gopher, hockey, minnesota, game, goal, team, s...
# ..                                                 ...
# 295  gopher, hockey, minnesota, game, goal, team, s...
# 296  gopher, hockey, minnesota, game, goal, team, s...
# 297  gopher, hockey, minnesota, game, goal, team, s...
# 298  gopher, hockey, minnesota, game, goal, team, s...
# 299  gopher, hockey, minnesota, game, goal, team, s...
#
#                                                   Text
# 200  ['st', 'paul', '7', 'inch', 'snow', 'ground', ...
# 201  ['florida', 'junior', 'tennis', 'player', 'all...
# 202  ['family', 'member', 'erik', 'scott', 'shot', ...
# 203  ['1', 'end', 'except', 'dozen', 'game', 'next'...
# 204  ['plenty', 'discussion', 'heading', 'men', 'co...
# ..                                                 ...
# 295  ['beijing', '7', 'month', 'old', 'baby', 'home...
# 296  ['former', 'gopher', 'shani', 'mark', 'attempt...
# 297  ['year', 'ago', 'gopher', 'men', 'basketball',...
# 298  ['preparation', 'tomorrow', 'season', 'opener'...
# 299  ['frank', 'busch', 'completing', '22year', 'ca...
#
# [100 rows x 5 columns]
# --- Topic 3 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 300        30262              3             0.7527
# 301        72564              3             0.7386
# 302        29750              3             0.7288
# 303       106623              3             0.7251
# 304        89946              3              0.724
# ..           ...            ...                ...
# 395        53894              3             0.6163
# 396        94540              3             0.6161
# 397        65909              3             0.6159
# 398        83282              3             0.6158
# 399        59116              3             0.6157
#
#                                               Keywords  \
# 300  nil, people, day, one, say, family, trump, lif...
# 301  nil, people, day, one, say, family, trump, lif...
# 302  nil, people, day, one, say, family, trump, lif...
# 303  nil, people, day, one, say, family, trump, lif...
# 304  nil, people, day, one, say, family, trump, lif...
# ..                                                 ...
# 395  nil, people, day, one, say, family, trump, lif...
# 396  nil, people, day, one, say, family, trump, lif...
# 397  nil, people, day, one, say, family, trump, lif...
# 398  nil, people, day, one, say, family, trump, lif...
# 399  nil, people, day, one, say, family, trump, lif...
#
#                                                   Text
# 300  ['spotlight', 'always', 'seemed', 'find', 'edd...
# 301  ['new', 'math', 'wrested', 'control', 'ncaa', ...
# 302  ['elton', 'brand', 'disappointment', 'reaching...
# 303  ['providence', 'house', 'empty', 'roommate', '...
# 304  ['sack', 'king', 'strahanheads', 'hall', 'fina...
# ..                                                 ...
# 395  ['march', 'madness', 'ithaca', 'ny', 'lonely',...
# 396  ['special', 'star', 'tribune', 'looking', 'pip...
# 397  ['snow', 'sport', 'last', 'barely', 'five', 's...
# 398  ['finally', 'arizona', 'state', 'six', 'year',...
# 399  ['derrick', 'rose', 'getting', 'stitch', 'way'...
#
# [100 rows x 5 columns]
# --- Topic 4 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 400        70792              4             0.9921
# 401        32177              4             0.9768
# 402        70785              4             0.9604
# 403       127699              4             0.9552
# 404       138582              4             0.9488
# ..           ...            ...                ...
# 495       141857              4             0.8678
# 496        64704              4             0.8677
# 497        15311              4             0.8675
# 498        35993              4             0.8673
# 499        73719              4             0.8671
#
#                                               Keywords  \
# 400  ncaa, said, college, school, athlete, sport, s...
# 401  ncaa, said, college, school, athlete, sport, s...
# 402  ncaa, said, college, school, athlete, sport, s...
# 403  ncaa, said, college, school, athlete, sport, s...
# 404  ncaa, said, college, school, athlete, sport, s...
# ..                                                 ...
# 495  ncaa, said, college, school, athlete, sport, s...
# 496  ncaa, said, college, school, athlete, sport, s...
# 497  ncaa, said, college, school, athlete, sport, s...
# 498  ncaa, said, college, school, athlete, sport, s...
# 499  ncaa, said, college, school, athlete, sport, s...
#
#                                                   Text
# 400  ['peace', 'new', 'prosperity', 'college', 'men...
# 401  ['special', 'section', 'ncaa', 'tournament', '...
# 402  ['cloud', 'auburn', 'cam', 'newton', 'lifted',...
# 403  ['detail', 'determined', 'long', 'beforehand',...
# 404  ['1955', 'montreal', 'jean', 'beliveau', 'scor...
# ..                                                 ...
# 495  ['10', 'year', 'college', 'football', 'finally...
# 496  ['dream', 'maker', 'found', 'one', 'boy', 'liv...
# 497  ['certainly', 'look', 'like', 'location', 'sho...
# 498  ['college', 'basketball', '1', 'illinois', '27...
# 499  ['11thranked', 'georgetown', 'notre', 'dame', ...
#
# [100 rows x 5 columns]
# --- Topic 5 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 500        21267              5             0.9224
# 501        24696              5             0.8915
# 502        31532              5             0.8349
# 503        27131              5             0.8322
# 504         1928              5             0.8302
# ..           ...            ...                ...
# 595         9067              5               0.71
# 596        34261              5             0.7092
# 597        17346              5             0.7085
# 598       127555              5             0.7083
# 599       131880              5             0.7082
#
#                                               Keywords  \
# 500  woman, u, championship, olympic, world, team, ...
# 501  woman, u, championship, olympic, world, team, ...
# 502  woman, u, championship, olympic, world, team, ...
# 503  woman, u, championship, olympic, world, team, ...
# 504  woman, u, championship, olympic, world, team, ...
# ..                                                 ...
# 595  woman, u, championship, olympic, world, team, ...
# 596  woman, u, championship, olympic, world, team, ...
# 597  woman, u, championship, olympic, world, team, ...
# 598  woman, u, championship, olympic, world, team, ...
# 599  woman, u, championship, olympic, world, team, ...
#
#                                                   Text
# 500  ['football', 'weekend', 'week', 'usa', 'today'...
# 501  ['frozen', 'four', '2004', 'ncaa', 'men', 'hoc...
# 502  ['jones', 'say', 'head', 'coaching', 'job', 'c...
# 503  ['one', 'record', 'aspire', 'shatter', 'speak'...
# 504  ['record', 'update', 'quick', 'read', 'news', ...
# ..                                                 ...
# 595  ['power', 'failure', 'thursday', 'winter', 'st...
# 596  ['taketwo', 'interactive', 'software', 'inc', ...
# 597  ['view', 'soldier', 'getting', 'killed', 'dail...
# 598  ['rocket', 'watt', 'scored', '21', 'point', 'a...
# 599  ['unusual', 'villanova', 'better', 'basketball...
#
# [100 rows x 5 columns]
# --- Topic 6 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 600         9057              6             0.8152
# 601         3626              6             0.7961
# 602       131280              6             0.7961
# 603       128482              6             0.7916
# 604        47008              6             0.7909
# ..           ...            ...                ...
# 695        35277              6             0.6992
# 696        39916              6             0.6992
# 697       116554              6             0.6992
# 698        80743              6             0.6991
# 699       123890              6             0.6989
#
#                                               Keywords  \
# 600  game, point, shot, first, second, said, minute...
# 601  game, point, shot, first, second, said, minute...
# 602  game, point, shot, first, second, said, minute...
# 603  game, point, shot, first, second, said, minute...
# 604  game, point, shot, first, second, said, minute...
# ..                                                 ...
# 695  game, point, shot, first, second, said, minute...
# 696  game, point, shot, first, second, said, minute...
# 697  game, point, shot, first, second, said, minute...
# 698  game, point, shot, first, second, said, minute...
# 699  game, point, shot, first, second, said, minute...
#
#                                                   Text
# 600  ['university', 'maryland', 'men', 'basketball'...
# 601  ['connie', 'tressel', 'dilemma', 'sure', 'shad...
# 602  ['st', 'thomas', 'picked', 'new', 'men', 'hock...
# 603  ['tanner', 'morgan', 'final', 'two', 'snap', '...
# 604  ['la', 'vega', 'former', 'ucla', 'quarterback'...
# ..                                                 ...
# 695  ['advertiser', 'staff', 'university', 'hawai',...
# 696  ['brennan', 'mark', 'get', 'help', 'would', 'e...
# 697  ['paige', 'hauschild', 'could', 'easily', 'wea...
# 698  ['field', 'pull', 'first', 'individual', 'pga'...
# 699  ['2020', 'mlb', 'draft', 'unlike', 'instead', ...
#
# [100 rows x 5 columns]
# --- Topic 7 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 700        60308              7             0.9004
# 701        24454              7             0.8655
# 702        24456              7             0.8576
# 703        24457              7             0.8539
# 704        24455              7             0.8538
# ..           ...            ...                ...
# 795        27265              7             0.6953
# 796        80296              7             0.6949
# 797        39643              7             0.6944
# 798        39638              7             0.6941
# 799       111747              7             0.6941
#
#                                               Keywords  \
# 700  per, point, 2024, season, ppg, guard, g, last,...
# 701  per, point, 2024, season, ppg, guard, g, last,...
# 702  per, point, 2024, season, ppg, guard, g, last,...
# 703  per, point, 2024, season, ppg, guard, g, last,...
# 704  per, point, 2024, season, ppg, guard, g, last,...
# ..                                                 ...
# 795  per, point, 2024, season, ppg, guard, g, last,...
# 796  per, point, 2024, season, ppg, guard, g, last,...
# 797  per, point, 2024, season, ppg, guard, g, last,...
# 798  per, point, 2024, season, ppg, guard, g, last,...
# 799  per, point, 2024, season, ppg, guard, g, last,...
#
#                                                   Text
# 700  ['school', 'policy', 'stanford', 'university',...
# 701  ['cal', 'state', 'northridge', 'men', 'basketb...
# 702  ['major', 'college', 'longer', 'allowed', 'sch...
# 703  ['casey', 'janssen', 'kevin', 'brophy', 'held'...
# 704  ['troubled', 'persistently', 'poor', 'graduati...
# ..                                                 ...
# 795  ['idea', 'get', 'radar', 'screen', 'march', 'l...
# 796  ['glen', 'taylor', 'hoped', 'much', 'improved'...
# 797  ['college', 'basketball', 'article', 'tuesday'...
# 798  ['martin', 'gramatica', 'cleverly', 'billed', ...
# 799  ['new', 'york', 'second', 'straight', 'game', ...
#
# [100 rows x 5 columns]
# --- Topic 8 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 800          256              8             0.9827
# 801        58953              8             0.9635
# 802        79094              8             0.9525
# 803         9378              8               0.95
# 804       146602              8             0.9429
# ..           ...            ...                ...
# 895        98230              8             0.8078
# 896       124662              8             0.8077
# 897       148042              8             0.8072
# 898       120018              8             0.8063
# 899       119218              8             0.8051
#
#                                               Keywords  \
# 800  tournament, team, state, big, ncaa, seed, game...
# 801  tournament, team, state, big, ncaa, seed, game...
# 802  tournament, team, state, big, ncaa, seed, game...
# 803  tournament, team, state, big, ncaa, seed, game...
# 804  tournament, team, state, big, ncaa, seed, game...
# ..                                                 ...
# 895  tournament, team, state, big, ncaa, seed, game...
# 896  tournament, team, state, big, ncaa, seed, game...
# 897  tournament, team, state, big, ncaa, seed, game...
# 898  tournament, team, state, big, ncaa, seed, game...
# 899  tournament, team, state, big, ncaa, seed, game...
#
#                                                   Text
# 800  ['special', 'section', 'march', 'atlanta', 'br...
# 801  ['miami', '78', 'maryland', '63', 'one', 'week...
# 802  ['one', 'admires', 'warren', 'sapp', 'late', '...
# 803  ['unheardof', 'nfl', 'draft', '20yearolds', 'b...
# 804  ['15th', 'time', 'program', 'history', 'duke',...
# ..                                                 ...
# 895  ['mai', 'mitsuyama', 'started', '84', 'game', ...
# 896  ['last', 'series', 'nov', '14', '1994', 'holy'...
# 897  ['march', 'madness', 'time', 'quirky', 'midmaj...
# 898  ['porter', 'moser', 'losing', 'righthand', 'ma...
# 899  ['monday', 'afternoon', 'sam', 'lindemann', 'c...
#
# [100 rows x 5 columns]
# --- Topic 9 ---
#      Document_No Dominant_Topic Topic_Perc_Contrib  \
# 900        57241              9             0.8812
# 901        50109              9             0.8643
# 902       144783              9             0.8291
# 903        49889              9             0.7625
# 904        50431              9             0.6934
# ..           ...            ...                ...
# 995        55506              9             0.3834
# 996        64718              9              0.381
# 997       119959              9             0.3805
# 998       140237              9             0.3803
# 999        80848              9             0.3794
#
#                                               Keywords  \
# 900  woman, uconn, clark, basketball, south, caroli...
# 901  woman, uconn, clark, basketball, south, caroli...
# 902  woman, uconn, clark, basketball, south, caroli...
# 903  woman, uconn, clark, basketball, south, caroli...
# 904  woman, uconn, clark, basketball, south, caroli...
# ..                                                 ...
# 995  woman, uconn, clark, basketball, south, caroli...
# 996  woman, uconn, clark, basketball, south, caroli...
# 997  woman, uconn, clark, basketball, south, caroli...
# 998  woman, uconn, clark, basketball, south, caroli...
# 999  woman, uconn, clark, basketball, south, caroli...
#
#                                                   Text
# 900  ['allen', 'park', 'mich', 'day', '2', 'nfc', '...
# 901  ['new', 'eye', 'college', 'football', 'officia...
# 902  ['college', 'park', 'md', 'music', 'fit', 'all...
# 903  ['fan', 'streamed', 'spokane', 'arena', 'frida...
# 904  ['north', 'carolina', 'start', 'men', 'basketb...
# ..                                                 ...
# 995  ['globe', 'north', '1', 'sport', 'diamond', 'm...
# 996  ['stuart', 'rabinowitz', 'finest', 'public', '...
# 997  ['washington', 'defense', 'secretary', 'mark',...
# 998  ['woman', 'elite', 'eight', 'field', 'set', '2...
# 999  ['ncaa', 'last', 'week', 'leveled', 'potential...
#
# [100 rows x 5 columns]
# --- Topic 10 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1000        54020             10             0.8038
# 1001        86617             10             0.7691
# 1002        35053             10              0.765
# 1003       125658             10             0.7635
# 1004        72610             10             0.7588
# ...           ...            ...                ...
# 1095       124372             10             0.6578
# 1096        49976             10             0.6558
# 1097        88696             10              0.655
# 1098        92221             10             0.6543
# 1099        84114             10             0.6541
#
#                                                Keywords  \
# 1000  said, like, would, going, get, year, one, team...
# 1001  said, like, would, going, get, year, one, team...
# 1002  said, like, would, going, get, year, one, team...
# 1003  said, like, would, going, get, year, one, team...
# 1004  said, like, would, going, get, year, one, team...
# ...                                                 ...
# 1095  said, like, would, going, get, year, one, team...
# 1096  said, like, would, going, get, year, one, team...
# 1097  said, like, would, going, get, year, one, team...
# 1098  said, like, would, going, get, year, one, team...
# 1099  said, like, would, going, get, year, one, team...
#
#                                                    Text
# 1000  ['waco', 'texas', 'proved', 'much', 'much', 'l...
# 1001  ['week', 'remaining', 'selection', 'sunday', '...
# 1002  ['2005', 'player', 'championship', 'bonus', 's...
# 1003  ['jumbled', 'season', 'college', 'basketball',...
# 1004  ['america', 'ready', 'forgive', 'tiger', 'wood...
# ...                                                 ...
# 1095  ['even', 'warm', 'one', 'fact', 'oregon', 'coa...
# 1096  ['buffalo', 'whatifs', 'bob', 'mckillop', 'wor...
# 1097  ['ballot', 'day', 'one', 'vote', 'kept', 'lebr...
# 1098  ['outward', 'appearance', 'baseball', 'state',...
# 1099  ['penn', 'state', 'senior', 'michael', 'zordic...
#
# [100 rows x 5 columns]
# --- Topic 11 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1100        28728             11              0.992
# 1101        28807             11             0.9798
# 1102       143634             11             0.9765
# 1103        47116             11              0.958
# 1104        28806             11             0.9527
# ...           ...            ...                ...
# 1195       105935             11             0.8156
# 1196        39607             11             0.8151
# 1197         8857             11             0.8148
# 1198        95221             11             0.8129
# 1199       147914             11             0.8101
#
#                                       Keywords  \
# 1100  v, pm, state, 1, 2, game, march, 3, 4, 7
# 1101  v, pm, state, 1, 2, game, march, 3, 4, 7
# 1102  v, pm, state, 1, 2, game, march, 3, 4, 7
# 1103  v, pm, state, 1, 2, game, march, 3, 4, 7
# 1104  v, pm, state, 1, 2, game, march, 3, 4, 7
# ...                                        ...
# 1195  v, pm, state, 1, 2, game, march, 3, 4, 7
# 1196  v, pm, state, 1, 2, game, march, 3, 4, 7
# 1197  v, pm, state, 1, 2, game, march, 3, 4, 7
# 1198  v, pm, state, 1, 2, game, march, 3, 4, 7
# 1199  v, pm, state, 1, 2, game, march, 3, 4, 7
#
#                                                    Text
# 1100  ['allscholatics', 'spring', '2005', 'player', ...
# 1101  ['christening', 'daniel', 'gibson', 'rising', ...
# 1102  ['c', 'onnor', 'bedard', '19yearold', 'blackha...
# 1103  ['history', 'geography', 'offer', 'indication'...
# 1104  ['colton', 'coach', 'remember', 'allen', 'brad...
# ...                                                 ...
# 1195  ['monday', 'night', '443', 'second', 'period',...
# 1196  ['25', 'year', 'ago', 'asu', '24', 'ua', '13',...
# 1197  ['ruth', 'ann', 'gardner', 'stepped', 'grand',...
# 1198  ['connecticut', 'woman', 'basketball', 'team',...
# 1199  ['semifinal', 'men', 'nit', 'national', 'invit...
#
# [100 rows x 5 columns]
# --- Topic 12 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1200        28076             12             0.7727
# 1201         4854             12             0.7629
# 1202       117829             12             0.7441
# 1203        97330             12             0.7433
# 1204         4861             12             0.7171
# ...           ...            ...                ...
# 1295       133272             12             0.5841
# 1296        58262             12             0.5834
# 1297         6514             12             0.5833
# 1298        39362             12             0.5829
# 1299       120239             12             0.5821
#
#                                                Keywords  \
# 1200  draft, season, nba, player, pick, league, team...
# 1201  draft, season, nba, player, pick, league, team...
# 1202  draft, season, nba, player, pick, league, team...
# 1203  draft, season, nba, player, pick, league, team...
# 1204  draft, season, nba, player, pick, league, team...
# ...                                                 ...
# 1295  draft, season, nba, player, pick, league, team...
# 1296  draft, season, nba, player, pick, league, team...
# 1297  draft, season, nba, player, pick, league, team...
# 1298  draft, season, nba, player, pick, league, team...
# 1299  draft, season, nba, player, pick, league, team...
#
#                                                    Text
# 1200  ['shanna', 'zolman', 'scored', '23', 'point', ...
# 1201  ['letter', 'wilt', 'chamberlain', 'kareem', 'a...
# 1202  ['big', 'west', 'men', 'basketball', 'tourname...
# 1203  ['washington', 'wizard', 'relatively', 'muted'...
# 1204  ['successful', 'eligibility', 'appeal', 'arizo...
# ...                                                 ...
# 1295  ['pittsburgh', 'eric', 'dixon', 'play', 'final...
# 1296  ['inventor', 'timing', 'device', 'used', '1', ...
# 1297  ['wrestling', '40th', 'midland', 'wrestling', ...
# 1298  ['electronic', 'art', 'inc', 'posted', 'unexpe...
# 1299  ['editor', 'note', 'story', 'updated', 'latest...
#
# [100 rows x 5 columns]
# --- Topic 13 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1300        51816             13              0.975
# 1301        25533             13             0.8587
# 1302        79168             13              0.848
# 1303        50618             13             0.8433
# 1304        13069             13             0.8432
# ...           ...            ...                ...
# 1395        97940             13             0.6841
# 1396         3528             13             0.6839
# 1397       104298             13             0.6824
# 1398         9204             13             0.6817
# 1399        53688             13             0.6813
#
#                                                Keywords  \
# 1300  football, game, state, season, quarterback, bo...
# 1301  football, game, state, season, quarterback, bo...
# 1302  football, game, state, season, quarterback, bo...
# 1303  football, game, state, season, quarterback, bo...
# 1304  football, game, state, season, quarterback, bo...
# ...                                                 ...
# 1395  football, game, state, season, quarterback, bo...
# 1396  football, game, state, season, quarterback, bo...
# 1397  football, game, state, season, quarterback, bo...
# 1398  football, game, state, season, quarterback, bo...
# 1399  football, game, state, season, quarterback, bo...
#
#                                                    Text
# 1300  ['first', 'time', 'three', 'year', 'kansa', 'c...
# 1301  ['louisville', 'like', 'injuryriddled', 'louis...
# 1302  ['cbs', 'connecticutbutler', 'ncaa', 'men', 'b...
# 1303  ['maybe', 'possibly', 'way', 'went', 'temple',...
# 1304  ['gail', 'goodrich', 'might', 'greatest', 'bas...
# ...                                                 ...
# 1395  ['past', 'week', 'exhilarating', 'emotional', ...
# 1396  ['ncaa', 'tournament', 'indiana', 'senior', 'f...
# 1397  ['fatherson', 'night', 'wednesday', 'gola', 'a...
# 1398  ['two', 'school', 'thought', 'whether', 'unlv'...
# 1399  ['bad', 'news', 'northwestern', 'fan', 'wildca...
#
# [100 rows x 5 columns]
# --- Topic 14 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1400        95185             14             0.9211
# 1401        10988             14             0.9209
# 1402       142348             14             0.9077
# 1403        44975             14             0.9006
# 1404        41837             14              0.897
# ...           ...            ...                ...
# 1495        24347             14             0.6409
# 1496         5050             14             0.6395
# 1497        17729             14             0.6381
# 1498       109613             14             0.6376
# 1499        45235             14             0.6358
#
#                                                Keywords  \
# 1400  tournament, st, game, goal, east, john, first,...
# 1401  tournament, st, game, goal, east, john, first,...
# 1402  tournament, st, game, goal, east, john, first,...
# 1403  tournament, st, game, goal, east, john, first,...
# 1404  tournament, st, game, goal, east, john, first,...
# ...                                                 ...
# 1495  tournament, st, game, goal, east, john, first,...
# 1496  tournament, st, game, goal, east, john, first,...
# 1497  tournament, st, game, goal, east, john, first,...
# 1498  tournament, st, game, goal, east, john, first,...
# 1499  tournament, st, game, goal, east, john, first,...
#
#                                                    Text
# 1400  ['first', 'reminder', 'starting', 'new', 'era'...
# 1401  ['college', 'uconn', '3', 'byu', '1', 'freshma...
# 1402  ['bear', 'legend', 'wnba', 'star', 'see', 'fir...
# 1403  ['editor', 'note', 'first', 'twopart', 'series...
# 1404  ['could', 'prove', 'one', 'coach', 'mike', 'kr...
# ...                                                 ...
# 1495  ['twentysix', 'specie', 'rare', 'plant', 'life...
# 1496  ['john', 'kresse', '560143', '23', 'season', '...
# 1497  ['ncaa', 'committee', 'yesterday', 'decided', ...
# 1498  ['american', 'south', 'long', 'leading', 'expo...
# 1499  ['tennessee', '63', 'winthrop', '61', 'grab', ...
#
# [100 rows x 5 columns]
# --- Topic 15 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1500        10998             15             0.8034
# 1501       130271             15             0.7924
# 1502        36431             15             0.7768
# 1503        71749             15             0.7721
# 1504        98639             15             0.7481
# ...           ...            ...                ...
# 1595       138802             15              0.618
# 1596        47250             15             0.6176
# 1597        18138             15             0.6175
# 1598        93517             15             0.6175
# 1599        69649             15             0.6164
#
#                                                Keywords  \
# 1500  arizona, baseball, game, asu, run, series, sof...
# 1501  arizona, baseball, game, asu, run, series, sof...
# 1502  arizona, baseball, game, asu, run, series, sof...
# 1503  arizona, baseball, game, asu, run, series, sof...
# 1504  arizona, baseball, game, asu, run, series, sof...
# ...                                                 ...
# 1595  arizona, baseball, game, asu, run, series, sof...
# 1596  arizona, baseball, game, asu, run, series, sof...
# 1597  arizona, baseball, game, asu, run, series, sof...
# 1598  arizona, baseball, game, asu, run, series, sof...
# 1599  arizona, baseball, game, asu, run, series, sof...
#
#                                                    Text
# 1500  ['cal', 'state', 'northridge', 'left', 'big', ...
# 1501  ['april', '3', '2013', 'age', '30', 'following...
# 1502  ['gazing', '500', 'kid', 'crowded', 'gym', 'cu...
# 1503  ['day', 'traded', 'away', 'nearly', 'every', '...
# 1504  ['week', 'ago', 'austin', 'river', 'became', '...
# ...                                                 ...
# 1595  ['president', 'joe', 'biden', 'wednesday', 'pa...
# 1596  ['h', 'catlin', 'founded', 'ucla', 'olympic', ...
# 1597  ['steve', 'carp', 'reviewjournal', 'unlv', 'co...
# 1598  ['watch', 'baseball', 'fan', 'shriners', 'voll...
# 1599  ['caption', 'text', 'illustration', 'caption',...
#
# [100 rows x 5 columns]
# --- Topic 16 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1600        74149             16             0.8647
# 1601        30536             16             0.8618
# 1602        40931             16               0.85
# 1603        82108             16             0.8488
# 1604        37076             16             0.8176
# ...           ...            ...                ...
# 1695        70319             16             0.6478
# 1696       136430             16             0.6474
# 1697       109646             16             0.6465
# 1698       119555             16             0.6461
# 1699         3009             16              0.646
#
#                                                Keywords  \
# 1600  golf, tour, open, championship, 2023, round, t...
# 1601  golf, tour, open, championship, 2023, round, t...
# 1602  golf, tour, open, championship, 2023, round, t...
# 1603  golf, tour, open, championship, 2023, round, t...
# 1604  golf, tour, open, championship, 2023, round, t...
# ...                                                 ...
# 1695  golf, tour, open, championship, 2023, round, t...
# 1696  golf, tour, open, championship, 2023, round, t...
# 1697  golf, tour, open, championship, 2023, round, t...
# 1698  golf, tour, open, championship, 2023, round, t...
# 1699  golf, tour, open, championship, 2023, round, t...
#
#                                                    Text
# 1600  ['cloud', 'performed', 'hostile', 'takeover', ...
# 1601  ['opposing', 'team', 'thrown', 'tough', 'defen...
# 1602  ['sport', 'log', 'figure', 'skating', 'kim', '...
# 1603  ['suzy', 'favor', 'hamilton', 'top', 'american...
# 1604  ['college', 'football', 'ron', 'zook', 'arrive...
# ...                                                 ...
# 1695  ['reserve', 'guard', 'louisville', 'coach', 'r...
# 1696  ['final', 'buzzer', 'sounded', 'march', '16', ...
# 1697  ['jason', 'day', 'getting', 'better', 'forgett...
# 1698  ['betting', 'march', 'madness', 'basketball', ...
# 1699  ['rsec', 'gopher', 'must', 'deal', 'consequenc...
#
# [100 rows x 5 columns]
# --- Topic 17 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1700        63571             17             0.9003
# 1701        63969             17             0.8952
# 1702        28279             17             0.8883
# 1703        83052             17             0.8809
# 1704        72243             17             0.8807
# ...           ...            ...                ...
# 1795        50477             17             0.7909
# 1796        89638             17             0.7909
# 1797        18321             17             0.7908
# 1798        71159             17             0.7908
# 1799       143545             17               0.79
#
#                                                Keywords  \
# 1700  point, scored, second, lead, first, state, reb...
# 1701  point, scored, second, lead, first, state, reb...
# 1702  point, scored, second, lead, first, state, reb...
# 1703  point, scored, second, lead, first, state, reb...
# 1704  point, scored, second, lead, first, state, reb...
# ...                                                 ...
# 1795  point, scored, second, lead, first, state, reb...
# 1796  point, scored, second, lead, first, state, reb...
# 1797  point, scored, second, lead, first, state, reb...
# 1798  point, scored, second, lead, first, state, reb...
# 1799  point, scored, second, lead, first, state, reb...
#
#                                                    Text
# 1700  ['check', 'ncaa', 'tournament', 'story', 'phot...
# 1701  ['one', 'day', 'cal', 'state', 'northridge', '...
# 1702  ['eric', 'musselman', 'fired', 'wednesday', 't...
# 1703  ['hoover', 'ala', 'hoover', 'ala', 'indiana', ...
# 1704  ['question', 'arose', 'recently', 'regarding',...
# ...                                                 ...
# 1795  ['ojai', 'day', 'university', 'nevada', 'la', ...
# 1796  ['maine', 'may', 'locked', 'colonial', 'athlet...
# 1797  ['rugby', 'u', 'team', 'face', 'tough', 'opene...
# 1798  ['washing', 'dish', 'seafood', 'restaurant', '...
# 1799  ['dave', 'flint', 'never', 'counted', 'northea...
#
# [100 rows x 5 columns]
# --- Topic 18 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1800        29156             18             0.9533
# 1801        79729             18             0.9372
# 1802        31218             18             0.9198
# 1803         5039             18             0.9133
# 1804        33437             18             0.9122
# ...           ...            ...                ...
# 1895        88065             18             0.7518
# 1896       100886             18             0.7517
# 1897        87797             18             0.7491
# 1898        73009             18             0.7488
# 1899        42394             18             0.7486
#
#                                                Keywords  \
# 1800  sport, game, basketball, network, college, fan...
# 1801  sport, game, basketball, network, college, fan...
# 1802  sport, game, basketball, network, college, fan...
# 1803  sport, game, basketball, network, college, fan...
# 1804  sport, game, basketball, network, college, fan...
# ...                                                 ...
# 1895  sport, game, basketball, network, college, fan...
# 1896  sport, game, basketball, network, college, fan...
# 1897  sport, game, basketball, network, college, fan...
# 1898  sport, game, basketball, network, college, fan...
# 1899  sport, game, basketball, network, college, fan...
#
#                                                    Text
# 1800  ['last', 'row', 'bold', 'name', 'mitch', 'albo...
# 1801  ['houston', 'somewhere', 'connecticut', 'fall'...
# 1802  ['tennessee', '59', 'rutgers', '49', 'througho...
# 1803  ['university', 'park', 'pa', 'semifinal', 'thu...
# 1804  ['former', 'baylor', 'basketball', 'player', '...
# ...                                                 ...
# 1895  ['ben', 'howland', 'fault', 'put', 'blame', 'u...
# 1896  ['junior', 'sam', 'mattis', 'penn', 'uncorked'...
# 1897  ['let', 'sink', 'every', 'position', 'player',...
# 1898  ['connecticut', 'coach', 'jim', 'calhoun', 'me...
# 1899  ['almost', 'fitting', 'moltentempered', 'bob',...
#
# [100 rows x 5 columns]
# --- Topic 19 ---
#       Document_No Dominant_Topic Topic_Perc_Contrib  \
# 1900        38552             19             0.8077
# 1901        46055             19             0.7235
# 1902         9233             19             0.7065
# 1903        28722             19             0.6714
# 1904        31712             19             0.5978
# ...           ...            ...                ...
# 1995        89067             19             0.3841
# 1996        63814             19             0.3832
# 1997       117053             19             0.3831
# 1998       115506             19              0.383
# 1999        32711             19             0.3801
#
#                                                Keywords  \
# 1900  ucla, usc, bruin, trojan, oregon, los, angeles...
# 1901  ucla, usc, bruin, trojan, oregon, los, angeles...
# 1902  ucla, usc, bruin, trojan, oregon, los, angeles...
# 1903  ucla, usc, bruin, trojan, oregon, los, angeles...
# 1904  ucla, usc, bruin, trojan, oregon, los, angeles...
# ...                                                 ...
# 1995  ucla, usc, bruin, trojan, oregon, los, angeles...
# 1996  ucla, usc, bruin, trojan, oregon, los, angeles...
# 1997  ucla, usc, bruin, trojan, oregon, los, angeles...
# 1998  ucla, usc, bruin, trojan, oregon, los, angeles...
# 1999  ucla, usc, bruin, trojan, oregon, los, angeles...
#
#                                                    Text
# 1900  ['chris', 'kenny', 'drove', 'length', 'court',...
# 1901  ['top', 'seed', 'awarded', 'florida', 'ohio', ...
# 1902  ['ncaa', 'tournament', '2', '1', '2', 'decade'...
# 1903  ['college', 'basketball', 'look', 'stage', 'tw...
# 1904  ['hofstra', 'football', 'coach', 'joe', 'gardi...
# ...                                                 ...
# 1995  ['final', 'high', 'school', 'girl', 'basketbal...
# 1996  ['ucla', 'open', 'second', 'football', 'season...
# 1997  ['malibu', 'ocean', 'become', 'bluer', 'since'...
# 1998  ['columbus', 'ohio', 'geno', 'auriemma', 'warn...
# 1999  ['could', 'pin', 'former', 'twin', 'public', '...
#
# [100 rows x 5 columns]

# %%
# Define the path to save the Excel file in your Google Drive
excel_file_path = '/content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_20_topics.xlsx'

# Save the DataFrame to an Excel file
try:
    top_100_documents_per_topic.to_excel(excel_file_path, index=False)
    print(f"Successfully saved the top 100 documents per topic to: {excel_file_path}")
except Exception as e:
    print(f"An error occurred while saving the Excel file: {e}")
# Out:
# Successfully saved the top 100 documents per topic to: /content/drive/MyDrive/Colab Notebooks/alex/top_100_articles/top_100_documents_per_topic_for_20_topics.xlsx

# %% [markdown]
# ##### **© 2024–2025 MD Rafsun Sheikh**
# ##### **Licensed under the Apache License, Version 2.0.**
