# %%
# Out:
# Raw file content (first 1000 characters):
# ____________________________________________________________
#
# ON THIS DATE
#
# http://ezproxy.newcastle.edu.au/login?url=https://www.proquest.com/newspapers/on-this-date/docview/3211794553/se-2?accountid=10499
#
# Abstract: None available.
#
# Links: https://newcastle.primo.exlibrisgroup.com/discovery/openurl?institution=61UON_INST&amp;vid=61UON_INST:61UON&amp;genre=article&amp;issn=10856706&amp;title=ON+THIS+DATE&amp;volume=&amp;issue=&amp;date=2025&amp;atitle=ON+THIS+DATE&amp;spage=4&amp;sid=ProQ%3Achicagotribune&amp;author=
#
# https://newcastle.primo.exlibrisgroup.com/discovery/openurl?institution=61UON_INST&amp;vid=61UON_INST:61UON&amp;genre=article&amp;issn=10856706&amp;title=ON+THIS+DATE&amp;volume=&amp;issue=&amp;date=2025&amp;atitle=ON+THIS+DATE&amp;spage=4&amp;sid=ProQ%3Achicagotribune&amp;author=
#
# Full text: ON THIS DATE
# May 27
# ...

# %% [markdown]
# # Task
# Analyze the text file "/content/2025_5.txt" and suggest possible analyses that can be performed on the data.

# %% [markdown]
# ## Parse the text file
#
# ### Subtask:
# Read the text file and extract information for each article, including the date, abstract, links, and full text.

# %%
# Out:
# --- Article 1 ---
# Date: May 27
# Abstract: None available.
# Links: ['http://ezproxy.newcastle.edu.au/login?url=https://www.proquest.com/newspapers/on-this-date/docview/3211794553/se-2?accountid=10499', 'https://newcastle.primo.exlibrisgroup.com/discovery/openurl?institution=61UON_INST&amp;vid=61UON_INST:61UON&amp;genre=article&amp;issn=10856706&amp;title=ON+THIS+DATE&amp;volume=&amp;issue=&amp;date=2025&amp;atitle=ON+THIS+DATE&amp;spage=4&amp;sid=ProQ%3Achicagotribune&amp;author=', 'https://newcastle.primo.exlibrisgroup.com/discovery/openurl?institution=61UON_INST&amp;vid=61UON_INST:61UON&amp;genre=article&amp;issn=10856706&amp;title=ON+THIS+DATE&amp;volume=&amp;issue=&amp;date=2025&amp;atitle=ON+THIS+DATE&amp;spage=4&amp;sid=ProQ%3Achicagotribune&amp;author=', 'http://ezproxy.newcastle.edu.au/login?url=https://www.proquest.com/usnews/newspapers/on-this-date/docview/3211794553/sem-2?accountid=10499']
# Full Text: ON THIS DATE
# May 27
# ...

# %%
# Out:
# --- Article 1 ---
# Date: May 27
# Abstract: None available.
# Links: ['http://ezproxy.newcastle.edu.au/login?url=https://www.proquest.com/newspapers/on-this-date/docview/3211794553/se-2?accountid=10499', 'https://newcastle.primo.exlibrisgroup.com/discovery/openurl?institution=61UON_INST&amp;vid=61UON_INST:61UON&amp;genre=article&amp;issn=10856706&amp;title=ON+THIS+DATE&amp;volume=&amp;issue=&amp;date=2025&amp;atitle=ON+THIS+DATE&amp;spage=4&amp;sid=ProQ%3Achicagotribune&amp;author=', 'https://newcastle.primo.exlibrisgroup.com/discovery/openurl?institution=61UON_INST&amp;vid=61UON_INST:61UON&amp;genre=article&amp;issn=10856706&amp;title=ON+THIS+DATE&amp;volume=&amp;issue=&amp;date=2025&amp;atitle=ON+THIS+DATE&amp;spage=4&amp;sid=ProQ%3Achicagotribune&amp;author=', 'http://ezproxy.newcastle.edu.au/login?url=https://www.proquest.com/usnews/newspapers/on-this-date/docview/3211794553/sem-2?accountid=10499']
# Full Text: ON THIS DATE
# May 27
# ...

# %%
# Out:
# --- Article 1 ---
# Date: May 27
# Abstract: None available.
# Links: ['http://ezproxy.newcastle.edu.au/login?url=https://www.proquest.com/newspapers/on-this-date/docview/3211794553/se-2?accountid=10499', 'https://newcastle.primo.exlibrisgroup.com/discovery/openurl?institution=61UON_INST&amp;vid=61UON_INST:61UON&amp;genre=article&amp;issn=10856706&amp;title=ON+THIS+DATE&amp;volume=&amp;issue=&amp;date=2025&amp;atitle=ON+THIS+DATE&amp;spage=4&amp;sid=ProQ%3Achicagotribune&amp;author=', 'https://newcastle.primo.exlibrisgroup.com/discovery/openurl?institution=61UON_INST&amp;vid=61UON_INST:61UON&amp;genre=article&amp;issn=10856706&amp;title=ON+THIS+DATE&amp;volume=&amp;issue=&amp;date=2025&amp;atitle=ON+THIS+DATE&amp;spage=4&amp;sid=ProQ%3Achicagotribune&amp;author=', 'http://ezproxy.newcastle.edu.au/login?url=https://www.proquest.com/usnews/newspapers/on-this-date/docview/3211794553/sem-2?accountid=10499']
# Full Text: ON THIS DATE
# May 27
# ...

# %% [markdown]
# ## Create a dataframe
#
# ### Subtask:
# Organize the extracted information into a pandas DataFrame with appropriate column names.

# %%
# Out:
#            Date         Abstract  \
# 0        May 27  None available.
# 1        May 25  None available.
# 2  May 25, 2025  None available.
# 3  May 25, 2025  None available.
# 4  May 24, 2025  None available.
#
#                                                Links  \
# 0  [http://ezproxy.newcastle.edu.au/login?url=htt...
# 1  [http://ezproxy.newcastle.edu.au/login?url=htt...
# 2  [http://ezproxy.newcastle.edu.au/login?url=htt...
# 3  [http://ezproxy.newcastle.edu.au/login?url=htt...
# 4  [http://ezproxy.newcastle.edu.au/login?url=htt...
#
#                                            Full Text
# 0  ON THIS DATE\nMay 27\n1904: Dennis McGann of t...
# 1  ON THIS DATE\nMay 25\n1906: Jesse Tannehill's ...
# 2  Few things in my life have been as consistent ...
# 3  Picked-up pieces while wondering if we’re witn...
# 4  Give President Trump the chance to banter, and...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 4 columns):
# ...

# %% [markdown]
# ## Clean and preprocess the data
#
# ### Subtask:
# Handle any missing values or inconsistencies in the extracted data.

# %%
# Out:
# Missing values before handling:
# Date         1
# Abstract     1
# Links        0
# Full Text    0
# dtype: int64

# %%
# Out:
# Missing values after handling:
# Date         0
# Abstract     0
# Links        0
# Full Text    0
# dtype: int64
# /tmp/ipython-input-9-277632988.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_articles['Date'].fillna('None', inplace=True)
# /tmp/ipython-input-9-277632988.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ## Suggest specific analyses
#
# ### Subtask:
# Based on the structured data, provide concrete examples of analyses that can be performed.

# %%
# Out:
# Suggested Analyses based on the Extracted Data:
#
# 1. Time-Based Analyses (using the 'Date' column):
#    - Analyze the frequency of articles published on specific dates.
#    - Identify trends or patterns in publication dates over the extracted period.
#    - If the date format allows, analyze the distribution of articles across days of the week or months.
#
# 2. Text-Based Analyses (using 'Abstract' and 'Full Text' columns):
#    - Topic Modeling: Identify major themes or topics discussed across the articles using techniques like LDA or NMF on the 'Full Text'.
#    - Sentiment Analysis: Determine the overall sentiment (positive, negative, neutral) of the articles or specific sections of the text.
#    - Keyword Extraction: Extract important keywords or phrases from the 'Full Text' to understand the main subjects of each article.
#    - Named Entity Recognition (NER): Identify and classify named entities (e.g., persons, organizations, locations) mentioned in the text.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The raw text file was successfully parsed to extract information for 155 articles, including Date, Abstract, Links, and Full Text, despite variations in the text structure.
# *   The extracted data was effectively organized into a pandas DataFrame with columns 'Date', 'Abstract', 'Links', and 'Full Text'.
# *   Missing values were identified in the 'Date' and 'Abstract' columns (one in each) and were handled by filling them with the placeholder 'None'.
# *   The DataFrame is now structured and cleaned, enabling further analysis.
#
# ### Insights or Next Steps
#
# *   Proceed with implementing the suggested analyses, starting with time-based and text-based analyses to gain initial insights into the content and publication patterns of the articles.
# *   Explore the link-based analyses to understand the external resources referenced and consider integrating external data if possible.

# %%
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Out:
#                                            Full Text  \
# 0  ON THIS DATE\nMay 27\n1904: Dennis McGann of t...
# 1  ON THIS DATE\nMay 25\n1906: Jesse Tannehill's ...
# 2  Few things in my life have been as consistent ...
# 3  Picked-up pieces while wondering if we’re witn...
# 4  Give President Trump the chance to banter, and...
#
#                                             Keywords
# 0  [hit, league, first, game, record, two, chicag...
# 1  [hit, first, chicago, sox, game, inning, win, ...
# 2  [jaws, shark, water, one, movie, chicago, shar...
# 3  [sox, red, boston, two, celtics, new, 2025, ye...
# 4  [trump, sports, said, year, president, publica...

# %% [markdown]
# # Task
# Analyze the text file "/content/2025_5.txt" to identify keywords, topics, and named entities, and perform topic modeling using LDA to identify the main themes.

# %% [markdown]
# ## Text preprocessing for lda
#
# ### Subtask:
# Clean and prepare the 'Full Text' data for topic modeling, including tokenization, removing stopwords and punctuation, and potentially stemming or lemmatization.

# %%
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                            Full Text  \
# 0  ON THIS DATE\nMay 27\n1904: Dennis McGann of t...
# 1  ON THIS DATE\nMay 25\n1906: Jesse Tannehill's ...
# 2  Few things in my life have been as consistent ...
# 3  Picked-up pieces while wondering if we’re witn...
# 4  Give President Trump the chance to banter, and...
#
#                                       Processed Text
# 0  [date, may, 27, 1904, dennis, mcgann, new, yor...
# 1  [date, may, 25, 1906, jesse, tannehill, 30, vi...
# 2  [thing, life, consistent, jaw, friendship, old...
# 3  [pickedup, piece, wondering, ’, witnessing, cu...
# 4  [give, president, trump, chance, banter, often...

# %%
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                            Full Text  \
# 0  ON THIS DATE\nMay 27\n1904: Dennis McGann of t...
# 1  ON THIS DATE\nMay 25\n1906: Jesse Tannehill's ...
# 2  Few things in my life have been as consistent ...
# 3  Picked-up pieces while wondering if we’re witn...
# 4  Give President Trump the chance to banter, and...
#
#                                       Processed Text
# 0  [date, may, 27, 1904, dennis, mcgann, new, yor...
# 1  [date, may, 25, 1906, jesse, tannehill, 30, vi...
# 2  [thing, life, consistent, jaw, friendship, old...
# 3  [pickedup, piece, wondering, ’, witnessing, cu...
# 4  [give, president, trump, chance, banter, often...

# %% [markdown]
# ## Create dictionary and corpus
#
# ### Subtask:
# Generate a dictionary and a corpus (bag-of-words representation) from the preprocessed text data, which are required inputs for LDA.

# %%
# Out:
# Dictionary:
# Dictionary<18851 unique tokens: ['0for12', '10', '100', '100th', '101']...>
#
# Corpus (first 5 documents):
# ...

# %% [markdown]
# ## Train lda model
#
# ### Subtask:
# Train an LDA model on the corpus to identify the underlying topics.

# %% [markdown]
# **Reasoning**:
# Train an LDA model using the corpus and dictionary.

# %%
# Out:
# LDA Topics:
# (0, '0.008*"team" + 0.007*"nt" + 0.007*"state" + 0.007*"game" + 0.006*"publication" + 0.006*"point" + 0.006*"basketball" + 0.006*"said" + 0.005*"clark" + 0.005*"year"')
# (1, '0.008*"team" + 0.007*"said" + 0.007*"new" + 0.007*"’" + 0.007*"city" + 0.006*"girl" + 0.006*"wrestling" + 0.006*"york" + 0.004*"smith" + 0.004*"school"')
# (2, '0.010*"people" + 0.009*"order" + 0.009*"said" + 0.008*"center" + 0.007*"transgender" + 0.007*"federal" + 0.007*"trans" + 0.006*"woman" + 0.006*"executive" + 0.006*"gender"')
# (3, '0.013*"hit" + 0.011*"run" + 0.009*"first" + 0.007*"game" + 0.007*"homer" + 0.007*"inning" + 0.007*"chicago" + 0.007*"home" + 0.006*"sox" + 0.006*"win"')
# (4, '0.018*"’" + 0.010*"sport" + 0.009*"“" + 0.008*"said" + 0.008*"”" + 0.006*"trump" + 0.006*"hall" + 0.005*"publication" + 0.005*"year" + 0.005*"kid"')
# ...

# %% [markdown]
# ## Train lda model retry 1
#
# ### Subtask:
# Train an LDA model on the corpus to identify the underlying topics. This is a retry due to a library compatibility issue in the previous attempt.

# %%
# Out:
# LDA Topics:
# (0, '0.008*"team" + 0.007*"nt" + 0.007*"state" + 0.007*"game" + 0.006*"publication" + 0.006*"point" + 0.006*"basketball" + 0.006*"said" + 0.005*"clark" + 0.005*"year"')
# (1, '0.008*"team" + 0.007*"said" + 0.007*"new" + 0.007*"’" + 0.007*"city" + 0.006*"girl" + 0.006*"wrestling" + 0.006*"york" + 0.004*"smith" + 0.004*"school"')
# (2, '0.010*"people" + 0.009*"order" + 0.009*"said" + 0.008*"center" + 0.007*"transgender" + 0.007*"federal" + 0.007*"trans" + 0.006*"woman" + 0.006*"executive" + 0.006*"gender"')
# (3, '0.013*"hit" + 0.011*"run" + 0.009*"first" + 0.007*"game" + 0.007*"homer" + 0.007*"inning" + 0.007*"chicago" + 0.007*"home" + 0.006*"sox" + 0.006*"win"')
# (4, '0.018*"’" + 0.010*"sport" + 0.009*"“" + 0.008*"said" + 0.008*"”" + 0.006*"trump" + 0.006*"hall" + 0.005*"publication" + 0.005*"year" + 0.005*"kid"')
# ...

# %% [markdown]
# ## Analyze lda results
#
# ### Subtask:
# Examine the topics and their associated keywords to interpret the main themes.

# %%
# Out:
# Interpreting LDA Topics:
#
# Topic #0:
# Keywords: 0.008*"team" + 0.007*"nt" + 0.007*"state" + 0.007*"game" + 0.006*"publication" + 0.006*"point" + 0.006*"basketball" + 0.006*"said" + 0.005*"clark" + 0.005*"year"
# This topic appears to be related to: Sports (games, teams, seasons, players).
#
# Topic #1:
# Keywords: 0.008*"team" + 0.007*"said" + 0.007*"new" + 0.007*"’" + 0.007*"city" + 0.006*"girl" + 0.006*"wrestling" + 0.006*"york" + 0.004*"smith" + 0.004*"school"
# This topic appears to be related to: Sports (games, teams, seasons, players).
#
# Topic #2:
# Keywords: 0.010*"people" + 0.009*"order" + 0.009*"said" + 0.008*"center" + 0.007*"transgender" + 0.007*"federal" + 0.007*"trans" + 0.006*"woman" + 0.006*"executive" + 0.006*"gender"
# This topic appears to be related to: General news or miscellaneous topics.
#
# Topic #3:
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The primary obstacle encountered throughout the analysis was a persistent `ValueError` indicating a numpy dtype size mismatch when using the `gensim` library for creating the dictionary, corpus, and training the LDA model. This suggests a binary incompatibility between the installed versions of numpy and gensim within the execution environment.
# *   Attempts to resolve the library compatibility issue by uninstalling and reinstalling `numpy`, `scipy`, and `gensim` were unsuccessful, likely due to conflicts with other pre-installed libraries in the environment.
# *   As a direct consequence of the unresolved library compatibility issue, the creation of the dictionary and corpus, and subsequently the training and analysis of the LDA model, could not be completed.
# *   The final attempt to analyze the LDA results failed with a `NameError` because the `lda_model` object was not successfully created in the preceding steps due to the underlying library issue.
#
# ### Insights or Next Steps
#
# *   The environment requires a thorough review and potential reconstruction to ensure compatible versions of `numpy`, `scipy`, and `gensim` can be installed without conflicts with other necessary libraries.
# *   Consider using a virtual environment or a containerized environment to manage dependencies and avoid conflicts between different projects or system-wide libraries.

# %%
# Out:
# Dictionary:
# Dictionary<18851 unique tokens: ['0for12', '10', '100', '100th', '101']...>
#
# Corpus (first 5 documents):
# ...

# %% [markdown]
# ##### **© 2024–2025 MD Rafsun Sheikh**
# ##### **Licensed under the Apache License, Version 2.0.**
